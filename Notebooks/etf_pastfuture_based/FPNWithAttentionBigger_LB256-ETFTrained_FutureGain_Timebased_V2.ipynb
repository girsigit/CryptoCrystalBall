# %% [markdown]
# # Mount drive and bucket
# Todo: Remove in public version

# %%
# Check if the notebook is run in Google Colab
import sys

COLAB = 'google.colab' in sys.modules

# %%
# Uncomment this cell to provide logging output to a file in addition to the lab in the browser
# This also keeps logging if the browser window is closed

# import datetime
# import logging

# nblog = open(f"/content/CryptoCrystalBall/Data/logs/nb_{datetime.datetime.utcnow().strftime('%Y%m%d_%H%M')}.log", "a+")
# print(nblog)
# sys.stdout.echo = nblog
# sys.stderr.echo = nblog

# %autosave 60

# %%
if COLAB:
  from google.colab import auth
  auth.authenticate_user()
else:
    print("Run the command!")
  #Todo #bring the command inside the notebook
  #run this terminal inside docker: gcloud auth login b.girsule@gmail.com --no-launch-browser
# Out:
# Run the command!

# %%
# Check if the tf version is 2.10.0, this is required to use the 'ignore_class' in the  SparseCategoricalCrossentropy
import tensorflow as tf

if '2.10.0' != tf.__version__:
  # !pip uninstall tensorflow -y
  # !pip install tensorflow-gpu==2.10.0
  please_restart_the_runtime
else:
  print("TF Version is 2.10.0, ok!")
# Out:
# 2023-04-03 12:00:17.240525: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 12:00:17.514780: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 12:00:17.613785: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-04-03 12:00:18.495949: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-03 12:00:18.496011: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-03 12:00:18.496016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TF Version is 2.10.0, ok!

# %%
from tensorflow import keras
from tensorflow.python.lib.io import file_io

from keras.layers import Input, Dense, Flatten, UnitNormalization, Permute, Conv1D, UpSampling1D, Add, LSTM, Concatenate, Multiply, Activation, Attention, Dropout
from keras.models import Model
from keras.optimizers import Adam

# %%
import os
from os import listdir
from os.path import isfile, join

# %%
import pandas as pd
import numpy as np
import copy
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import gc
import random
import datetime

# %%
# Set the google cloud bucket data
project_id = 'tweetprediction'
bucket_name = 'crypto_nlp_training'

# %%
# Set the checkpoint path for saving train progress
if COLAB:
    raise NotImplementedError("Google Buckets have to be implemented in this notebook before using them in Colab!")
    CHECKPOINT_PATH = f"gs://{bucket_name}/chk/"
else:
    CHECKPOINT_PATH = f"/content/bigdata/chk/"

# %%
# Check if the notebook is run in google colab, if so, clone the repo
if COLAB:
    print("Running in Colab")

    # Clone the whole repo to get all data and code if not already done
    if not os.path.exists("/content/CryptoCrystalBall"):
      # !git clone https://github.com/girsigit/CryptoCrystalBall

    # %cd /content

# %%
# Try importing the Ta-Lib library, if this fails, try to install it and
# import it again afterwards
try:
    import talib
except:
    # !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
    # !tar -xzvf ta-lib-0.4.0-src.tar.gz
    # %cd ta-lib
    # !./configure --prefix=/usr
    # !make
    # !make install
    # !pip install Ta-Lib
    # %cd ..

    import talib

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ---
# # Add custom import path for DataStreamCreator and IndicatorCalculator
#
# These libs are not in the standard python directory, so their paths have to be added to the import paths

# %%
# Get the current directory
current_dir = os.getcwd()
current_dir_splitted = ["", "content"]
current_dir_splitted
# Out:
# ['', 'content']

# %%
# Create the import directories for the DataStreamCreator and the IndicatorCalculator
dsc_dir = '/content/CryptoCrystalBall/DataStreamCreator'
print(f"dsc_dir: {dsc_dir}")

ind_dir = '/content/CryptoCrystalBall/IndicatorCalculator'
print(f"ind_dir: {ind_dir}")

# Add them to the import paths
sys.path.insert(0, dsc_dir)
sys.path.insert(0, ind_dir)
# Out:
# dsc_dir: /content/CryptoCrystalBall/DataStreamCreator
# ind_dir: /content/CryptoCrystalBall/IndicatorCalculator

# %%
# Import the actual classes
from IndicatorCalculator import IndicatorCalculator
import DataStreamCreator

# %% [markdown]
# ---
# # Define all the parameters and variables

# %%
# # Define the tick data path
# DATA_PATH = os.path.join(os.sep, *current_dir_splitted, 'DemoData')
# print(f"DATA_PATH: {DATA_PATH}")

# %%
# # Define the chart image save path
# IMG_SAVE_PATH = os.path.join(os.sep, *current_dir_splitted, 'Documentation', 'Images')
# print(f"IMG_SAVE_PATH: {IMG_SAVE_PATH}")

# %%
# Define a global random seed
RANDOM_SEED = 42

# Set the seed in np
np.random.seed(RANDOM_SEED)

# %%
# X_BLOCK_LENGHT defines how far into the past a 'slice of a chart' shall be
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator#xblockgenerator

# For this ML architecture, the X_BLOCK_LENGHT has to be a member of 2**n, otherwise the feature pyramid cannot be built correctly 

# X_BLOCK_LENGHT = 256
X_BLOCK_LENGHT = 128

# %%
# How many examples shall be processed at the same time, limited by GPU memory
BATCH_SIZE = 384 # for X_BLOCK_LENGHT = 256
BATCH_SIZE = 512 # for X_BLOCK_LENGHT = 128

# %%
# A fixed number of features is used
FEATURES = 160

# %%
# Finanical indicator timespans
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/IndicatorCalculator
SHORTSPAN = 7
MIDSPAN = 38
LONGSPAN = 50

# %%
# Additional settings for the data stream
# For this notebook, the calculation of pattern indicators is turned off
DATA_STREAM_PARAMETERS = {
    "calcPatternIndicators": False, # No patterns are used
    "calcVolumeInidators": False, # No volume indicators, these are wide spread and may disturb the classifer
    "dropna": True # Drop all tick/indicator table rows containing nan values instead of just replacing them by 0 (which would lead to wrong predictions)
}

# %% [markdown]
# # Load the dataset

# %%
# Define the dataset path
DATASET_PATH = "/content/dataset/ETF/tickdata/ticks"

# Get all file names
ALL_FILES = [os.path.join(DATASET_PATH,f) for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f)) and ".csv" in f ]

# Sort them (as a stable basis for randomizing afterwards)
ALL_FILES = sorted(ALL_FILES)

print(f"The whole dataset contains {len(ALL_FILES)} files.")
print(ALL_FILES[:3])
# Out:
# The whole dataset contains 1064 files.
# ['/content/dataset/ETF/tickdata/ticks/DE0002635265.csv', '/content/dataset/ETF/tickdata/ticks/DE0002635273.csv', '/content/dataset/ETF/tickdata/ticks/DE0002635281.csv']

# %% [markdown]
# ### Split the dataset into 3 parts
# - The **train** set is used to train the machine-learning network then used to predicting future information
# - The **test** set is used in the next step. On it a trading (entry/exit) strategy will be developed
# - The **eval** set will then be used as an never-seen set to try and evalutate the combination of the ML network and the trading strategy

# %%
# It uses a fixed random seed to allow this cell to be copied to other notebooks producing the same result
SPLIT_RANDOM_SEED = 666

TRAIN_SET_SIZE = 0.5
TEST_SET_SIZE = 0.25
# EVAL_SET_SIZE: The rest

# Files are shuffled before splitting
random.Random(SPLIT_RANDOM_SEED).shuffle(ALL_FILES)

train_split_index = int(len(ALL_FILES) * TRAIN_SET_SIZE)
print(f"train_split_index: {train_split_index}")

test_split_index = int(len(ALL_FILES) * (TRAIN_SET_SIZE + TEST_SET_SIZE))
print(f"test_split_index: {test_split_index}")

TRAIN_FILES = ALL_FILES[:train_split_index]
TEST_FILES = ALL_FILES[train_split_index:test_split_index]
EVAL_FILES = ALL_FILES[test_split_index:]

print(f"The train set contains {len(TRAIN_FILES)} files")
print(f"The test set contains {len(TEST_FILES)} files")
print(f"The eval set contains {len(EVAL_FILES)} files")
# Out:
# train_split_index: 532
# test_split_index: 798
# The train set contains 532 files
# The test set contains 266 files
# The eval set contains 266 files

# %% [markdown]
# ---
# # Prepare data source
#
# For training a neural network, first the data source has to be prepared. For this purpose, the method `FileListToDataStream` from the `DataStreamCreator` class is used. This method creates a stream of `X-Block` and `y-data` arrays out of a list of .csv file names, pointing to tick tables (called `EXAMPLE_FILE_PATHS` in this example). For details about `X-Blocks` and `y-data`, please refer to the documentation of the `XBlockGenerator` and the `YDataGenerator` under https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator.
#
# <br>
#
# As y values for training the ML network the possible future gain and it derivation will be used. The y data type `PARAM_DICT_TEMPLATE_Y_DATA_TYPE_PAST_FUTURE_GAIN` will provide both past and future gain, but the model will only be trained on the future gain, as the past gain can be easily calculated directly, also in a live application.

# %%
Y_TYPE_DICT = copy.deepcopy(DataStreamCreator.YDataGenerator.PARAM_DICT_TEMPLATE_Y_DATA_TYPE_PAST_FUTURE_GAIN)

Y_TYPE_DICT["gain_timespan"] = 60
# Y_TYPE_DICT["direction_ma_timespan"] = 14
# Y_TYPE_DICT["derivation_ma_timespan"] = 14

Y_TYPE_DICT
# Out:
# {'dataType': 3,
#  'gain_timespan': 60,
#  'direction_ma_timespan': 48,
#  'derivation_ma_timespan': 48}

# %%
XShape = (BATCH_SIZE, X_BLOCK_LENGHT, FEATURES)
XShape
# Out:
# (512, 128, 160)

# %%
# A python generator function has to be applied on the dataStream

def pythonGeneratorSignalsTraining():
  # Initialize the FileListToDataStream generator
  dataStreamTraining = DataStreamCreator.FileListToDataStream(fileList = TRAIN_FILES,
                                                      batch_size = BATCH_SIZE,
                                                      X_Block_lenght = X_BLOCK_LENGHT,
                                                      y_type_dict=Y_TYPE_DICT,
                                                      shuffle=True,
                                                      parallel_generators = np.min([BATCH_SIZE, 8]),
                                                      random_seed = RANDOM_SEED,
                                                      **DATA_STREAM_PARAMETERS
                                                      )

  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStreamTraining)
      _X = ne['X']
      _y = ne['y'][:,[1,3]]
    
      # Limit the y signal to avoid excess
      _y /= 10.0
      _y = np.clip(_y, -10.0, 10.0)

      yield (_X, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
tfGenTraining = tf.data.Dataset.from_generator(pythonGeneratorSignalsTraining, 
                                               output_types = (tf.float32, tf.float32),
                                               output_shapes=(
                                                   (BATCH_SIZE, X_BLOCK_LENGHT, FEATURES),
                                                   (BATCH_SIZE, 2)
                                                   )
                                               )

tfGenTraining = tfGenTraining.prefetch(buffer_size=32)
tfGenTraining
# Out:
# 2023-04-03 12:00:22.350932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:22.423931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:22.424188: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:22.426799: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 12:00:22.429218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:22.429564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:22.429857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:23.149931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:23.150400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:23.150504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 12:00:23.150590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6179 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# <PrefetchDataset element_spec=(TensorSpec(shape=(512, 128, 160), dtype=tf.float32, name=None), TensorSpec(shape=(512, 2), dtype=tf.float32, name=None))>

# %% [markdown]
# ---
# # Create the neural network
#
# This approach uses a FPN (Feature-Pyramid-Network, https://jonathan-hui.medium.com/understanding-feature-pyramid-networks-for-object-detection-fpn-45b227b9106c) architecture, followed by LSTM and Dense regressor heads to extract the future gain information.
# The pyramid elements are built in a Res-Net style to provide a good information flow.
#
#
# Additionally, it is equipped with Attention layers to focus on relevant information. Futhermore, it uses antialiasing to smooth out disturbance.
#
#
# ```
# Todo: Create Image of network structure
# ```

# %%
# Create the CreateModelFPNWithAttention model
def CreateModelFPNWithAttention():
  # Define model parameters
  mp = {
      "NAME": "FPNWithAttentionBiggerTimebased",
      "VERSION": "2_FutureOnly_60days",
      "CNN_INITIAL_FILTERS": 64,
      "CNN_EXTRACTOR_LAYERS": 6,
      "CNN_INITIAL_KERNEL_SIZE": 2,
      "CNN_MAX_KERNEL_SIZE": 8,
      "FEATURE_PYRAMID_START_INDEX": 2,
      "HEAD_LSTM_SIZE": 64,
      "HEAD_DENSE_SIZE": 32
      }
  
  # Create the model input  
  inputTicksAndIndicators = Input(shape=(X_BLOCK_LENGHT, FEATURES), name='inputTicksAndIndicators', dtype='float32')

  # Apply dropout on the input to make the model robust
  inputTicksAndIndicators = Dropout(0.1, name='inputDropout')(inputTicksAndIndicators)

  # Normalize the input data, as it has a wide value spread (range of 1e8)
  normalized = UnitNormalization(name="UnitNormalizationInput", axis=-2)(inputTicksAndIndicators)

  # ----------------------------------------------------------------------------

  # A 1D-CNN pyramid is used to extract higher-level features out of the time dimension
  conv_layers = []
  aligned_layers = []
  feature_map_layers = []
  anti_aliased_layers = []
  anti_aliased_pyramid_indices = []
  regressor_layers = []

  finalFilters = mp["CNN_INITIAL_FILTERS"] * 2**(mp["FEATURE_PYRAMID_START_INDEX"])
  print(finalFilters) 

  for i in range(mp["CNN_EXTRACTOR_LAYERS"]):
    if 0 == i:
      source_layer = normalized
    else:
      source_layer = feature_conv
    
    filters = int(mp["CNN_INITIAL_FILTERS"]*(2**i))
    kernel_size = mp["CNN_INITIAL_KERNEL_SIZE"]*(2**i)
    kernel_size = int(np.min([mp["CNN_MAX_KERNEL_SIZE"], kernel_size]))
    strides = int(np.min([2,kernel_size]))

    print(f"Step {i}, using {filters} filters with a kernel size of {kernel_size} at strides of {strides}")

    # Create the feature extraction convolution
    res_net_element = Conv1D(filters=source_layer.shape[-1],
                          kernel_size=kernel_size,
                          strides=1, 
                          padding="same",
                          name=f"ResNet_{i}_Conv1D_1")(source_layer)
    
    res_net_element = Activation("relu",
                              name=f"ResNet_{i}_ReLU")(res_net_element)
    
    res_net_element = Conv1D(filters=source_layer.shape[-1],
                          kernel_size=kernel_size,
                          strides=1, 
                          padding="same",
                          name=f"ResNet_{i}_Conv1D_2")(res_net_element)
    
    res_net_element = Add(name=f"ResNet_{i}_Add")([res_net_element, source_layer])
        
    feature_conv = Conv1D(filters=filters,
                          kernel_size=kernel_size,
                          strides=strides, 
                          padding="same",
                          name=f"ResNet_{i}_Feature_Conv1D_FilterDimReduction")(res_net_element)

    attention_map = Attention(name=f"Attention_Layer_{i}")([feature_conv,feature_conv])
    print(f"attention_map.shape: {attention_map.shape}")

    feature_conv_attentioned = Multiply(name=f"Multiply_Apply_Attention_{i}")([feature_conv, attention_map])
    print(f"feature_conv_attentioned.shape: {feature_conv_attentioned.shape}")
    
    conv_layers.append(feature_conv_attentioned)

    # Apply the feature extraction pyramid
    if mp["FEATURE_PYRAMID_START_INDEX"] <= i:
      # Apply a 1x1 convolution to align the channel depth    
      if feature_conv_attentioned.shape[-1] != finalFilters:
        aligned_layer = Conv1D(filters=finalFilters,
                              kernel_size=1,
                              strides=1,
                              padding="same",
                              name=f"Channel_Depth_Alignment_{i}")(feature_conv_attentioned)
      else:
        aligned_layer = feature_conv_attentioned
      
      aligned_layers.append(aligned_layer)

  # Go top-down through the aligned_layers to create the feature_map_layers
  for i in range(mp["CNN_EXTRACTOR_LAYERS"]-1, mp["FEATURE_PYRAMID_START_INDEX"]-1, -1):
    aligned_layers_index = i - mp["FEATURE_PYRAMID_START_INDEX"]
    aligned_layer = aligned_layers[aligned_layers_index]

    print(f"Building feature_map_layers, step {i}. Shape of aligned_layer: {aligned_layer.shape}")

    # The highest-filtered layer is taken as feature map directly
    if i == mp["CNN_EXTRACTOR_LAYERS"]-1:
      feature_map_layers.append(aligned_layer)
      anti_aliased_layers.append(feature_map_layers[-1])
    else:
      # Take the last feature_map_layer and scale it by two
      upsampled = UpSampling1D(size=2,
                               name=f"Pyramid_Upsampling_{i}")(feature_map_layers[-1])

      # Add the aligned_layer
      added = Add(name=f"Pyramid_Add_{i}")([upsampled, aligned_layer])

      # Append as new feature_map_layer
      feature_map_layers.append(added)

      # Apply a convolution with a kernel size of 3 to "reduce the aliasing effect"
      anti_aliased_layer = Conv1D(filters=feature_map_layers[-1].shape[-1],
                                  kernel_size=3,
                                  strides=1,
                                  padding="same",
                                  name=f"Anti_Alias_{i}")(feature_map_layers[-1])

      anti_aliased_layers.append(anti_aliased_layer)

    # Helper storage to keep pyramid index consistent, also in predictor/regressor
    anti_aliased_pyramid_indices.append(i)

  # Apply the predictor head to each feature dimension layer
  for n in range(len(anti_aliased_layers)):
    predictor_input = anti_aliased_layers[n]

    # Get the pyramid index
    pyramid_index = anti_aliased_pyramid_indices[n]

    # Permute the Conv output back
    predictor_input = Permute((2, 1), name=f"PermutePredictorInput_{pyramid_index}")(predictor_input)

    predictor = LSTM(units=mp["HEAD_LSTM_SIZE"],
                     name=f"Predictor_Head_{pyramid_index}_LSTM")(predictor_input)
    
    # Direction and derivation regressor
    regressor = Dense(units=mp["HEAD_DENSE_SIZE"],
                      name=f"Predictor_Head_{pyramid_index}_Dense_Regressor",
                      activation='relu')(predictor)
    
    regressor_layers.append(regressor)
  
  # Add all regressors together
  regressor_conced = Concatenate(name="Concatenate_regressors")(regressor_layers)
  #regressor_conced = Dense(regressor_conced.shape[1], name="Combined_Regressor_1")(regressor_conced)
  #regressor_conced = Dense(regressor_conced.shape[1], name="Combined_Regressor_2")(regressor_conced)

  # The output are two values (direction and derivation) in the range [-1.0, 1.0]
  output = Dense(2, activation="tanh", name="Output")(regressor_conced)
  outputs = [output]

  # Combine it all into a model object
  model = Model(inputs=inputTicksAndIndicators, outputs=outputs, name=mp["NAME"] + "_" + str(mp["VERSION"]))

  return model, mp

model, model_config = CreateModelFPNWithAttention()
print(model_config)
model.summary(line_length=220)
# Out:
# 256
# Step 0, using 64 filters with a kernel size of 2 at strides of 2
# attention_map.shape: (None, 64, 64)
# feature_conv_attentioned.shape: (None, 64, 64)
# Step 1, using 128 filters with a kernel size of 4 at strides of 2
# attention_map.shape: (None, 32, 128)
# feature_conv_attentioned.shape: (None, 32, 128)
# Step 2, using 256 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 16, 256)
# feature_conv_attentioned.shape: (None, 16, 256)
# Step 3, using 512 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 8, 512)
# feature_conv_attentioned.shape: (None, 8, 512)
# Step 4, using 1024 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 4, 1024)
# feature_conv_attentioned.shape: (None, 4, 1024)
# Step 5, using 2048 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 2, 2048)
# feature_conv_attentioned.shape: (None, 2, 2048)
# Building feature_map_layers, step 5. Shape of aligned_layer: (None, 2, 256)
# Building feature_map_layers, step 4. Shape of aligned_layer: (None, 4, 256)
# Building feature_map_layers, step 3. Shape of aligned_layer: (None, 8, 256)
# Building feature_map_layers, step 2. Shape of aligned_layer: (None, 16, 256)
# {'NAME': 'FPNWithAttentionBiggerTimebased', 'VERSION': '2_FutureOnly_60days', 'CNN_INITIAL_FILTERS': 64, 'CNN_EXTRACTOR_LAYERS': 6, 'CNN_INITIAL_KERNEL_SIZE': 2, 'CNN_MAX_KERNEL_SIZE': 8, 'FEATURE_PYRAMID_START_INDEX': 2, 'HEAD_LSTM_SIZE': 64, 'HEAD_DENSE_SIZE': 32}
# Model: "FPNWithAttentionBiggerTimebased_2_FutureOnly_60days"
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                           Output Shape                                     Param #                   Connected to
# ============================================================================================================================================================================================================================
#  input_1 (InputLayer)                                                   [(None, 128, 160)]                               0                         []
#
#  UnitNormalizationInput (UnitNormalization)                             (None, 128, 160)                                 0                         ['input_1[0][0]']
#
#  ResNet_0_Conv1D_1 (Conv1D)                                             (None, 128, 160)                                 51360                     ['UnitNormalizationInput[1][0]']
#
#  ResNet_0_ReLU (Activation)                                             (None, 128, 160)                                 0                         ['ResNet_0_Conv1D_1[1][0]']
#
#  ResNet_0_Conv1D_2 (Conv1D)                                             (None, 128, 160)                                 51360                     ['ResNet_0_ReLU[1][0]']
#
#  ResNet_0_Add (Add)                                                     (None, 128, 160)                                 0                         ['ResNet_0_Conv1D_2[1][0]',
#                                                                                                                                                     'UnitNormalizationInput[1][0]']
#
#  ResNet_0_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 64, 64)                                   20544                     ['ResNet_0_Add[1][0]']
#
#  ResNet_1_Conv1D_1 (Conv1D)                                             (None, 64, 64)                                   16448                     ['ResNet_0_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_1_ReLU (Activation)                                             (None, 64, 64)                                   0                         ['ResNet_1_Conv1D_1[1][0]']
#
#  ResNet_1_Conv1D_2 (Conv1D)                                             (None, 64, 64)                                   16448                     ['ResNet_1_ReLU[1][0]']
#
#  ResNet_1_Add (Add)                                                     (None, 64, 64)                                   0                         ['ResNet_1_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_0_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_1_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 32, 128)                                  32896                     ['ResNet_1_Add[1][0]']
#
#  ResNet_2_Conv1D_1 (Conv1D)                                             (None, 32, 128)                                  131200                    ['ResNet_1_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_2_ReLU (Activation)                                             (None, 32, 128)                                  0                         ['ResNet_2_Conv1D_1[1][0]']
#
#  ResNet_2_Conv1D_2 (Conv1D)                                             (None, 32, 128)                                  131200                    ['ResNet_2_ReLU[1][0]']
#
#  ResNet_2_Add (Add)                                                     (None, 32, 128)                                  0                         ['ResNet_2_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_1_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_2_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 16, 256)                                  262400                    ['ResNet_2_Add[1][0]']
#
#  ResNet_3_Conv1D_1 (Conv1D)                                             (None, 16, 256)                                  524544                    ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_3_ReLU (Activation)                                             (None, 16, 256)                                  0                         ['ResNet_3_Conv1D_1[1][0]']
#
#  ResNet_3_Conv1D_2 (Conv1D)                                             (None, 16, 256)                                  524544                    ['ResNet_3_ReLU[1][0]']
#
#  ResNet_3_Add (Add)                                                     (None, 16, 256)                                  0                         ['ResNet_3_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_3_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 8, 512)                                   1049088                   ['ResNet_3_Add[1][0]']
#
#  ResNet_4_Conv1D_1 (Conv1D)                                             (None, 8, 512)                                   2097664                   ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_4_ReLU (Activation)                                             (None, 8, 512)                                   0                         ['ResNet_4_Conv1D_1[1][0]']
#
#  ResNet_4_Conv1D_2 (Conv1D)                                             (None, 8, 512)                                   2097664                   ['ResNet_4_ReLU[1][0]']
#
#  ResNet_4_Add (Add)                                                     (None, 8, 512)                                   0                         ['ResNet_4_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_4_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 4, 1024)                                  4195328                   ['ResNet_4_Add[1][0]']
#
#  ResNet_5_Conv1D_1 (Conv1D)                                             (None, 4, 1024)                                  8389632                   ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_5_ReLU (Activation)                                             (None, 4, 1024)                                  0                         ['ResNet_5_Conv1D_1[1][0]']
#
#  ResNet_5_Conv1D_2 (Conv1D)                                             (None, 4, 1024)                                  8389632                   ['ResNet_5_ReLU[1][0]']
#
#  ResNet_5_Add (Add)                                                     (None, 4, 1024)                                  0                         ['ResNet_5_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_5_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 2, 2048)                                  16779264                  ['ResNet_5_Add[1][0]']
#
#  Attention_Layer_5 (Attention)                                          (None, 2, 2048)                                  0                         ['ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Multiply_Apply_Attention_5 (Multiply)                                  (None, 2, 2048)                                  0                         ['ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_5[1][0]']
#
#  Attention_Layer_4 (Attention)                                          (None, 4, 1024)                                  0                         ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Channel_Depth_Alignment_5 (Conv1D)                                     (None, 2, 256)                                   524544                    ['Multiply_Apply_Attention_5[1][0]']
#
#  Multiply_Apply_Attention_4 (Multiply)                                  (None, 4, 1024)                                  0                         ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_4[1][0]']
#
#  Pyramid_Upsampling_4 (UpSampling1D)                                    (None, 4, 256)                                   0                         ['Channel_Depth_Alignment_5[1][0]']
#
#  Channel_Depth_Alignment_4 (Conv1D)                                     (None, 4, 256)                                   262400                    ['Multiply_Apply_Attention_4[1][0]']
#
#  Attention_Layer_3 (Attention)                                          (None, 8, 512)                                   0                         ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Pyramid_Add_4 (Add)                                                    (None, 4, 256)                                   0                         ['Pyramid_Upsampling_4[1][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_4[1][0]']
#
#  Multiply_Apply_Attention_3 (Multiply)                                  (None, 8, 512)                                   0                         ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_3[1][0]']
#
#  Pyramid_Upsampling_3 (UpSampling1D)                                    (None, 8, 256)                                   0                         ['Pyramid_Add_4[1][0]']
#
#  Channel_Depth_Alignment_3 (Conv1D)                                     (None, 8, 256)                                   131328                    ['Multiply_Apply_Attention_3[1][0]']
#
#  Pyramid_Add_3 (Add)                                                    (None, 8, 256)                                   0                         ['Pyramid_Upsampling_3[1][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_3[1][0]']
#
#  Attention_Layer_2 (Attention)                                          (None, 16, 256)                                  0                         ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Pyramid_Upsampling_2 (UpSampling1D)                                    (None, 16, 256)                                  0                         ['Pyramid_Add_3[1][0]']
#
#  Multiply_Apply_Attention_2 (Multiply)                                  (None, 16, 256)                                  0                         ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_2[1][0]']
#
#  Pyramid_Add_2 (Add)                                                    (None, 16, 256)                                  0                         ['Pyramid_Upsampling_2[1][0]',
#                                                                                                                                                     'Multiply_Apply_Attention_2[1][0]']
#
#  Anti_Alias_4 (Conv1D)                                                  (None, 4, 256)                                   196864                    ['Pyramid_Add_4[1][0]']
#
#  Anti_Alias_3 (Conv1D)                                                  (None, 8, 256)                                   196864                    ['Pyramid_Add_3[1][0]']
#
#  Anti_Alias_2 (Conv1D)                                                  (None, 16, 256)                                  196864                    ['Pyramid_Add_2[1][0]']
#
#  PermutePredictorInput_5 (Permute)                                      (None, 256, 2)                                   0                         ['Channel_Depth_Alignment_5[1][0]']
#
#  PermutePredictorInput_4 (Permute)                                      (None, 256, 4)                                   0                         ['Anti_Alias_4[1][0]']
#
#  PermutePredictorInput_3 (Permute)                                      (None, 256, 8)                                   0                         ['Anti_Alias_3[1][0]']
#
#  PermutePredictorInput_2 (Permute)                                      (None, 256, 16)                                  0                         ['Anti_Alias_2[1][0]']
#
#  Predictor_Head_5_LSTM (LSTM)                                           (None, 64)                                       17152                     ['PermutePredictorInput_5[1][0]']
#
#  Predictor_Head_4_LSTM (LSTM)                                           (None, 64)                                       17664                     ['PermutePredictorInput_4[1][0]']
#
#  Predictor_Head_3_LSTM (LSTM)                                           (None, 64)                                       18688                     ['PermutePredictorInput_3[1][0]']
#
#  Predictor_Head_2_LSTM (LSTM)                                           (None, 64)                                       20736                     ['PermutePredictorInput_2[1][0]']
#
#  Predictor_Head_5_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_5_LSTM[1][0]']
#
#  Predictor_Head_4_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_4_LSTM[1][0]']
#
#  Predictor_Head_3_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_3_LSTM[1][0]']
#
#  Predictor_Head_2_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_2_LSTM[1][0]']
#
#  Concatenate_regressors (Concatenate)                                   (None, 128)                                      0                         ['Predictor_Head_5_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_4_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_3_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_2_Dense_Regressor[1][0]']
#
#  Output (Dense)                                                         (None, 2)                                        258                       ['Concatenate_regressors[1][0]']
#
# ============================================================================================================================================================================================================================
# Total params: 46,352,898
# Trainable params: 46,352,898
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # Train the model

# %%
# Define the checkpoint name for storing training progress
CHKPNT_NAME = f"{model.name}_GPU_{X_BLOCK_LENGHT}LB"
CHKPNT_NAME
# Out:
# 'FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB'

# %%
# Set an optimizer
optimizer = Adam(
    learning_rate=1e-03,
    epsilon=1e-06,
    beta_1=0.9,
    beta_2=0.98,
    decay=0.01)

# %%
# Compile the model
model.compile(
    optimizer = optimizer,
    loss = ["mse"], 
    metrics=["mae"])

# %%
#@title CustomCallback
# This method stores the model weights every `save_freq` batches, or at least at the epoch's end

class CustomCallback(tf.keras.callbacks.Callback):
  def __init__(self, save_freq, val_freq, checkpoint_path, model_name, epoch_add=0):
    self.save_freq = save_freq
    self.val_freq = val_freq
    self.checkpoint_path = checkpoint_path
    self.model_name = model_name
    self.current_epoch = 0
    self.epoch_add = epoch_add

  def on_epoch_begin(self, epoch, logs=None):
    self.current_epoch = epoch + self.epoch_add
    # keys = list(logs.keys())
    # print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

  def on_epoch_end(self, epoch, logs=None):
    self.saveTheModel(-1, logs)

  def on_train_batch_end(self, batch, logs=None):
    self.saveTheModel(batch, logs)

  def saveTheModel(self, batch, logs=None):
    if (0 < batch and 0 == batch % self.save_freq) or (0 > batch):
      logging.info(str(datetime.datetime.utcnow()))
    
      if 0 > batch:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_end".format(self.current_epoch)
                                    )
      else:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_{:05d}".format(self.current_epoch, batch)
                                    )
      
      fp = os.path.join(_save_folder, "model.h5")
      model.save(fp)
      logging.info(f"Saved model to '{fp}'")
      
      # Save optimizer config
      # c = copy.deepcopy(self.model.optimizer.get_config())

#       fp = os.path.join(_save_folder, "c.pickle")
#       with file_io.FileIO(fp, mode='wb+') as handle:
#         pickle.dump(self.model.optimizer.get_config(), handle, protocol=pickle.HIGHEST_PROTOCOL)
        
#       logging.info(f"Saved optimizer config to '{fp}'")

#       # Save optimizer weights
#       # w = copy.deepcopy(self.model.optimizer.get_weights())

#       fp = os.path.join(_save_folder, "w.pickle")
#       with open(fp, "wb") as handle:
#         # with file_io.FileIO(fp, mode='wb+') as handle:
#         pickle.dump(self.model.optimizer.get_weights(), handle, protocol=pickle.HIGHEST_PROTOCOL)
      
#       logging.info(f"Saved optimizer weights to '{fp}'")
        
      logging.info(f"Did a gc collect: {gc.collect()}")

    # if 0 < batch and 0 == batch % self.val_freq:
    #   print("-------------------------EVAL-------------------------")
    #   model.evaluate(tfgenTest)
    #   print("\n-------------------------EVAL-------------------------")

# %%
# If the training is resumed from a previous checkpoint, these epochs can be added to keep model saving consistent
epoch_add = 0

# %%
# Define how often the model shall be saved
CALLBACK_EVERY_N_BATCHES = 2000

# %%
# Create the custom callback
cc = CustomCallback(checkpoint_path = CHECKPOINT_PATH,
                    model_name = CHKPNT_NAME,
                    save_freq = CALLBACK_EVERY_N_BATCHES,
                    val_freq = CALLBACK_EVERY_N_BATCHES,
                    epoch_add = epoch_add)

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Todo: Create more elegant solution
log_dir = "gs://ticks_with_indicators_with_volume/logs/TPU/" + CHKPNT_NAME + "_" + datetime.datetime.now().strftime("%Y%m%d%H%M%S")

if not COLAB:
    log_dir = os.path.join("/content/CryptoCrystalBall/Data/logs",log_dir.split("/")[-1])

log_dir
# Out:
# '/content/CryptoCrystalBall/Data/logs/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB_20230403120024'

# %%
# Create a TensorBoard callback for moniting the training progress
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    update_freq=CALLBACK_EVERY_N_BATCHES,
    profile_batch=(5,100)
    )
# Out:
# 2023-04-03 12:00:24.421748: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-04-03 12:00:24.421773: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-04-03 12:00:24.422475: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2023-04-03 12:00:24.422731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory
# 2023-04-03 12:00:24.519685: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-04-03 12:00:24.519794: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed

# %%
# Load previous weights if necessary
MODEL_PATH = "/content/CryptoCrystalBall/Notebooks/etf_pastfuture_based/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB/cp_daily_valid_05_end/model.h5"

model.load_weights(MODEL_PATH)

# %%
Todo important: CustomCallback has to set MODEL_PATH (i think for test and eval saving)
# Out:
#   Cell In[42], line 1
#     Todo important: CustomCallback has to set MODEL_PATH
#          ^
# SyntaxError: invalid syntax

# %%
# Activate the TensorBoard
# %tensorboard --logdir $log_dir --host 0.0.0.0 --port 6006

# %%
stop

# %% [markdown]
# # Start training

# %%
# Train for one epoch on a higher learning rate to get the model going
model.fit(tfGenTraining,
          epochs=1,
          verbose = 1,
          callbacks=[tensorboard_callback, cc])
# Out:
# INFO:root:File 'IE00B6X2VY59.csv' loaded, 531 left
# INFO:root:File 'IE00BYXVGZ48.csv' loaded, 530 left
# INFO:root:File 'DE000A0F5UF5.csv' loaded, 529 left
# INFO:root:File 'DE000ETFL441.csv' loaded, 528 left
# INFO:root:File 'LU1781541179.csv' loaded, 527 left
# INFO:root:File 'LU1650487926.csv' loaded, 526 left
# INFO:root:File 'LU1285960032.csv' loaded, 525 left
# INFO:root:File 'IE00B1FZSD53.csv' loaded, 524 left
# 2023-03-30 17:49:24.318585: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8700
# INFO:root:File 'IE00B5KQNG97.csv' loaded, 523 left
# 2023-03-30 17:49:25.450671: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:root:File 'IE00BYM31M36.csv' loaded, 522 left
# INFO:root:File 'LU2082996542.csv' loaded, 521 left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Train for one epoch on a higher learning rate to get the model going
# ----> 2 model.fit(tfGenTraining,
#       3           epochs=1,
#       4           verbose = 1,
#       5           callbacks=[tensorboard_callback, cc])
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# Decrease the learning rate to avoid overshooting
model.optimizer.learning_rate = 5e-6
logging.info(f"Decreased learning rate: {model.optimizer.learning_rate.numpy()}")

# %%
# Create a new CustomCallback with 1 epoch added to the logging file name
epoch_add = 1

cc = CustomCallback(checkpoint_path = CHECKPOINT_PATH,
                    model_name = CHKPNT_NAME,
                    save_freq = CALLBACK_EVERY_N_BATCHES,
                    val_freq = CALLBACK_EVERY_N_BATCHES,
                    epoch_add = epoch_add)

# %%
# Train further on with the reduced learning rate
model.fit(tfGenTraining,
          epochs=5,
          verbose = 1,
          callbacks=[tensorboard_callback, cc])

# %% [markdown]
# # Use the model to predict the future

# %%
# Create a generator for prediction
# Todo: Use same method as for training to avoid different settings

def pythonGeneratorPrediction(fileList):
  # Initialize the FileListToDataStream generator
  dataStream= DataStreamCreator.FileListToDataStream(fileList = fileList,
                                                     batch_size = BATCH_SIZE,
                                                     X_Block_lenght = X_BLOCK_LENGHT,
                                                     y_type_dict=Y_TYPE_DICT,
                                                     shuffle=False,
                                                     parallel_generators = 1,
                                                     random_seed = RANDOM_SEED,
                                                     **DATA_STREAM_PARAMETERS
                                                    )
  
  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStream)
      _X = ne['X']
      _y = _y = ne['y']
    
      # Limit the y signal to avoid excess
      _y /= 10.0
      _y = np.clip(_y, -10.0, 10.0)

      yield (_X, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
# Load a file to visualize the prediction results
FILE_FOR_VISUALIZATION = TEST_FILES[4]
FILE_FOR_VISUALIZATION
# Out:
# '/content/dataset/ETF/tickdata/ticks/IE00BYSZ5T81.csv'

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
tfGenPrediction = tf.data.Dataset.from_generator(lambda: pythonGeneratorPrediction(fileList=[FILE_FOR_VISUALIZATION]), 
                                               output_types = (tf.float32, tf.float32),
                                               output_shapes=(
                                                   (BATCH_SIZE, X_BLOCK_LENGHT, FEATURES),
                                                   (BATCH_SIZE, 4)
                                                   )
                                               )
tfGenPrediction
# Out:
# <FlatMapDataset element_spec=(TensorSpec(shape=(512, 128, 160), dtype=tf.float32, name=None), TensorSpec(shape=(512, 4), dtype=tf.float32, name=None))>

# %%
# Predict something
p = model.predict(tfGenPrediction)
p *= 10.0
p.shape
# Out:
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
#       4/Unknown - 3s 154ms/step
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# 4/4 [==============================] - 3s 190ms/step
# (2048, 2)

# %%
# Store the prediction results in nicely named variables
p_future = p[:,0]
p_future_derivation = p[:,1]

# %%
# Helper method to get the gain data from the past using the generator
def getPastDataFromGen(genIn, predictedShapeIn):
    it = genIn.as_numpy_iterator()

    y_past_data = np.empty((predictedShapeIn[0], 2))
    i = 0

    try:
        while (ne := next(it)):
            y_past_data[i:i+ne[1].shape[0],0] = ne[1][:,0]
            y_past_data[i:i+ne[1].shape[0],1] = ne[1][:,2]

            i += ne[1].shape[0]

    except StopIteration:
        pass

    return y_past_data
    
y_past_data = getPastDataFromGen(tfGenPrediction, p.shape)
y_past_data.shape
# Out:
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# (2048, 2)

# %%
# Todo: Improve plotting of the results

# %%
plt.plot(y_past_data[:,0])

# %%
plt.plot(y_past_data[:,1])

# %%
plt.plot(p_future)

# %%
plt.plot(p_future_derivation)

# %% [markdown]
# # Add the predictions to the tick table to visualize them

# %%
# Load the table
tickDF = pd.read_csv(FILE_FOR_VISUALIZATION)
tickDF
# Out:
#         startsAt   open   high    low  close  volume  quoteVolume
# 0     1455667200  26.94  26.94  26.94  26.94     0.0          0.0
# 1     1455753600  27.16  27.16  27.16  27.16     0.0          0.0
# 2     1455840000  27.17  27.17  27.17  27.17     0.0          0.0
# 3     1455926400  27.17  27.17  27.17  27.17     0.0          0.0
# 4     1456012800  27.17  27.17  27.17  27.17     0.0          0.0
# ...          ...    ...    ...    ...    ...     ...          ...
# 2560  1676851200  27.66  27.66  27.66  27.66     0.0          0.0
# 2561  1676937600  27.39  27.39  27.39  27.39     0.0          0.0
# 2562  1677024000  27.49  27.49  27.49  27.49     0.0          0.0
# 2563  1677110400  27.66  27.66  27.66  27.66     0.0          0.0
# 2564  1677196800  27.66  27.66  27.66  27.66     0.0          0.0
#
# [2565 rows x 7 columns]

# %%
# Because the data is cropped in the batching process (Todo: fix this) and can also not be used fully due to the X-Block and y-data creation,
# the loaded DF has a bigger shape
tickDF.shape[0] - p.shape[0]
# Out:
# 517

# %%
# Crop the DF to meet the prediction
tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
tickDFcropped
# Out:
#         startsAt   open   high    low  close  volume  quoteVolume
# 517   1500336000  25.87  25.87  25.87  25.87     0.0          0.0
# 518   1500422400  25.91  25.91  25.91  25.91     0.0          0.0
# 519   1500508800  26.02  26.02  26.02  26.02     0.0          0.0
# 520   1500595200  25.74  25.74  25.74  25.74     0.0          0.0
# 521   1500681600  25.74  25.74  25.74  25.74     0.0          0.0
# ...          ...    ...    ...    ...    ...     ...          ...
# 2560  1676851200  27.66  27.66  27.66  27.66     0.0          0.0
# 2561  1676937600  27.39  27.39  27.39  27.39     0.0          0.0
# 2562  1677024000  27.49  27.49  27.49  27.49     0.0          0.0
# 2563  1677110400  27.66  27.66  27.66  27.66     0.0          0.0
# 2564  1677196800  27.66  27.66  27.66  27.66     0.0          0.0
#
# [2048 rows x 7 columns]

# %%
# Plot the prediction again, now over the open price
chart_name="Predicted direction of price movement with open price"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name, fontsize=14)

_ = ax1.plot(p_future, color="green", label="Predicted p_future")
_ = ax1.plot(p_future_derivation, color="red", label="Predicted p_future_derivation")
# _ = ax1.plot(p_neutral, color="gray", label="Predicted neutral")

ax2 = ax1.twinx()

ax2.plot(tickDFcropped.loc[:,'open'].values, color="black", label="Price")

ax1.set_xlabel("Timesteps")
ax1.set_ylabel("Direction")
ax2.set_ylabel("Price")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc="upper left")

# Save the figure
# fig_name = "FileListToDataStreamExample_" + chart_name.replace(" ", "_").replace("'", "").replace("(", "").replace(")", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")

# %%
#@title Buy and sell signal thresholds
BUY_SIGNAL_THRESHOLD_FUTURE = 0.15 #@param {type:"number"}
BUY_SIGNAL_THRESHOLD_PAST = 0.01 #@param {type:"number"}

SELL_SIGNAL_THRESHOLD_PAST = 0.1 #@param {type:"number"}

# %%
#@title Plot buy and sell signals
chart_name="Buy and sell signals"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name)

x_datetimes = [datetime.datetime.fromtimestamp(ts) for ts in tickDFcropped.loc[:,'open'].index]

_ = ax1.plot(x_datetimes, tickDFcropped.loc[:,'open'].values, color="black", label="Price", linewidth=2)

# Color area axis
ax2 = ax1.twinx()

# Convert the float value prediction into rising and falling categories
yCategoryFall = p_future_gain <= SELL_SIGNAL_THRESHOLD_PAST
yCategoryRise = (p_future_gain > p_past_gain) & (p_past_gain <= BUY_SIGNAL_THRESHOLD_FUTURE) #(p_future_gain >= BUY_SIGNAL_THRESHOLD_FUTURE)

ax2.fill_between(x_datetimes, yCategoryFall , alpha=0.5, color="red", label="'Buy' signal")
ax2.fill_between(x_datetimes, yCategoryRise , alpha=0.5, color="green", label="'Sell' signal")

# Remove tick marks and set limits for color area axis
ax2.set_yticks([])
ax2.set_ylim(-0.05,1.05)

ax3 = ax1.twinx()
_ = ax3.plot(x_datetimes, p_future_gain, color="blue", label="Predicted future gain")
# _ = ax3.plot(x_datetimes, 10.0*p_dir_derivation, color="red", label="10.0 * Predicted price direction derivation")
# ax3.set_ylim(-1.05,1.05)

ax3.plot([np.min(x_datetimes), np.max(x_datetimes)], [0.0,0.0], color="gray")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax2.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc="upper left")

# Save the figure
# fig_name = chart_name.replace(" ", "_").replace("'", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 14
#      11 ax2 = ax1.twinx()
#      13 # Convert the float value prediction into rising and falling categories
# ---> 14 yCategoryFall = p_past_gain >= SELL_SIGNAL_THRESHOLD_PAST
#      15 yCategoryRise = (p_future_gain > p_past_gain) & (p_past_gain <= BUY_SIGNAL_THRESHOLD_FUTURE) #(p_future_gain >= BUY_SIGNAL_THRESHOLD_FUTURE)
#      17 ax2.fill_between(x_datetimes, yCategoryFall , alpha=0.5, color="red", label="'Buy' signal")
#
# NameError: name 'p_past_gain' is not defined

# %% [markdown]
# # Add predictions to tick tables
# # Predict the test and eval set
# The future information for these sets is predicted using the trained model, additionally the past gain info is acquired using the `FileListToDataStream` generator. It is then stored together with the tick information as .csv files, which then can be used to develop a trading strategy.
#
# ```
# Todo: Add link to finder notebooks
# ```

# %%
stop

# %%
# PREDICTED_SAVE_PATH = "/content/dataset/etffancy/PastFutureGainV2/test"

# %%
# Get the model name and the checkpoint name
model_name, checkpoint_name = tuple(MODEL_PATH.split(os.sep)[-3:-1])
print(f"model_name: '{model_name}'")
print(f"checkpoint_name: '{checkpoint_name}'")
# Out:
# model_name: 'FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB'
# checkpoint_name: 'cp_daily_valid_05_end'

# %%
# Replace the latest element in the DATASET_PATH with "predicted"
prediction_save_path = DATASET_PATH.split(os.sep)[:-1]
prediction_save_path += ["predicted"]

# Preserve the root symbol
if prediction_save_path[0] == "":
    prediction_save_path[0] = os.sep

# Add the model info to the path
prediction_save_path += [model_name, checkpoint_name]
    
prediction_save_path
# Out:
# ['/',
#  'content',
#  'dataset',
#  'ETF',
#  'tickdata',
#  'predicted',
#  'FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB',
#  'cp_daily_valid_05_end']

# %%
# Check each path element and create it if necessary
for i in range(1, len(prediction_save_path)):
    partial_path_string = os.path.join(*prediction_save_path[:i+1])

    if not os.path.exists(partial_path_string):
        os.mkdir(partial_path_string)
        
# Create the test and eval save folders
PREDICTION_SAVE_PATH_TEST = os.path.join(*(prediction_save_path + ["test"]))
if not os.path.exists(PREDICTION_SAVE_PATH_TEST):
    os.mkdir(PREDICTION_SAVE_PATH_TEST)

PREDICTION_SAVE_PATH_EVAL = os.path.join(*(prediction_save_path + ["eval"]))
if not os.path.exists(PREDICTION_SAVE_PATH_EVAL):
    os.mkdir(PREDICTION_SAVE_PATH_EVAL)

print(f"PREDICTION_SAVE_PATH_TEST: '{PREDICTION_SAVE_PATH_TEST}'")
print(f"PREDICTION_SAVE_PATH_EVAL: '{PREDICTION_SAVE_PATH_EVAL}'")
# Out:
# PREDICTION_SAVE_PATH_TEST: '/content/dataset/ETF/tickdata/predicted/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB/cp_daily_valid_05_end/test'
# PREDICTION_SAVE_PATH_EVAL: '/content/dataset/ETF/tickdata/predicted/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_128LB/cp_daily_valid_05_end/eval'

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
# https://stackoverflow.com/questions/52443273/how-do-you-send-arguments-to-a-generator-function-using-tf-data-dataset-from-gen

fileList = TEST_FILES
PREDICTED_SAVE_PATH = PREDICTION_SAVE_PATH_TEST

pd.options.mode.chained_assignment = None  # default='warn'

for file_index in tqdm(range(0, len(fileList))):
    try:
        filename = fileList[file_index]

        logging.info(f"\nFile name: '{filename}' for index {file_index}")

        tfGenPrediction = tf.data.Dataset.from_generator(lambda: pythonGeneratorPrediction(fileList=[filename]), 
                                                       output_types = (tf.float32, tf.float32),
                                                       output_shapes=(
                                                           (BATCH_SIZE, X_BLOCK_LENGHT, FEATURES),
                                                           (BATCH_SIZE, 4)
                                                           )
                                                       )
        p = model.predict(tfGenPrediction, verbose = 0)

        logging.info(f"p.shape: {p.shape}")

        p_future_gain = p[:,0]
        p_future_gain_derivation = p[:,1]
        
        # Load the tick table
        tickDF = pd.read_csv(filename)
        tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
        
        # Add the predicted future gain
        tickDFcropped.loc[:,"p_future_gain"] = p_future_gain
        tickDFcropped.loc[:,"p_future_gain_derivation"] = p_future_gain_derivation
        
        # Get the (known) past data
        y_past_data = getPastDataFromGen(tfGenPrediction, p.shape)

        # Add the past gain
        tickDFcropped.loc[:,"p_past_gain"] = y_past_data[:,0]
        tickDFcropped.loc[:,"p_past_gain_derivation"] = y_past_data[:,1]

        # Save the DF
        tickDFcropped.to_csv(os.path.join(PREDICTED_SAVE_PATH, filename.split(os.path.sep)[-1]))

        logging.info("Saved the predicted data.")
    except KeyboardInterrupt:
        raise
    except Exception as ex:
        logging.warning(str(ex))
# Out:
#   0%|                                                   | 0/266 [00:00<?, ?it/s]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1598688189.csv' for index 0
# INFO:root:File 'LU1598688189.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'LU1598688189.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   0%|▏                                          | 1/266 [00:07<32:22,  7.33s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B8CJW150.csv' for index 1
# INFO:root:File 'IE00B8CJW150.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8CJW150.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▎                                          | 2/266 [00:11<24:24,  5.55s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYYHSM20.csv' for index 2
# INFO:root:File 'IE00BYYHSM20.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYYHSM20.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▍                                          | 3/266 [00:14<18:44,  4.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMW42074.csv' for index 3
# INFO:root:File 'IE00BMW42074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BMW42074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▋                                          | 4/266 [00:15<13:55,  3.19s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYSZ5T81.csv' for index 4
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▊                                          | 5/266 [00:19<13:57,  3.21s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMDBMY19.csv' for index 5
# INFO:root:File 'IE00BMDBMY19.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|▉                                          | 6/266 [00:19<10:07,  2.34s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF11F565.csv' for index 6
# INFO:root:File 'IE00BF11F565.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF11F565.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▏                                         | 7/266 [00:22<10:36,  2.46s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B44CGS96.csv' for index 7
# INFO:root:File 'IE00B44CGS96.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B44CGS96.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▎                                         | 8/266 [00:27<13:47,  3.21s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKM4GZ66.csv' for index 8
# INFO:root:File 'IE00BKM4GZ66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKM4GZ66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▍                                         | 9/266 [00:31<14:52,  3.47s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010655712.csv' for index 9
# INFO:root:File 'FR0010655712.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'FR0010655712.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▌                                        | 10/266 [00:37<18:12,  4.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B8GKDB10.csv' for index 10
# INFO:root:File 'IE00B8GKDB10.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8GKDB10.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▋                                        | 11/266 [00:41<18:09,  4.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B1TXK627.csv' for index 11
# INFO:root:File 'IE00B1TXK627.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'IE00B1TXK627.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|█▉                                        | 12/266 [00:48<21:03,  4.97s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BLLZQ805.csv' for index 12
# INFO:root:File 'IE00BLLZQ805.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BLLZQ805.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██                                        | 13/266 [00:49<16:37,  3.94s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKWQ0J47.csv' for index 13
# INFO:root:File 'IE00BKWQ0J47.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKWQ0J47.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██▏                                       | 14/266 [00:53<16:16,  3.88s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B53L4X51.csv' for index 14
# INFO:root:File 'IE00B53L4X51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B53L4X51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▎                                       | 15/266 [00:59<18:22,  4.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BGYWT403.csv' for index 15
# INFO:root:File 'IE00BGYWT403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BGYWT403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▌                                       | 16/266 [01:01<15:27,  3.71s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5MJYX09.csv' for index 16
# INFO:root:File 'IE00B5MJYX09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MJYX09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▋                                       | 17/266 [01:07<17:54,  4.32s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYTH5S21.csv' for index 17
# INFO:root:File 'IE00BYTH5S21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|██▊                                       | 18/266 [01:07<13:16,  3.21s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1291109293.csv' for index 18
# INFO:root:File 'LU1291109293.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1291109293.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   7%|███                                       | 19/266 [01:10<13:16,  3.23s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BK72HJ67.csv' for index 19
# INFO:root:File 'IE00BK72HJ67.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BK72HJ67.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▏                                      | 20/266 [01:12<11:20,  2.77s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2082998837.csv' for index 20
# INFO:root:File 'LU2082998837.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2082998837.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▎                                      | 21/266 [01:14<09:51,  2.41s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDGV0415.csv' for index 21
# INFO:root:File 'IE00BDGV0415.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BDGV0415.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▍                                      | 22/266 [01:16<09:36,  2.36s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0629459743.csv' for index 22
# INFO:root:File 'LU0629459743.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'LU0629459743.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▋                                      | 23/266 [01:21<12:34,  3.11s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0950674332.csv' for index 23
# INFO:root:File 'LU0950674332.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU0950674332.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▊                                      | 24/266 [01:23<11:53,  2.95s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1829219556.csv' for index 24
# INFO:root:File 'LU1829219556.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'LU1829219556.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▉                                      | 25/266 [01:28<14:03,  3.50s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0007P4PBU1.csv' for index 25
# INFO:root:File 'IE0007P4PBU1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  10%|████                                      | 26/266 [01:29<10:22,  2.59s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0H08E0.csv' for index 26
# INFO:root:File 'DE000A0H08E0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:File 'DE000A0H08E0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  10%|████▎                                     | 27/266 [01:37<17:08,  4.30s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2233156749.csv' for index 27
# INFO:root:File 'LU2233156749.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2233156749.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▍                                     | 28/266 [01:39<13:49,  3.49s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B2QWDY88.csv' for index 28
# INFO:root:File 'IE00B2QWDY88.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B2QWDY88.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▌                                     | 29/266 [01:45<16:56,  4.29s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5NLX835.csv' for index 29
# INFO:root:File 'IE00B5NLX835.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5NLX835.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▋                                     | 30/266 [01:50<18:34,  4.72s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1940199711.csv' for index 30
# INFO:root:File 'LU1940199711.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'LU1940199711.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|████▉                                     | 31/266 [01:53<15:27,  3.94s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681039647.csv' for index 31
# INFO:root:File 'LU1681039647.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1681039647.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████                                     | 32/266 [01:58<17:25,  4.47s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1834983477.csv' for index 32
# INFO:root:File 'LU1834983477.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'LU1834983477.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████▏                                    | 33/266 [02:05<19:56,  5.13s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2037749822.csv' for index 33
# INFO:root:File 'LU2037749822.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'LU2037749822.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▎                                    | 34/266 [02:07<16:19,  4.22s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6QGFW01.csv' for index 34
# INFO:root:File 'IE00B6QGFW01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6QGFW01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▌                                    | 35/266 [02:12<16:53,  4.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0H08S0.csv' for index 35
# INFO:root:File 'DE000A0H08S0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:File 'DE000A0H08S0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|█████▋                                    | 36/266 [02:20<21:17,  5.55s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMDPBY65.csv' for index 36
# INFO:root:File 'IE00BMDPBY65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BMDPBY65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|█████▊                                    | 37/266 [02:22<16:41,  4.37s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETF9603.csv' for index 37
# INFO:root:File 'DE000ETF9603.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'DE000ETF9603.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|██████                                    | 38/266 [02:24<14:31,  3.82s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKWQ0K51.csv' for index 38
# INFO:root:File 'IE00BKWQ0K51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKWQ0K51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▏                                   | 39/266 [02:28<14:21,  3.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0392494562.csv' for index 39
# INFO:root:File 'LU0392494562.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0392494562.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▎                                   | 40/266 [02:34<16:36,  4.41s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0908501215.csv' for index 40
# INFO:root:File 'LU0908501215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'LU0908501215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▍                                   | 41/266 [02:38<16:23,  4.37s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYX2JD69.csv' for index 41
# INFO:root:File 'IE00BYX2JD69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYX2JD69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  16%|██████▋                                   | 42/266 [02:41<14:22,  3.85s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETFL318.csv' for index 42
# INFO:root:File 'DE000ETFL318.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'DE000ETFL318.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  16%|██████▊                                   | 43/266 [02:46<16:25,  4.42s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BLLZQS08.csv' for index 43
# INFO:root:File 'IE00BLLZQS08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BLLZQS08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|██████▉                                   | 44/266 [02:48<13:12,  3.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDZVH966.csv' for index 44
# INFO:root:File 'IE00BDZVH966.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BDZVH966.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████                                   | 45/266 [02:51<12:00,  3.26s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BGDQ0L74.csv' for index 45
# INFO:root:File 'IE00BGDQ0L74.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BGDQ0L74.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████▎                                  | 46/266 [02:53<10:44,  2.93s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B652H904.csv' for index 46
# INFO:root:File 'IE00B652H904.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B652H904.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▍                                  | 47/266 [02:58<12:44,  3.49s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0H0744.csv' for index 47
# INFO:root:File 'DE000A0H0744.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'DE000A0H0744.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▌                                  | 48/266 [03:04<16:22,  4.51s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0378434236.csv' for index 48
# INFO:root:File 'LU0378434236.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'LU0378434236.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▋                                  | 49/266 [03:10<18:00,  4.98s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1190417599.csv' for index 49
# INFO:root:File 'LU1190417599.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1190417599.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  19%|███████▉                                  | 50/266 [03:14<16:29,  4.58s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFXR5S54.csv' for index 50
# INFO:root:File 'IE00BFXR5S54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFXR5S54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  19%|████████                                  | 51/266 [03:16<13:53,  3.88s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE0005933980.csv' for index 51
# INFO:root:File 'DE0005933980.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE0005933980.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▏                                 | 52/266 [03:24<17:33,  4.92s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1048317025.csv' for index 52
# INFO:root:File 'LU1048317025.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1048317025.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▎                                 | 53/266 [03:28<16:19,  4.60s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2182388319.csv' for index 53
# INFO:root:File 'LU2182388319.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2182388319.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▌                                 | 54/266 [03:29<13:06,  3.71s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFNM3H51.csv' for index 54
# INFO:root:File 'IE00BFNM3H51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFNM3H51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▋                                 | 55/266 [03:31<11:29,  3.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDBRDM35.csv' for index 55
# INFO:root:File 'IE00BDBRDM35.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BDBRDM35.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▊                                 | 56/266 [03:34<10:42,  3.06s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDBRT036.csv' for index 56
# INFO:root:File 'IE00BDBRT036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BDBRT036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|█████████                                 | 57/266 [03:37<10:31,  3.02s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B42TW061.csv' for index 57
# INFO:root:File 'IE00B42TW061.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B42TW061.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▏                                | 58/266 [03:43<13:11,  3.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B0M63516.csv' for index 58
# INFO:root:File 'IE00B0M63516.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'IE00B0M63516.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▎                                | 59/266 [03:50<16:32,  4.79s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681040900.csv' for index 59
# INFO:root:File 'LU1681040900.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1681040900.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▍                                | 60/266 [03:53<15:12,  4.43s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1650492173.csv' for index 60
# INFO:root:File 'LU1650492173.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'LU1650492173.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▋                                | 61/266 [04:00<17:22,  5.09s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3VWMM18.csv' for index 61
# INFO:root:File 'IE00B3VWMM18.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VWMM18.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▊                                | 62/266 [04:06<17:57,  5.28s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6R51Z18.csv' for index 62
# INFO:root:File 'IE00B6R51Z18.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6R51Z18.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|█████████▉                                | 63/266 [04:10<17:24,  5.15s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B1YZSC51.csv' for index 63
# INFO:root:File 'IE00B1YZSC51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B1YZSC51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|██████████                                | 64/266 [04:17<18:32,  5.51s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B02KXM00.csv' for index 64
# INFO:root:File 'IE00B02KXM00.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'IE00B02KXM00.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|██████████▎                               | 65/266 [04:24<20:26,  6.10s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000VTOHNZ0.csv' for index 65
# INFO:root:File 'IE000VTOHNZ0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  25%|██████████▍                               | 66/266 [04:25<14:41,  4.41s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKSBGS44.csv' for index 66
# INFO:root:File 'IE00BKSBGS44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BKSBGS44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  25%|██████████▌                               | 67/266 [04:26<11:51,  3.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000FNVOB27.csv' for index 67
# INFO:root:File 'IE000FNVOB27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  26%|██████████▋                               | 68/266 [04:27<08:45,  2.66s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ0G8977.csv' for index 68
# INFO:root:File 'IE00BZ0G8977.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BZ0G8977.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  26%|██████████▉                               | 69/266 [04:30<09:20,  2.85s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3VWN393.csv' for index 69
# INFO:root:File 'IE00B3VWN393.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VWN393.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  26%|███████████                               | 70/266 [04:36<12:05,  3.70s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B43QJJ40.csv' for index 70
# INFO:root:File 'IE00B43QJJ40.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00B43QJJ40.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▏                              | 71/266 [04:38<10:53,  3.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B14X4S71.csv' for index 71
# INFO:root:File 'IE00B14X4S71.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'IE00B14X4S71.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▎                              | 72/266 [04:45<14:12,  4.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BQQP9H09.csv' for index 72
# INFO:root:File 'IE00BQQP9H09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BQQP9H09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▌                              | 73/266 [04:49<13:12,  4.11s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFNM3L97.csv' for index 73
# INFO:root:File 'IE00BFNM3L97.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFNM3L97.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  28%|███████████▋                              | 74/266 [04:51<11:20,  3.54s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681038599.csv' for index 74
# INFO:root:File 'LU1681038599.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU1681038599.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  28%|███████████▊                              | 75/266 [04:56<12:49,  4.03s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ0PKT83.csv' for index 75
# INFO:root:File 'IE00BZ0PKT83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BZ0PKT83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  29%|████████████                              | 76/266 [05:00<12:13,  3.86s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BQQP9G91.csv' for index 76
# INFO:root:File 'IE00BQQP9G91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BQQP9G91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  29%|████████████▏                             | 77/266 [05:03<11:53,  3.77s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000HJV1VH3.csv' for index 77
# INFO:root:File 'IE000HJV1VH3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  29%|████████████▎                             | 78/266 [05:04<08:46,  2.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZKHS06.csv' for index 78
# INFO:root:File 'IE00BHZKHS06.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00BHZKHS06.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  30%|████████████▍                             | 79/266 [05:08<09:50,  3.16s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWBXM724.csv' for index 79
# INFO:root:File 'IE00BWBXM724.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWBXM724.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  30%|████████████▋                             | 80/266 [05:11<10:06,  3.26s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKWQ0H23.csv' for index 80
# INFO:root:File 'IE00BKWQ0H23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKWQ0H23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  30%|████████████▊                             | 81/266 [05:15<10:28,  3.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1048313891.csv' for index 81
# INFO:root:File 'LU1048313891.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1048313891.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  31%|████████████▉                             | 82/266 [05:19<10:42,  3.49s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010429068.csv' for index 82
# INFO:root:File 'FR0010429068.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'FR0010429068.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  31%|█████████████                             | 83/266 [05:25<13:25,  4.40s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BCBJG560.csv' for index 83
# INFO:root:File 'IE00BCBJG560.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00BCBJG560.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▎                            | 84/266 [05:29<13:05,  4.31s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0629460832.csv' for index 84
# INFO:root:File 'LU0629460832.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'LU0629460832.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▍                            | 85/266 [05:34<13:30,  4.48s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETF9082.csv' for index 85
# INFO:root:File 'DE000ETF9082.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'DE000ETF9082.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▌                            | 86/266 [05:37<12:08,  4.05s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0008471009.csv' for index 86
# INFO:root:File 'IE0008471009.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:File 'IE0008471009.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|█████████████▋                            | 87/266 [05:46<16:36,  5.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYSX4176.csv' for index 87
# INFO:root:File 'IE00BYSX4176.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BYSX4176.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|█████████████▉                            | 88/266 [05:48<13:19,  4.49s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2090063160.csv' for index 88
# INFO:root:File 'LU2090063160.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2090063160.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|██████████████                            | 89/266 [05:50<10:42,  3.63s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1589349734.csv' for index 89
# INFO:root:File 'LU1589349734.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1589349734.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▏                           | 90/266 [05:53<09:52,  3.37s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B7LW6Y90.csv' for index 90
# INFO:root:File 'IE00B7LW6Y90.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B7LW6Y90.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▎                           | 91/266 [05:57<10:55,  3.75s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZPJ452.csv' for index 91
# INFO:root:File 'IE00BHZPJ452.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZPJ452.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▌                           | 92/266 [05:59<09:26,  3.25s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681037518.csv' for index 92
# INFO:root:File 'LU1681037518.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU1681037518.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▋                           | 93/266 [06:05<11:08,  3.86s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYV12Y75.csv' for index 93
# INFO:root:File 'IE00BYV12Y75.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BYV12Y75.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▊                           | 94/266 [06:08<10:38,  3.71s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYXYYK40.csv' for index 94
# INFO:root:File 'IE00BYXYYK40.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYXYYK40.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████                           | 95/266 [06:11<09:45,  3.43s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5M4WH52.csv' for index 95
# INFO:root:File 'IE00B5M4WH52.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B5M4WH52.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▏                          | 96/266 [06:16<11:04,  3.91s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1437017863.csv' for index 96
# INFO:root:File 'LU1437017863.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1437017863.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▎                          | 97/266 [06:19<10:14,  3.64s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681041114.csv' for index 97
# INFO:root:File 'LU1681041114.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1681041114.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▍                          | 98/266 [06:23<10:18,  3.68s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1377382285.csv' for index 98
# INFO:root:File 'LU1377382285.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1377382285.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▋                          | 99/266 [06:26<09:47,  3.52s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1048315243.csv' for index 99
# INFO:root:File 'LU1048315243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'LU1048315243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▍                         | 100/266 [06:29<09:49,  3.55s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETFL235.csv' for index 100
# INFO:root:File 'DE000ETFL235.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'DE000ETFL235.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▌                         | 101/266 [06:35<11:35,  4.21s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1437016972.csv' for index 101
# INFO:root:File 'LU1437016972.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1437016972.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▋                         | 102/266 [06:38<10:38,  3.90s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2090063327.csv' for index 102
# INFO:root:File 'LU2090063327.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2090063327.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|███████████████▉                         | 103/266 [06:40<08:44,  3.22s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B4613386.csv' for index 103
# INFO:root:File 'IE00B4613386.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B4613386.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|████████████████                         | 104/266 [06:45<10:09,  3.77s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BP3QZD73.csv' for index 104
# INFO:root:File 'IE00BP3QZD73.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BP3QZD73.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# ...
# INFO:root:File 'LU1681039480.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1681039480.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  87%|███████████████████████████████████▊     | 232/266 [14:39<02:22,  4.20s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1900067940.csv' for index 232
# INFO:root:File 'LU1900067940.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'LU1900067940.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|███████████████████████████████████▉     | 233/266 [14:46<02:43,  4.95s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BJ5JP105.csv' for index 233
# INFO:root:File 'IE00BJ5JP105.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BJ5JP105.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████     | 234/266 [14:48<02:09,  4.05s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZRR253.csv' for index 234
# INFO:root:File 'IE00BHZRR253.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZRR253.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████▏    | 235/266 [14:50<01:48,  3.51s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWBXMB69.csv' for index 235
# INFO:root:File 'IE00BWBXMB69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWBXMB69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▍    | 236/266 [14:54<01:44,  3.50s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6R52259.csv' for index 236
# INFO:root:File 'IE00B6R52259.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6R52259.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▌    | 237/266 [14:59<01:52,  3.89s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFNM3D14.csv' for index 237
# INFO:root:File 'IE00BFNM3D14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFNM3D14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▋    | 238/266 [15:01<01:35,  3.40s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3VWN518.csv' for index 238
# INFO:root:File 'IE00B3VWN518.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VWN518.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▊    | 239/266 [15:06<01:50,  4.08s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/NL0009690247.csv' for index 239
# INFO:root:File 'NL0009690247.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'NL0009690247.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▉    | 240/266 [15:12<01:54,  4.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF540Y54.csv' for index 240
# INFO:root:File 'IE00BF540Y54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF540Y54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▏   | 241/266 [15:14<01:36,  3.84s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMWXKN31.csv' for index 241
# INFO:root:File 'IE00BMWXKN31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BMWXKN31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▎   | 242/266 [15:16<01:15,  3.14s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1287023268.csv' for index 242
# INFO:root:File 'LU1287023268.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1287023268.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▍   | 243/266 [15:21<01:29,  3.90s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0032523478.csv' for index 243
# INFO:root:File 'IE0032523478.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6656, 2)
# INFO:root:File 'IE0032523478.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▌   | 244/266 [15:29<01:52,  5.12s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B53QG562.csv' for index 244
# INFO:root:File 'IE00B53QG562.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B53QG562.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▊   | 245/266 [15:35<01:50,  5.25s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETF9074.csv' for index 245
# INFO:root:File 'DE000ETF9074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'DE000ETF9074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▉   | 246/266 [15:38<01:33,  4.67s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681038672.csv' for index 246
# INFO:root:File 'LU1681038672.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'LU1681038672.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████   | 247/266 [15:42<01:25,  4.51s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKBF6H24.csv' for index 247
# INFO:root:File 'IE00BKBF6H24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BKBF6H24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████▏  | 248/266 [15:44<01:08,  3.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010869495.csv' for index 248
# INFO:root:File 'FR0010869495.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'FR0010869495.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▍  | 249/266 [15:50<01:12,  4.28s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681043912.csv' for index 249
# INFO:root:File 'LU1681043912.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1681043912.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▌  | 250/266 [15:56<01:15,  4.73s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BCRY6227.csv' for index 250
# INFO:root:File 'IE00BCRY6227.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00BCRY6227.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▋  | 251/266 [16:00<01:08,  4.56s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B52XQP83.csv' for index 251
# INFO:root:File 'IE00B52XQP83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B52XQP83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▊  | 252/266 [16:05<01:07,  4.85s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2090062352.csv' for index 252
# INFO:root:File 'LU2090062352.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2090062352.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▉  | 253/266 [16:07<00:50,  3.92s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B27YCF74.csv' for index 253
# INFO:root:File 'IE00B27YCF74.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B27YCF74.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|███████████████████████████████████████▏ | 254/266 [16:14<00:56,  4.74s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKWQ0Q14.csv' for index 254
# INFO:root:File 'IE00BKWQ0Q14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKWQ0Q14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▎ | 255/266 [16:17<00:48,  4.44s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWBXM617.csv' for index 255
# INFO:root:File 'IE00BWBXM617.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWBXM617.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▍ | 256/266 [16:21<00:41,  4.17s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKY40J65.csv' for index 256
# INFO:root:File 'IE00BKY40J65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BKY40J65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▌ | 257/266 [16:23<00:30,  3.41s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000G6GSP88.csv' for index 257
# INFO:root:File 'IE000G6GSP88.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  97%|███████████████████████████████████████▊ | 258/266 [16:23<00:20,  2.53s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000I8KRLL9.csv' for index 258
# INFO:root:File 'IE000I8KRLL9.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  97%|███████████████████████████████████████▉ | 259/266 [16:24<00:13,  1.96s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3VWLG82.csv' for index 259
# INFO:root:File 'IE00B3VWLG82.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VWLG82.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████ | 260/266 [16:29<00:18,  3.08s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3XM3R14.csv' for index 260
# INFO:root:File 'IE00B3XM3R14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3XM3R14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▏| 261/266 [16:35<00:19,  3.82s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BNC1F287.csv' for index 261
# INFO:root:File 'IE00BNC1F287.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BNC1F287.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▍| 262/266 [16:36<00:12,  3.12s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B87G8S03.csv' for index 262
# INFO:root:File 'IE00B87G8S03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B87G8S03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▌| 263/266 [16:41<00:10,  3.56s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B7K93397.csv' for index 263
# INFO:root:File 'IE00B7K93397.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B7K93397.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▋| 264/266 [16:46<00:07,  3.89s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0496786657.csv' for index 264
# INFO:root:File 'LU0496786657.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU0496786657.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|████████████████████████████████████████▊| 265/266 [16:51<00:04,  4.34s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0446734369.csv' for index 265
# INFO:root:File 'LU0446734369.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0446734369.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|█████████████████████████████████████████| 266/266 [16:57<00:00,  3.82s/it]

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
# https://stackoverflow.com/questions/52443273/how-do-you-send-arguments-to-a-generator-function-using-tf-data-dataset-from-gen

fileList = EVAL_FILES
PREDICTED_SAVE_PATH = PREDICTION_SAVE_PATH_EVAL

# fileList = TEST_FILES
# PREDICTED_SAVE_PATH = "/content/dataset/etffancy/FPNWithAttentionBiggerTimebased_1_FutureOnly/test"

pd.options.mode.chained_assignment = None  # default='warn'

for file_index in tqdm(range(0, len(fileList))):
    try:
        filename = fileList[file_index]

        logging.info(f"\nFile name: '{filename}' for index {file_index}")

        tfGenPrediction = tf.data.Dataset.from_generator(lambda: pythonGeneratorPrediction(fileList=[filename]), 
                                                       output_types = (tf.float32, tf.float32),
                                                       output_shapes=(
                                                           (BATCH_SIZE, X_BLOCK_LENGHT, FEATURES),
                                                           (BATCH_SIZE, 4)
                                                           )
                                                       )
        p = model.predict(tfGenPrediction, verbose = 0)

        logging.info(f"p.shape: {p.shape}")

        p_future_gain = p[:,0]
        p_future_gain_derivation = p[:,1]
        
        # Load the tick table
        tickDF = pd.read_csv(filename)
        tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
        
        # Add the predicted future gain
        tickDFcropped.loc[:,"p_future_gain"] = p_future_gain
        tickDFcropped.loc[:,"p_future_gain_derivation"] = p_future_gain_derivation
        
        # Get the (known) past data
        y_past_data = getPastDataFromGen(tfGenPrediction, p.shape)

        # Add the past gain
        tickDFcropped.loc[:,"p_past_gain"] = y_past_data[:,0]
        tickDFcropped.loc[:,"p_past_gain_derivation"] = y_past_data[:,1]

        # Save the DF
        tickDFcropped.to_csv(os.path.join(PREDICTED_SAVE_PATH, filename.split(os.path.sep)[-1]))

        logging.info("Saved the predicted data.")
    except KeyboardInterrupt:
        raise
    except Exception as ex:
        logging.warning(str(ex))
# Out:
#   0%|                                                   | 0/266 [00:00<?, ?it/s]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B4KBBD01.csv' for index 0
# INFO:root:File 'IE00B4KBBD01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00B4KBBD01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   0%|▏                                          | 1/266 [00:02<12:22,  2.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B0M62Y33.csv' for index 1
# INFO:root:File 'IE00B0M62Y33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'IE00B0M62Y33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▎                                          | 2/266 [00:09<23:20,  5.31s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZPJ346.csv' for index 2
# INFO:root:File 'IE00BHZPJ346.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZPJ346.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▍                                          | 3/266 [00:11<16:55,  3.86s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ6V7883.csv' for index 3
# INFO:root:File 'IE00BZ6V7883.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BZ6V7883.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▋                                          | 4/266 [00:15<15:34,  3.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2082997193.csv' for index 4
# INFO:root:File 'LU2082997193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2082997193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▊                                          | 5/266 [00:16<12:21,  2.84s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B1FZS681.csv' for index 5
# INFO:root:File 'IE00B1FZS681.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'IE00B1FZS681.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▉                                          | 6/266 [00:23<17:56,  4.14s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF2GFH28.csv' for index 6
# INFO:root:File 'IE00BF2GFH28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BF2GFH28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▏                                         | 7/266 [00:25<15:05,  3.50s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF4RFH31.csv' for index 7
# INFO:root:File 'IE00BF4RFH31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF4RFH31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▎                                         | 8/266 [00:28<13:41,  3.19s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/NL0011683594.csv' for index 8
# INFO:root:File 'NL0011683594.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'NL0011683594.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▍                                         | 9/266 [00:31<13:34,  3.17s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/NL0009690239.csv' for index 9
# INFO:root:File 'NL0009690239.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'NL0009690239.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▌                                        | 10/266 [00:36<16:02,  3.76s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFWXDW46.csv' for index 10
# INFO:root:File 'IE00BFWXDW46.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFWXDW46.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▋                                        | 11/266 [00:38<14:01,  3.30s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0192223062.csv' for index 11
# INFO:root:File 'LU0192223062.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6656, 2)
# INFO:root:File 'LU0192223062.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|█▉                                        | 12/266 [00:46<19:27,  4.59s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHXMHK04.csv' for index 12
# INFO:root:File 'IE00BHXMHK04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHXMHK04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██                                        | 13/266 [00:48<16:11,  3.84s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BM9GRP64.csv' for index 13
# INFO:root:File 'IE00BM9GRP64.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BM9GRP64.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██▏                                       | 14/266 [00:49<13:03,  3.11s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010424135.csv' for index 14
# INFO:root:File 'FR0010424135.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'FR0010424135.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▎                                       | 15/266 [00:56<17:23,  4.16s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B94ZB998.csv' for index 15
# INFO:root:File 'IE00B94ZB998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B94ZB998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▌                                       | 16/266 [01:00<17:27,  4.19s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYX8XC17.csv' for index 16
# INFO:root:File 'IE00BYX8XC17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BYX8XC17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▋                                       | 17/266 [01:03<15:47,  3.81s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZPJ908.csv' for index 17
# INFO:root:File 'IE00BHZPJ908.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZPJ908.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   7%|██▊                                       | 18/266 [01:05<13:34,  3.29s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B1XNH568.csv' for index 18
# INFO:root:File 'IE00B1XNH568.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B1XNH568.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   7%|███                                       | 19/266 [01:12<18:01,  4.38s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0008470928.csv' for index 19
# INFO:root:File 'IE0008470928.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:File 'IE0008470928.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▏                                      | 20/266 [01:21<23:46,  5.80s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ048579.csv' for index 20
# INFO:root:File 'IE00BZ048579.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BZ048579.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▎                                      | 21/266 [01:23<19:16,  4.72s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0530119774.csv' for index 21
# INFO:root:File 'LU0530119774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU0530119774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▍                                      | 22/266 [01:28<19:46,  4.86s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1273488715.csv' for index 22
# INFO:root:File 'LU1273488715.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1273488715.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▋                                      | 23/266 [01:32<17:37,  4.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1291106356.csv' for index 23
# INFO:root:File 'LU1291106356.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1291106356.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▊                                      | 24/266 [01:35<16:13,  4.02s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5SSQT16.csv' for index 24
# INFO:root:File 'IE00B5SSQT16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B5SSQT16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▉                                      | 25/266 [01:40<17:06,  4.26s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0392496344.csv' for index 25
# INFO:root:File 'LU0392496344.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0392496344.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  10%|████                                      | 26/266 [01:45<18:58,  4.74s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000HMSHYJ6.csv' for index 26
# INFO:root:File 'IE000HMSHYJ6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  10%|████▎                                     | 27/266 [01:46<13:51,  3.48s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B27YCK28.csv' for index 27
# INFO:root:File 'IE00B27YCK28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B27YCK28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▍                                     | 28/266 [01:52<17:06,  4.31s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000O58J820.csv' for index 28
# INFO:root:File 'IE000O58J820.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  11%|████▌                                     | 29/266 [01:53<12:30,  3.17s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B60SX394.csv' for index 29
# INFO:root:File 'IE00B60SX394.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B60SX394.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▋                                     | 30/266 [01:58<15:29,  3.94s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3YCGJ38.csv' for index 30
# INFO:root:File 'IE00B3YCGJ38.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B3YCGJ38.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|████▉                                     | 31/266 [02:04<17:01,  4.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0446734872.csv' for index 31
# INFO:root:File 'LU0446734872.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0446734872.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████                                     | 32/266 [02:09<18:29,  4.74s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE0002635281.csv' for index 32
# INFO:root:File 'DE0002635281.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE0002635281.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████▏                                    | 33/266 [02:17<21:17,  5.48s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B0M63177.csv' for index 33
# INFO:root:File 'IE00B0M63177.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'IE00B0M63177.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▎                                    | 34/266 [02:24<23:07,  5.98s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1737653045.csv' for index 34
# INFO:root:File 'LU1737653045.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1737653045.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▌                                    | 35/266 [02:26<19:05,  4.96s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF92J153.csv' for index 35
# INFO:root:File 'IE00BF92J153.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  14%|█████▋                                    | 36/266 [02:27<14:05,  3.67s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWTN6Y99.csv' for index 36
# INFO:root:File 'IE00BWTN6Y99.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWTN6Y99.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|█████▊                                    | 37/266 [02:31<13:53,  3.64s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BH04GL39.csv' for index 37
# INFO:root:File 'IE00BH04GL39.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BH04GL39.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|██████                                    | 38/266 [02:33<12:07,  3.19s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BK5BQT80.csv' for index 38
# INFO:root:File 'IE00BK5BQT80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BK5BQT80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▏                                   | 39/266 [02:35<10:44,  2.84s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1829220216.csv' for index 39
# INFO:root:File 'LU1829220216.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'LU1829220216.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▎                                   | 40/266 [02:40<12:59,  3.45s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681038243.csv' for index 40
# INFO:root:File 'LU1681038243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU1681038243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▍                                   | 41/266 [02:45<15:02,  4.01s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000TVPSRI1.csv' for index 41
# INFO:root:File 'IE000TVPSRI1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  16%|██████▋                                   | 42/266 [02:45<11:04,  2.96s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2009202107.csv' for index 42
# INFO:root:File 'LU2009202107.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'LU2009202107.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  16%|██████▊                                   | 43/266 [02:48<10:00,  2.69s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B9M6RS56.csv' for index 43
# INFO:root:File 'IE00B9M6RS56.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B9M6RS56.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|██████▉                                   | 44/266 [02:52<11:37,  3.14s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A2QP323.csv' for index 44
# INFO:root:File 'DE000A2QP323.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'DE000A2QP323.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████                                   | 45/266 [02:53<09:38,  2.62s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF16M727.csv' for index 45
# INFO:root:File 'IE00BF16M727.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BF16M727.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████▎                                  | 46/266 [02:55<08:31,  2.32s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF3N7102.csv' for index 46
# INFO:root:File 'IE00BF3N7102.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF3N7102.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▍                                  | 47/266 [02:57<08:41,  2.38s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMDBMK72.csv' for index 47
# INFO:root:File 'IE00BMDBMK72.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  18%|███████▌                                  | 48/266 [02:58<06:39,  1.83s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BFNM3K80.csv' for index 48
# INFO:root:File 'IE00BFNM3K80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BFNM3K80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▋                                  | 49/266 [03:00<07:08,  1.98s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000W95TAE6.csv' for index 49
# INFO:root:File 'IE000W95TAE6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  19%|███████▉                                  | 50/266 [03:01<05:35,  1.55s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2090062782.csv' for index 50
# INFO:root:File 'LU2090062782.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2090062782.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  19%|████████                                  | 51/266 [03:02<05:37,  1.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0005042456.csv' for index 51
# INFO:root:File 'IE0005042456.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:File 'IE0005042456.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▏                                 | 52/266 [03:11<13:42,  3.85s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0F5UG3.csv' for index 52
# INFO:root:File 'DE000A0F5UG3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'DE000A0F5UG3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▎                                 | 53/266 [03:18<16:54,  4.76s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ163H91.csv' for index 53
# INFO:root:File 'IE00BZ163H91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BZ163H91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▌                                 | 54/266 [03:22<15:12,  4.31s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B4L5ZY03.csv' for index 54
# INFO:root:File 'IE00B4L5ZY03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B4L5ZY03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▋                                 | 55/266 [03:27<16:31,  4.70s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B44Z5B48.csv' for index 55
# INFO:root:File 'IE00B44Z5B48.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B44Z5B48.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▊                                 | 56/266 [03:32<16:50,  4.81s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B78JSG98.csv' for index 56
# INFO:root:File 'IE00B78JSG98.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B78JSG98.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|█████████                                 | 57/266 [03:37<16:37,  4.77s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1650492330.csv' for index 57
# INFO:root:File 'LU1650492330.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1650492330.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▏                                | 58/266 [03:40<14:48,  4.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2133056387.csv' for index 58
# INFO:root:File 'LU2133056387.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2133056387.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▎                                | 59/266 [03:42<11:57,  3.47s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2109787635.csv' for index 59
# INFO:root:File 'LU2109787635.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2109787635.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▍                                | 60/266 [03:43<10:03,  2.93s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5MJYY16.csv' for index 60
# INFO:root:File 'IE00B5MJYY16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MJYY16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▋                                | 61/266 [03:49<12:51,  3.76s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYX5K108.csv' for index 61
# INFO:root:File 'IE00BYX5K108.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYX5K108.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▊                                | 62/266 [03:52<11:46,  3.46s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMDBMN04.csv' for index 62
# INFO:root:File 'IE00BMDBMN04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BMDBMN04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|█████████▉                                | 63/266 [03:53<09:39,  2.86s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2090062865.csv' for index 63
# INFO:root:File 'LU2090062865.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2090062865.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|██████████                                | 64/266 [03:55<08:20,  2.48s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5WFQ436.csv' for index 64
# INFO:root:File 'IE00B5WFQ436.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B5WFQ436.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%|██████████▎                               | 65/266 [04:00<11:09,  3.33s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3VTN290.csv' for index 65
# INFO:root:File 'IE00B3VTN290.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VTN290.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  25%|██████████▍                               | 66/266 [04:06<13:33,  4.07s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZPJ569.csv' for index 66
# INFO:root:File 'IE00BHZPJ569.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZPJ569.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  25%|██████████▌                               | 67/266 [04:08<11:33,  3.48s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BNGFMX61.csv' for index 67
# INFO:root:File 'IE00BNGFMX61.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BNGFMX61.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  26%|██████████▋                               | 68/266 [04:10<09:32,  2.89s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BH4GPZ28.csv' for index 68
# INFO:root:File 'IE00BH4GPZ28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BH4GPZ28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  26%|██████████▉                               | 69/266 [04:11<08:31,  2.60s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681046774.csv' for index 69
# INFO:root:File 'LU1681046774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU1681046774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  26%|███████████                               | 70/266 [04:17<11:09,  3.41s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE0005933998.csv' for index 70
# INFO:root:File 'DE0005933998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE0005933998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▏                              | 71/266 [04:24<14:50,  4.57s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1792117779.csv' for index 71
# INFO:root:File 'LU1792117779.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1792117779.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▎                              | 72/266 [04:27<12:44,  3.94s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1602145119.csv' for index 72
# INFO:root:File 'LU1602145119.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1602145119.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  27%|███████████▌                              | 73/266 [04:29<11:20,  3.53s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000JZ473P7.csv' for index 73
# INFO:root:File 'IE000JZ473P7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  28%|███████████▋                              | 74/266 [04:30<08:22,  2.62s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE0003Z9E2Y3.csv' for index 74
# INFO:root:File 'IE0003Z9E2Y3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  28%|███████████▊                              | 75/266 [04:30<06:21,  2.00s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETFL201.csv' for index 75
# INFO:root:File 'DE000ETFL201.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'DE000ETFL201.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  29%|████████████                              | 76/266 [04:36<10:00,  3.16s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5BMR087.csv' for index 76
# INFO:root:File 'IE00B5BMR087.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B5BMR087.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  29%|████████████▏                             | 77/266 [04:41<11:59,  3.81s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDFC6G93.csv' for index 77
# INFO:root:File 'IE00BDFC6G93.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BDFC6G93.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  29%|████████████▎                             | 78/266 [04:44<10:44,  3.43s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE000QRNAC66.csv' for index 78
# INFO:root:File 'IE000QRNAC66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  30%|████████████▍                             | 79/266 [04:44<07:58,  2.56s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKWQ0L68.csv' for index 79
# INFO:root:File 'IE00BKWQ0L68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKWQ0L68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  30%|████████████▋                             | 80/266 [04:48<09:00,  2.91s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B1FZS467.csv' for index 80
# INFO:root:File 'IE00B1FZS467.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'IE00B1FZS467.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  30%|████████████▊                             | 81/266 [04:55<12:26,  4.03s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BJSFR200.csv' for index 81
# INFO:root:File 'IE00BJSFR200.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BJSFR200.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  31%|████████████▉                             | 82/266 [04:57<10:33,  3.44s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000ETFL078.csv' for index 82
# INFO:root:File 'DE000ETFL078.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'DE000ETFL078.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  31%|█████████████                             | 83/266 [05:03<12:55,  4.24s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BDS67326.csv' for index 83
# INFO:root:File 'IE00BDS67326.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BDS67326.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▎                            | 84/266 [05:06<11:33,  3.81s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF0M6N54.csv' for index 84
# INFO:root:File 'IE00BF0M6N54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF0M6N54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▍                            | 85/266 [05:08<10:21,  3.44s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYTRRF33.csv' for index 85
# INFO:root:File 'IE00BYTRRF33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BYTRRF33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▌                            | 86/266 [05:12<10:05,  3.36s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2082999132.csv' for index 86
# INFO:root:File 'LU2082999132.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2082999132.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|█████████████▋                            | 87/266 [05:13<08:26,  2.83s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMH5YR69.csv' for index 87
# INFO:root:File 'IE00BMH5YR69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  33%|█████████████▉                            | 88/266 [05:14<06:22,  2.15s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYXVGX24.csv' for index 88
# INFO:root:File 'IE00BYXVGX24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYXVGX24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|██████████████                            | 89/266 [05:16<06:55,  2.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1650487413.csv' for index 89
# INFO:root:File 'LU1650487413.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'LU1650487413.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▏                           | 90/266 [05:24<11:03,  3.77s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BVGC6645.csv' for index 90
# INFO:root:File 'IE00BVGC6645.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BVGC6645.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▎                           | 91/266 [05:27<11:03,  3.79s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1324516308.csv' for index 91
# INFO:root:File 'LU1324516308.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1324516308.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▌                           | 92/266 [05:31<10:25,  3.59s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1602144732.csv' for index 92
# INFO:root:File 'LU1602144732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1602144732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▋                           | 93/266 [05:33<09:39,  3.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1832418773.csv' for index 93
# INFO:root:File 'LU1832418773.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1832418773.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▊                           | 94/266 [05:39<11:28,  4.00s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5B5TG76.csv' for index 94
# INFO:root:File 'IE00B5B5TG76.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5B5TG76.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████                           | 95/266 [05:44<12:47,  4.49s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWBXM278.csv' for index 95
# INFO:root:File 'IE00BWBXM278.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWBXM278.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▏                          | 96/266 [05:48<11:55,  4.21s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6SPMN59.csv' for index 96
# INFO:root:File 'IE00B6SPMN59.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6SPMN59.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▎                          | 97/266 [05:53<12:06,  4.30s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYVQ9F29.csv' for index 97
# INFO:root:File 'IE00BYVQ9F29.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BYVQ9F29.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▍                          | 98/266 [05:55<10:19,  3.69s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0259322260.csv' for index 98
# INFO:root:File 'LU0259322260.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'LU0259322260.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▋                          | 99/266 [06:01<12:41,  4.56s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BYYXBF44.csv' for index 99
# INFO:root:File 'IE00BYYXBF44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BYYXBF44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▍                         | 100/266 [06:05<11:25,  4.13s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BD45KH83.csv' for index 100
# INFO:root:File 'IE00BD45KH83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BD45KH83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▌                         | 101/266 [06:07<10:01,  3.64s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1287023185.csv' for index 101
# INFO:root:File 'LU1287023185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1287023185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▋                         | 102/266 [06:13<11:42,  4.28s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6R52036.csv' for index 102
# INFO:root:File 'IE00B6R52036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6R52036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|███████████████▉                         | 103/266 [06:18<12:06,  4.46s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1812091194.csv' for index 103
# INFO:root:File 'LU1812091194.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1812091194.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|████████████████                         | 104/266 [06:23<12:54,  4.78s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0908501058.csv' for index 104
# ...
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010524777.csv' for index 231
# INFO:root:File 'FR0010524777.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'FR0010524777.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  87%|███████████████████████████████████▊     | 232/266 [14:25<02:12,  3.91s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B8X9NW27.csv' for index 232
# INFO:root:File 'IE00B8X9NW27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8X9NW27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|███████████████████████████████████▉     | 233/266 [14:30<02:12,  4.03s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0F5UJ7.csv' for index 233
# INFO:root:File 'DE000A0F5UJ7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7680, 2)
# INFO:root:File 'DE000A0F5UJ7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████     | 234/266 [14:38<02:53,  5.43s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0011857234.csv' for index 234
# INFO:root:File 'FR0011857234.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'FR0011857234.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████▏    | 235/266 [14:42<02:34,  4.98s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0D8Q23.csv' for index 235
# INFO:root:File 'DE000A0D8Q23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE000A0D8Q23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▍    | 236/266 [14:50<02:54,  5.83s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0H08R2.csv' for index 236
# INFO:root:File 'DE000A0H08R2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7680, 2)
# INFO:root:File 'DE000A0H08R2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▌    | 237/266 [14:59<03:14,  6.69s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B4L5YX21.csv' for index 237
# INFO:root:File 'IE00B4L5YX21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B4L5YX21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▋    | 238/266 [15:04<02:58,  6.37s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0010424143.csv' for index 238
# INFO:root:File 'FR0010424143.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'FR0010424143.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▊    | 239/266 [15:11<02:53,  6.42s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BF4G6Z54.csv' for index 239
# INFO:root:File 'IE00BF4G6Z54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BF4G6Z54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▉    | 240/266 [15:13<02:13,  5.15s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMW3QX54.csv' for index 240
# INFO:root:File 'IE00BMW3QX54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BMW3QX54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▏   | 241/266 [15:17<01:58,  4.72s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B14X4Q57.csv' for index 241
# INFO:root:File 'IE00B14X4Q57.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:File 'IE00B14X4Q57.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▎   | 242/266 [15:24<02:08,  5.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKY81B71.csv' for index 242
# INFO:root:File 'IE00BKY81B71.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  91%|█████████████████████████████████████▍   | 243/266 [15:24<01:30,  3.92s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BZ163G84.csv' for index 243
# INFO:root:File 'IE00BZ163G84.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'IE00BZ163G84.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▌   | 244/266 [15:28<01:21,  3.72s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1452600270.csv' for index 244
# INFO:root:File 'LU1452600270.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:File 'LU1452600270.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▊   | 245/266 [15:31<01:14,  3.53s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKS7L097.csv' for index 245
# INFO:root:File 'IE00BKS7L097.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BKS7L097.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▉   | 246/266 [15:32<00:59,  2.99s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B6YX5K17.csv' for index 246
# INFO:root:File 'IE00B6YX5K17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:File 'IE00B6YX5K17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████   | 247/266 [15:37<01:06,  3.50s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B5MTXK03.csv' for index 247
# INFO:root:File 'IE00B5MTXK03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MTXK03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████▏  | 248/266 [15:43<01:14,  4.16s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BMDFDY08.csv' for index 248
# INFO:root:File 'IE00BMDFDY08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BMDFDY08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▍  | 249/266 [15:44<00:57,  3.39s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B2NPKV68.csv' for index 249
# INFO:root:File 'IE00B2NPKV68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'IE00B2NPKV68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▌  | 250/266 [15:51<01:07,  4.23s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKM4H197.csv' for index 250
# INFO:root:File 'IE00BKM4H197.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BKM4H197.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▋  | 251/266 [15:54<01:01,  4.11s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B3WMTH43.csv' for index 251
# INFO:root:File 'IE00B3WMTH43.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3WMTH43.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▊  | 252/266 [16:00<01:03,  4.54s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0H08F7.csv' for index 252
# INFO:root:File 'DE000A0H08F7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:File 'DE000A0H08F7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▉  | 253/266 [16:08<01:13,  5.67s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BHZRR030.csv' for index 253
# INFO:root:File 'IE00BHZRR030.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1024, 2)
# INFO:root:File 'IE00BHZRR030.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|███████████████████████████████████████▏ | 254/266 [16:10<00:54,  4.58s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1804202403.csv' for index 254
# INFO:root:File 'LU1804202403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1804202403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▎ | 255/266 [16:13<00:43,  3.94s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0603933895.csv' for index 255
# INFO:root:File 'LU0603933895.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU0603933895.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▍ | 256/266 [16:18<00:42,  4.28s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B53L3W79.csv' for index 256
# INFO:root:File 'IE00B53L3W79.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B53L3W79.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▌ | 257/266 [16:23<00:42,  4.67s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/FR0011550193.csv' for index 257
# INFO:root:File 'FR0011550193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'FR0011550193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▊ | 258/266 [16:28<00:36,  4.52s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00B44CND37.csv' for index 258
# INFO:root:File 'IE00B44CND37.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'IE00B44CND37.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▉ | 259/266 [16:33<00:32,  4.68s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BWBXM500.csv' for index 259
# INFO:root:File 'IE00BWBXM500.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:File 'IE00BWBXM500.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████ | 260/266 [16:36<00:26,  4.35s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/DE000A0F5UK5.csv' for index 260
# INFO:root:File 'DE000A0F5UK5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:File 'DE000A0F5UK5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▏| 261/266 [16:44<00:27,  5.55s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU2082999215.csv' for index 261
# INFO:root:File 'LU2082999215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'LU2082999215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▍| 262/266 [16:46<00:17,  4.38s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/IE00BKY58G26.csv' for index 262
# INFO:root:File 'IE00BKY58G26.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:File 'IE00BKY58G26.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▌| 263/266 [16:48<00:10,  3.54s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1659681669.csv' for index 263
# INFO:root:File 'LU1659681669.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1659681669.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▋| 264/266 [16:50<00:06,  3.27s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU0378438732.csv' for index 264
# INFO:root:File 'LU0378438732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:File 'LU0378438732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|████████████████████████████████████████▊| 265/266 [16:56<00:04,  4.11s/it]INFO:root:
# File name: '/content/dataset/ETF/tickdata/ticks/LU1681048804.csv' for index 265
# INFO:root:File 'LU1681048804.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:File 'LU1681048804.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|█████████████████████████████████████████| 266/266 [17:02<00:00,  3.84s/it]
