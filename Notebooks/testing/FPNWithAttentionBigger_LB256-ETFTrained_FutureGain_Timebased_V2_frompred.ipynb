# %% [markdown]
# # Mount drive and bucket
# Todo: Remove in public version

# %%
# Check if the notebook is run in Google Colab
import sys

COLAB = 'google.colab' in sys.modules

# %%
import sys
import datetime
import logging

# nblog = open(f"/content/bigdata/nb_{datetime.datetime.utcnow().strftime('%Y%m%d_%H%M')}.log", "a+")
# print(nblog)
# sys.stdout.echo = nblog
# sys.stderr.echo = nblog

#get_ipython().log.handlers[0].stream = nblog
#get_ipython().log.setLevel(logging.INFO)

# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
# if COLAB:
#   from google.colab import drive
#   drive.mount('/content/drive')

# %%
if COLAB:
  from google.colab import auth
  auth.authenticate_user()
else:
    print("Run the command!")
  #Todo #bring the command inside the notebook
  #run this terminal inside docker: gcloud auth login b.girsule@gmail.com --no-launch-browser
# Out:
# Run the command!

# %%
# Todo: Check if possible in local docker
# from google.cloud import storage

# %%
# Check if the tf version is 2.10.0, this is required to use the 'ignore_class' in the  SparseCategoricalCrossentropy
import tensorflow as tf

if '2.10.0' != tf.__version__:
  # !pip uninstall tensorflow -y
  # !pip install tensorflow-gpu==2.10.0
  please_restart_the_runtime
else:
  print("TF Version is 2.10.0, ok!")
# Out:
# 2023-03-29 18:02:22.444115: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 18:02:22.715758: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-29 18:02:22.848540: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-29 18:02:23.895290: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-29 18:02:23.895354: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-29 18:02:23.895359: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TF Version is 2.10.0, ok!

# %%
from tensorflow import keras
# import tensorflow_gcs_config
from tensorflow.python.lib.io import file_io

from keras.layers import Input, Dense, Flatten #, ReLU, Add, Flatten, Concatenate, LayerNormalization, UpSampling2D, Activation, LSTM, Multiply, Dropout, Reshape, Permute, BatchNormalization, MaxPooling1D, AveragePooling1D, MaxPooling3D, AveragePooling2D, LayerNormalization, MaxPooling2D
from keras.models import Model
from keras.optimizers import Adam

# %%
import os
from os import listdir
from os.path import isfile, join

# %%
import pandas as pd
import numpy as np
import copy
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import gc
import random

# %%
# Set the google cloud bucket data
project_id = 'tweetprediction'
bucket_name = 'crypto_nlp_training'

# %%
# Set the checkpoint path for saving train progress
if COLAB:
    CHECKPOINT_PATH = f"gs://{bucket_name}/chk/"
else:
    CHECKPOINT_PATH = f"/content/bigdata/chk/"

# %%
# Check if the notebook is run in google colab, if so, clone the repo
if COLAB:
    print("Running in Colab")

    # Clone the whole repo to get all data and code if not already done
    if not os.path.exists("/content/CryptoCrystalBall"):
      # !git clone https://github.com/girsigit/CryptoCrystalBall

      # cd into the notebooks directory --> Necessary to match all paths for importing
    #%cd /content/CryptoCrystalBall/JupyterDocker/notebooks
    # %cd /content

# %%
# Try importing the Ta-Lib library, if this fails, try to install it and
# import it again afterwards
try:
    import talib
except:
    # !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
    # !tar -xzvf ta-lib-0.4.0-src.tar.gz
    # %cd ta-lib
    # !./configure --prefix=/usr
    # !make
    # !make install
    # !pip install Ta-Lib
    # %cd ..

    import talib

# %%
try:
  from transformers import TFRobertaModel, RobertaConfig
except:
  # Important!: Version 4.23 does not work on TPU
  # !pip install transformers==4.22

  from transformers import TFRobertaModel, RobertaConfig
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
# !pip uninstall -y tensorboard-plugin-profile

# %%
# # Required to do profiling
# !pip install tensorboard-plugin-profile

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ---
# # Add custom import path for DataStreamCreator and IndicatorCalculator
#
# These libs are not in the standard python directory, so their paths have to be added to the import paths

# %%
# # Get the current directory
# current_dir = os.getcwd()
# current_dir_splitted = current_dir.split(os.sep)

# Todo: is inside /content/CB in local docker
current_dir_splitted = ["", "content"]
current_dir_splitted
# Out:
# ['', 'content']

# %%
# Create the import directories for the DataStreamCreator and the IndicatorCalculator
dsc_dir = '/content/CryptoCrystalBall/DataStreamCreator'
print(f"dsc_dir: {dsc_dir}")

ind_dir = '/content/CryptoCrystalBall/IndicatorCalculator'
print(f"ind_dir: {ind_dir}")

# Add them to the import paths
sys.path.insert(0, dsc_dir)
sys.path.insert(0, ind_dir)
# Out:
# dsc_dir: /content/CryptoCrystalBall/DataStreamCreator
# ind_dir: /content/CryptoCrystalBall/IndicatorCalculator

# %%
# Import the actual classes
from IndicatorCalculator import IndicatorCalculator
import DataStreamCreator

# %% [markdown]
# ---
# # Define all the parameters and variables

# %%
# Define the tick data path
DATA_PATH = os.path.join(os.sep, *current_dir_splitted, 'DemoData')
print(f"DATA_PATH: {DATA_PATH}")
# Out:
# DATA_PATH: /content/DemoData

# %%
# Define the chart image save path
IMG_SAVE_PATH = os.path.join(os.sep, *current_dir_splitted, 'Documentation', 'Images')
print(f"IMG_SAVE_PATH: {IMG_SAVE_PATH}")
# Out:
# IMG_SAVE_PATH: /content/Documentation/Images

# %%
# Define a global random seed
RANDOM_SEED = 42

# Set the seed in np
np.random.seed(RANDOM_SEED)

# %%
# X_BLOCK_LENGHT defines how far into the past a 'slice of a chart' shall be
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator#xblockgenerator
X_BLOCK_LENGHT = 256

# %%
# How many examples shall be processed at the same time, limited by GPU memory
BATCH_SIZE = 384

# %%
# A fixed number of features is used
FEATURES = 160

# %%
# Finanical indicator timespans
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/IndicatorCalculator
SHORTSPAN = 7
MIDSPAN = 38
LONGSPAN = 50

# %%
# Additional settings for the data stream
# For this notebook, the calculation of pattern indicators is turned off
DATA_STREAM_PARAMETERS = {
    "calcPatternIndicators": False, # No patterns are used
    "calcVolumeInidators": False, # No volume indicators, these are wide spread and may disturb the classifer
    "dropna": True # Drop all tick/indicator table rows containing nan values instead of just replacing them by 0 (which would lead to wrong predictions)
}

# %% [markdown]
# # Load the train dataset

# %%
# Get train file names - Only pick the ones ending with -USDT to prevent
# influence between different currencies
TRAIN_PATH = "/content/dataset/etffancy"

# Get all file names
ALL_FILES = [os.path.join(TRAIN_PATH,f) for f in listdir(TRAIN_PATH) if isfile(join(TRAIN_PATH, f)) and ".csv" in f ]

# Sort them (as a stable basis for randomizing afterwards)
ALL_FILES = sorted(ALL_FILES)

print(f"The train dataset contains {len(ALL_FILES)} files.")
print(ALL_FILES[:3])
# Out:
# The train dataset contains 1064 files.
# ['/content/dataset/etffancy/DE0002635265.csv', '/content/dataset/etffancy/DE0002635273.csv', '/content/dataset/etffancy/DE0002635281.csv']

# %%
# Split the dataset into train, test (trade algorithm train) and eval (trade algorithm test)
SPLIT_RANDOM_SEED = 666
TRAIN_SET_SIZE = 0.5
TEST_SET_SIZE = 0.25
# EVAL_SET_SIZE: The rest

random.Random(SPLIT_RANDOM_SEED).shuffle(ALL_FILES)

train_split_index = int(len(ALL_FILES) * TRAIN_SET_SIZE)
print(f"train_split_index: {train_split_index}")

test_split_index = int(len(ALL_FILES) * (TRAIN_SET_SIZE + TEST_SET_SIZE))
print(f"test_split_index: {test_split_index}")

TRAIN_FILES = ALL_FILES[:train_split_index]
TEST_FILES = ALL_FILES[train_split_index:test_split_index]
EVAL_FILES = ALL_FILES[test_split_index:]
# Out:
# train_split_index: 532
# test_split_index: 798

# %% [markdown]
# ---
# # Prepare data source
#
# For training a neural network, first the data source has to be prepared. For this purpose, the method `FileListToDataStream` from the `DataStreamCreator` class is used. This method creates a stream of `X-Block` and `y-data` arrays out of a list of .csv file names, pointing to tick tables (called `EXAMPLE_FILE_PATHS` in this example). For details about `X-Blocks` and `y-data`, please refer to the documentation of the `XBlockGenerator` and the `YDataGenerator` under https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator.
#
# <br>
#
# WRONG  WRONG  WRONG  WRONG  WRONG  WRONG  WRONG  WRONG
# Target values (y-data) from the data generator would not be necessary in this notebook, but since it cannot be switched off, the future direction and its derviation of the price have been chosen in `Y_TYPE_DICT` since they are not expensive to compute. A switch flag will be added in a future release.

# %%
# FPNWithAttention_5_ETF_Trained_Past_Future_Gain_TrainSetOnly_GPU_64LB
Y_TYPE_DICT = copy.deepcopy(DataStreamCreator.YDataGenerator.PARAM_DICT_TEMPLATE_Y_DATA_TYPE_PAST_FUTURE_GAIN)
Y_TYPE_DICT["gain_timespan"] = 60
# Y_TYPE_DICT["direction_ma_timespan"] = 14
# Y_TYPE_DICT["derivation_ma_timespan"] = 14
Y_TYPE_DICT
# Out:
# {'dataType': 3,
#  'gain_timespan': 60,
#  'direction_ma_timespan': 48,
#  'derivation_ma_timespan': 48}

# %%
TARGET_FEATURE_CNT = 160 #256

# %%
XShape = (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT)
XShape
# Out:
# (384, 256, 160)

# %%
import numpy as np
a = np.array([1,2,3,4])
a[[1,3]]
# Out:
# array([2, 4])

# %%
# A python generator function has to be applied on the dataStream

def pythonGeneratorSignalsTraining():
  # Initialize the FileListToDataStream generator
  dataStreamTraining = DataStreamCreator.FileListToDataStream(fileList = TRAIN_FILES,
                                                      batch_size = BATCH_SIZE,
                                                      X_Block_lenght = X_BLOCK_LENGHT,
                                                      y_type_dict=Y_TYPE_DICT,
                                                      shuffle=True,
                                                      parallel_generators = np.min([BATCH_SIZE, 8]),
                                                      random_seed = RANDOM_SEED,
                                                      **DATA_STREAM_PARAMETERS
                                                      )

  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStreamTraining)
      _X = ne['X']
      _y = ne['y'][:,[1,3]]
    
      # Limit the y signal to avoid excess
      _y /= 10.0
      _y = np.clip(_y, -10.0, 10.0)
        
      # 'Blow up' the X array to a 2**n size
      #_X_new = np.zeros((_X.shape[0], _X.shape[1], TARGET_FEATURE_CNT))
      #_X_new[:,:,:_X.shape[2]] = _X

      yield (_X, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
tfGenTraining = tf.data.Dataset.from_generator(pythonGeneratorSignalsTraining, 
                                               output_types = (tf.float32, tf.float32),
                                               output_shapes=(
                                                   (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                   (BATCH_SIZE, 2)
                                                   )
                                               )

tfGenTraining = tfGenTraining.prefetch(buffer_size=32)
tfGenTraining
# Out:
# 2023-03-29 18:02:27.892804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:27.956073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:27.956279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:27.958662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 18:02:27.960597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:27.960819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:27.960960: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:28.724735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:28.725316: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:28.725428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-29 18:02:28.725517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6179 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# <PrefetchDataset element_spec=(TensorSpec(shape=(384, 256, 160), dtype=tf.float32, name=None), TensorSpec(shape=(384, 2), dtype=tf.float32, name=None))>

# %% [markdown]
# ---
# # Create the neural network
#
# In the example, two Conv1D pyramids are used to extract features at different levels out of the feature and the time dimension.
#
# It is also possible to use different architecures, like LSTM, Conv2D, Attention-Based ones or even NLP-based models. I have already tried many different ones and will publish them into the model zoo.
#
# ```
# Todo: Create Model Zoo
# ```
#
# ```
# Todo: Create Image of netwrok structure
# ```

# %%
# from keras.layers import Input, Dense, ReLU, Add, Flatten, Concatenate, LayerNormalization, UpSampling2D, Activation, LSTM, Multiply, Dropout, Reshape, Permute, BatchNormalization, MaxPooling1D, AveragePooling1D, MaxPooling3D, AveragePooling2D, LayerNormalization, MaxPooling2D, UnitNormalization, UpSampling1D
from keras.layers import UnitNormalization, Permute, Conv1D, UpSampling1D, Add, LSTM, Concatenate, Multiply, Activation, Attention, Dropout

# %%
# Create the FPNWithFScaledInput model
# Infos about the feature pyramid: https://jonathan-hui.medium.com/understanding-feature-pyramid-networks-for-object-detection-fpn-45b227b9106c

def CreateModelFPNWithAttention():
  # Define model parameters
  mp = {
      "NAME": "FPNWithAttentionBiggerTimebased",
      "VERSION": "2_FutureOnly_60days",
      "CNN_INITIAL_FILTERS": 64,
      "CNN_EXTRACTOR_LAYERS": 6,
      "CNN_INITIAL_KERNEL_SIZE": 2,
      "CNN_MAX_KERNEL_SIZE": 8,
      "FEATURE_PYRAMID_START_INDEX": 2,
      "HEAD_LSTM_SIZE": 64,
      "HEAD_DENSE_SIZE": 32
      }
  
  # Create the model input  
  inputTicksAndIndicators = Input(shape=(X_BLOCK_LENGHT, TARGET_FEATURE_CNT), name='inputTicksAndIndicators', dtype='float32')
  inputTicksAndIndicators = Dropout(0.1, name='inputDropout')(inputTicksAndIndicators)

  # Normalize the input data, as it has a wide value spread (range of 1e8)
  normalized = UnitNormalization(name="UnitNormalizationInput", axis=-2)(inputTicksAndIndicators)

  # Permute it to Conv over Features
  #normalized = Permute((2, 1), name="PermuteInput")(normalized)

  # ----------------------------------------------------------------------------

  # As an example a 1D-CNN pyramid is used to extract higher-level features out
  # of the indicator+tick dimension
  conv_layers = []
  aligned_layers = []
  feature_map_layers = []
  anti_aliased_layers = []
  anti_aliased_pyramid_indices = []
  regressor_layers = []

  finalFilters = mp["CNN_INITIAL_FILTERS"] * 2**(mp["FEATURE_PYRAMID_START_INDEX"])
  print(finalFilters) 

  for i in range(mp["CNN_EXTRACTOR_LAYERS"]):
    if 0 == i:
      source_layer = normalized
    else:
      source_layer = feature_conv
    
    filters = int(mp["CNN_INITIAL_FILTERS"]*(2**i))
    kernel_size = mp["CNN_INITIAL_KERNEL_SIZE"]*(2**i)
    kernel_size = int(np.min([mp["CNN_MAX_KERNEL_SIZE"], kernel_size]))
    strides = int(np.min([2,kernel_size]))

    print(f"Step {i}, using {filters} filters with a kernel size of {kernel_size} at strides of {strides}")

    # Create the feature extraction convolution
    res_net_element = Conv1D(filters=source_layer.shape[-1],
                          kernel_size=kernel_size,
                          strides=1, 
                          padding="same",
                          name=f"ResNet_{i}_Conv1D_1")(source_layer)
    
    res_net_element = Activation("relu",
                              name=f"ResNet_{i}_ReLU")(res_net_element)
    
    res_net_element = Conv1D(filters=source_layer.shape[-1],
                          kernel_size=kernel_size,
                          strides=1, 
                          padding="same",
                          name=f"ResNet_{i}_Conv1D_2")(res_net_element)
    
    res_net_element = Add(name=f"ResNet_{i}_Add")([res_net_element, source_layer])
        
    feature_conv = Conv1D(filters=filters,
                          kernel_size=kernel_size,
                          strides=strides, 
                          padding="same",
                          name=f"ResNet_{i}_Feature_Conv1D_FilterDimReduction")(res_net_element)

    attention_map = Attention(name=f"Attention_Layer_{i}")([feature_conv,feature_conv])
    print(f"attention_map.shape: {attention_map.shape}")

    feature_conv_attentioned = Multiply(name=f"Multiply_Apply_Attention_{i}")([feature_conv, attention_map])
    print(f"feature_conv_attentioned.shape: {feature_conv_attentioned.shape}")
    
    conv_layers.append(feature_conv_attentioned)

    # Apply the feature extraction pyramid
    if mp["FEATURE_PYRAMID_START_INDEX"] <= i:
      # Apply a 1x1 convolution to align the channel depth    
      if feature_conv_attentioned.shape[-1] != finalFilters:
        aligned_layer = Conv1D(filters=finalFilters,
                              kernel_size=1,
                              strides=1,
                              padding="same",
                              name=f"Channel_Depth_Alignment_{i}")(feature_conv_attentioned)
      else:
        aligned_layer = feature_conv_attentioned
      
      aligned_layers.append(aligned_layer)

  # Go top-down through the aligned_layers to create the feature_map_layers
  for i in range(mp["CNN_EXTRACTOR_LAYERS"]-1, mp["FEATURE_PYRAMID_START_INDEX"]-1, -1):
    aligned_layers_index = i - mp["FEATURE_PYRAMID_START_INDEX"]
    aligned_layer = aligned_layers[aligned_layers_index]

    print(f"Building feature_map_layers, step {i}. Shape of aligned_layer: {aligned_layer.shape}")

    # The highest-filtered layer is taken as feature map directly
    if i == mp["CNN_EXTRACTOR_LAYERS"]-1:
      feature_map_layers.append(aligned_layer)
      anti_aliased_layers.append(feature_map_layers[-1])
    else:
      # Take the last feature_map_layer and scale it by two
      upsampled = UpSampling1D(size=2,
                               name=f"Pyramid_Upsampling_{i}")(feature_map_layers[-1])

      # Add the aligned_layer
      added = Add(name=f"Pyramid_Add_{i}")([upsampled, aligned_layer])

      # Append as new feature_map_layer
      feature_map_layers.append(added)

      # Apply a convolution with a kernel size of 3 to "reduce the aliasing effect"
      anti_aliased_layer = Conv1D(filters=feature_map_layers[-1].shape[-1],
                                  kernel_size=3,
                                  strides=1,
                                  padding="same",
                                  name=f"Anti_Alias_{i}")(feature_map_layers[-1])

      anti_aliased_layers.append(anti_aliased_layer)

    # Helper storage to keep pyramid index consistent, also in predictor/regressor
    anti_aliased_pyramid_indices.append(i)

  # Apply the predictor head to each feature dimension layer
  for n in range(len(anti_aliased_layers)):
    predictor_input = anti_aliased_layers[n]

    # Get the pyramid index
    pyramid_index = anti_aliased_pyramid_indices[n]

    # Permute the Conv output back
    predictor_input = Permute((2, 1), name=f"PermutePredictorInput_{pyramid_index}")(predictor_input)

    predictor = LSTM(units=mp["HEAD_LSTM_SIZE"],
                     name=f"Predictor_Head_{pyramid_index}_LSTM")(predictor_input)
    
    # Direction and derivation regressor
    regressor = Dense(units=mp["HEAD_DENSE_SIZE"],
                      name=f"Predictor_Head_{pyramid_index}_Dense_Regressor",
                      activation='relu')(predictor)
    
    regressor_layers.append(regressor)
  
  # Add all regressors together
  regressor_conced = Concatenate(name="Concatenate_regressors")(regressor_layers)
  #regressor_conced = Dense(regressor_conced.shape[1], name="Combined_Regressor_1")(regressor_conced)
  #regressor_conced = Dense(regressor_conced.shape[1], name="Combined_Regressor_2")(regressor_conced)

  # The output are two values (direction and derivation) in the range [-1.0, 1.0]
  output = Dense(2, activation="tanh", name="Output")(regressor_conced)
  outputs = [output]

  # Combine it all into a model object
  model = Model(inputs=inputTicksAndIndicators, outputs=outputs, name=mp["NAME"] + "_" + str(mp["VERSION"]))

  return model, mp

model, model_config = CreateModelFPNWithAttention()
print(model_config)
model.summary(line_length=220)
# Out:
# 256
# Step 0, using 64 filters with a kernel size of 2 at strides of 2
# attention_map.shape: (None, 128, 64)
# feature_conv_attentioned.shape: (None, 128, 64)
# Step 1, using 128 filters with a kernel size of 4 at strides of 2
# attention_map.shape: (None, 64, 128)
# feature_conv_attentioned.shape: (None, 64, 128)
# Step 2, using 256 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 32, 256)
# feature_conv_attentioned.shape: (None, 32, 256)
# Step 3, using 512 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 16, 512)
# feature_conv_attentioned.shape: (None, 16, 512)
# Step 4, using 1024 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 8, 1024)
# feature_conv_attentioned.shape: (None, 8, 1024)
# Step 5, using 2048 filters with a kernel size of 8 at strides of 2
# attention_map.shape: (None, 4, 2048)
# feature_conv_attentioned.shape: (None, 4, 2048)
# Building feature_map_layers, step 5. Shape of aligned_layer: (None, 4, 256)
# Building feature_map_layers, step 4. Shape of aligned_layer: (None, 8, 256)
# Building feature_map_layers, step 3. Shape of aligned_layer: (None, 16, 256)
# Building feature_map_layers, step 2. Shape of aligned_layer: (None, 32, 256)
# {'NAME': 'FPNWithAttentionBiggerTimebased', 'VERSION': '2_FutureOnly_60days', 'CNN_INITIAL_FILTERS': 64, 'CNN_EXTRACTOR_LAYERS': 6, 'CNN_INITIAL_KERNEL_SIZE': 2, 'CNN_MAX_KERNEL_SIZE': 8, 'FEATURE_PYRAMID_START_INDEX': 2, 'HEAD_LSTM_SIZE': 64, 'HEAD_DENSE_SIZE': 32}
# Model: "FPNWithAttentionBiggerTimebased_2_FutureOnly_60days"
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                           Output Shape                                     Param #                   Connected to
# ============================================================================================================================================================================================================================
#  input_1 (InputLayer)                                                   [(None, 256, 160)]                               0                         []
#
#  UnitNormalizationInput (UnitNormalization)                             (None, 256, 160)                                 0                         ['input_1[0][0]']
#
#  ResNet_0_Conv1D_1 (Conv1D)                                             (None, 256, 160)                                 51360                     ['UnitNormalizationInput[1][0]']
#
#  ResNet_0_ReLU (Activation)                                             (None, 256, 160)                                 0                         ['ResNet_0_Conv1D_1[1][0]']
#
#  ResNet_0_Conv1D_2 (Conv1D)                                             (None, 256, 160)                                 51360                     ['ResNet_0_ReLU[1][0]']
#
#  ResNet_0_Add (Add)                                                     (None, 256, 160)                                 0                         ['ResNet_0_Conv1D_2[1][0]',
#                                                                                                                                                     'UnitNormalizationInput[1][0]']
#
#  ResNet_0_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 128, 64)                                  20544                     ['ResNet_0_Add[1][0]']
#
#  ResNet_1_Conv1D_1 (Conv1D)                                             (None, 128, 64)                                  16448                     ['ResNet_0_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_1_ReLU (Activation)                                             (None, 128, 64)                                  0                         ['ResNet_1_Conv1D_1[1][0]']
#
#  ResNet_1_Conv1D_2 (Conv1D)                                             (None, 128, 64)                                  16448                     ['ResNet_1_ReLU[1][0]']
#
#  ResNet_1_Add (Add)                                                     (None, 128, 64)                                  0                         ['ResNet_1_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_0_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_1_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 64, 128)                                  32896                     ['ResNet_1_Add[1][0]']
#
#  ResNet_2_Conv1D_1 (Conv1D)                                             (None, 64, 128)                                  131200                    ['ResNet_1_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_2_ReLU (Activation)                                             (None, 64, 128)                                  0                         ['ResNet_2_Conv1D_1[1][0]']
#
#  ResNet_2_Conv1D_2 (Conv1D)                                             (None, 64, 128)                                  131200                    ['ResNet_2_ReLU[1][0]']
#
#  ResNet_2_Add (Add)                                                     (None, 64, 128)                                  0                         ['ResNet_2_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_1_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_2_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 32, 256)                                  262400                    ['ResNet_2_Add[1][0]']
#
#  ResNet_3_Conv1D_1 (Conv1D)                                             (None, 32, 256)                                  524544                    ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_3_ReLU (Activation)                                             (None, 32, 256)                                  0                         ['ResNet_3_Conv1D_1[1][0]']
#
#  ResNet_3_Conv1D_2 (Conv1D)                                             (None, 32, 256)                                  524544                    ['ResNet_3_ReLU[1][0]']
#
#  ResNet_3_Add (Add)                                                     (None, 32, 256)                                  0                         ['ResNet_3_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_3_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 16, 512)                                  1049088                   ['ResNet_3_Add[1][0]']
#
#  ResNet_4_Conv1D_1 (Conv1D)                                             (None, 16, 512)                                  2097664                   ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_4_ReLU (Activation)                                             (None, 16, 512)                                  0                         ['ResNet_4_Conv1D_1[1][0]']
#
#  ResNet_4_Conv1D_2 (Conv1D)                                             (None, 16, 512)                                  2097664                   ['ResNet_4_ReLU[1][0]']
#
#  ResNet_4_Add (Add)                                                     (None, 16, 512)                                  0                         ['ResNet_4_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_4_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 8, 1024)                                  4195328                   ['ResNet_4_Add[1][0]']
#
#  ResNet_5_Conv1D_1 (Conv1D)                                             (None, 8, 1024)                                  8389632                   ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_5_ReLU (Activation)                                             (None, 8, 1024)                                  0                         ['ResNet_5_Conv1D_1[1][0]']
#
#  ResNet_5_Conv1D_2 (Conv1D)                                             (None, 8, 1024)                                  8389632                   ['ResNet_5_ReLU[1][0]']
#
#  ResNet_5_Add (Add)                                                     (None, 8, 1024)                                  0                         ['ResNet_5_Conv1D_2[1][0]',
#                                                                                                                                                     'ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  ResNet_5_Feature_Conv1D_FilterDimReduction (Conv1D)                    (None, 4, 2048)                                  16779264                  ['ResNet_5_Add[1][0]']
#
#  Attention_Layer_5 (Attention)                                          (None, 4, 2048)                                  0                         ['ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Multiply_Apply_Attention_5 (Multiply)                                  (None, 4, 2048)                                  0                         ['ResNet_5_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_5[1][0]']
#
#  Attention_Layer_4 (Attention)                                          (None, 8, 1024)                                  0                         ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Channel_Depth_Alignment_5 (Conv1D)                                     (None, 4, 256)                                   524544                    ['Multiply_Apply_Attention_5[1][0]']
#
#  Multiply_Apply_Attention_4 (Multiply)                                  (None, 8, 1024)                                  0                         ['ResNet_4_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_4[1][0]']
#
#  Pyramid_Upsampling_4 (UpSampling1D)                                    (None, 8, 256)                                   0                         ['Channel_Depth_Alignment_5[1][0]']
#
#  Channel_Depth_Alignment_4 (Conv1D)                                     (None, 8, 256)                                   262400                    ['Multiply_Apply_Attention_4[1][0]']
#
#  Attention_Layer_3 (Attention)                                          (None, 16, 512)                                  0                         ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Pyramid_Add_4 (Add)                                                    (None, 8, 256)                                   0                         ['Pyramid_Upsampling_4[1][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_4[1][0]']
#
#  Multiply_Apply_Attention_3 (Multiply)                                  (None, 16, 512)                                  0                         ['ResNet_3_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_3[1][0]']
#
#  Pyramid_Upsampling_3 (UpSampling1D)                                    (None, 16, 256)                                  0                         ['Pyramid_Add_4[1][0]']
#
#  Channel_Depth_Alignment_3 (Conv1D)                                     (None, 16, 256)                                  131328                    ['Multiply_Apply_Attention_3[1][0]']
#
#  Pyramid_Add_3 (Add)                                                    (None, 16, 256)                                  0                         ['Pyramid_Upsampling_3[1][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_3[1][0]']
#
#  Attention_Layer_2 (Attention)                                          (None, 32, 256)                                  0                         ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]']
#
#  Pyramid_Upsampling_2 (UpSampling1D)                                    (None, 32, 256)                                  0                         ['Pyramid_Add_3[1][0]']
#
#  Multiply_Apply_Attention_2 (Multiply)                                  (None, 32, 256)                                  0                         ['ResNet_2_Feature_Conv1D_FilterDimReduction[1][0]',
#                                                                                                                                                     'Attention_Layer_2[1][0]']
#
#  Pyramid_Add_2 (Add)                                                    (None, 32, 256)                                  0                         ['Pyramid_Upsampling_2[1][0]',
#                                                                                                                                                     'Multiply_Apply_Attention_2[1][0]']
#
#  Anti_Alias_4 (Conv1D)                                                  (None, 8, 256)                                   196864                    ['Pyramid_Add_4[1][0]']
#
#  Anti_Alias_3 (Conv1D)                                                  (None, 16, 256)                                  196864                    ['Pyramid_Add_3[1][0]']
#
#  Anti_Alias_2 (Conv1D)                                                  (None, 32, 256)                                  196864                    ['Pyramid_Add_2[1][0]']
#
#  PermutePredictorInput_5 (Permute)                                      (None, 256, 4)                                   0                         ['Channel_Depth_Alignment_5[1][0]']
#
#  PermutePredictorInput_4 (Permute)                                      (None, 256, 8)                                   0                         ['Anti_Alias_4[1][0]']
#
#  PermutePredictorInput_3 (Permute)                                      (None, 256, 16)                                  0                         ['Anti_Alias_3[1][0]']
#
#  PermutePredictorInput_2 (Permute)                                      (None, 256, 32)                                  0                         ['Anti_Alias_2[1][0]']
#
#  Predictor_Head_5_LSTM (LSTM)                                           (None, 64)                                       17664                     ['PermutePredictorInput_5[1][0]']
#
#  Predictor_Head_4_LSTM (LSTM)                                           (None, 64)                                       18688                     ['PermutePredictorInput_4[1][0]']
#
#  Predictor_Head_3_LSTM (LSTM)                                           (None, 64)                                       20736                     ['PermutePredictorInput_3[1][0]']
#
#  Predictor_Head_2_LSTM (LSTM)                                           (None, 64)                                       24832                     ['PermutePredictorInput_2[1][0]']
#
#  Predictor_Head_5_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_5_LSTM[1][0]']
#
#  Predictor_Head_4_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_4_LSTM[1][0]']
#
#  Predictor_Head_3_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_3_LSTM[1][0]']
#
#  Predictor_Head_2_Dense_Regressor (Dense)                               (None, 32)                                       2080                      ['Predictor_Head_2_LSTM[1][0]']
#
#  Concatenate_regressors (Concatenate)                                   (None, 128)                                      0                         ['Predictor_Head_5_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_4_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_3_Dense_Regressor[1][0]',
#                                                                                                                                                     'Predictor_Head_2_Dense_Regressor[1][0]']
#
#  Output (Dense)                                                         (None, 2)                                        258                       ['Concatenate_regressors[1][0]']
#
# ============================================================================================================================================================================================================================
# Total params: 46,360,578
# Trainable params: 46,360,578
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # Train the model

# %% [markdown]
# ### Train strategy in the paper
# https://huggingface.co/roberta-base
#
# The model was trained on 1024 V100 GPUs for 500K steps with a batch size of 8K and a sequence length of 512. The optimizer used is Adam with a learning rate of 6e-4, β1=0.9\beta_{1} = 0.9β1​=0.9, β2=0.98\beta_{2} = 0.98β2​=0.98 and ϵ=1e−6\epsilon = 1e-6ϵ=1e−6, a weight decay of 0.01, learning rate warmup for 24,000 steps and linear decay of the learning rate after.

# %%
CHKPNT_NAME = f"{model.name}_GPU_{X_BLOCK_LENGHT}LB"
CHKPNT_NAME
# Out:
# 'FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB'

# %%
# Set an optimizer
optimizer = Adam(
    learning_rate=1e-03,
    epsilon=1e-06,
    beta_1=0.9,
    beta_2=0.98,
    decay=0.01)

# %%
# Compile the model
model.compile(
    optimizer = optimizer,
    loss = ["mse"], 
    metrics=["mae"])

# %%
#@title CustomCallback
class CustomCallback(tf.keras.callbacks.Callback):
  def __init__(self, save_freq, val_freq, checkpoint_path, model_name, epoch_add=0):
    self.save_freq = save_freq
    self.val_freq = val_freq
    self.checkpoint_path = checkpoint_path
    self.model_name = model_name
    self.current_epoch = 0
    self.epoch_add = epoch_add

  def on_epoch_begin(self, epoch, logs=None):
    self.current_epoch = epoch + self.epoch_add
    # keys = list(logs.keys())
    # print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

  def on_epoch_end(self, epoch, logs=None):
    self.saveTheModel(-1, logs)

  def on_train_batch_end(self, batch, logs=None):
    self.saveTheModel(batch, logs)

  def saveTheModel(self, batch, logs=None):
    if (0 < batch and 0 == batch % self.save_freq) or (0 > batch):
      logging.info(str(datetime.datetime.utcnow()))
    
      if 0 > batch:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_end".format(self.current_epoch)
                                    )
      else:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_{:05d}".format(self.current_epoch, batch)
                                    )
      
      fp = os.path.join(_save_folder, "model.h5")
      model.save(fp)
      logging.info(f"Saved model to '{fp}'")
      
      # Save optimizer config
      # c = copy.deepcopy(self.model.optimizer.get_config())

      fp = os.path.join(_save_folder, "c.pickle")
      with file_io.FileIO(fp, mode='wb+') as handle:
        pickle.dump(self.model.optimizer.get_config(), handle, protocol=pickle.HIGHEST_PROTOCOL)
        
      logging.info(f"Saved optimizer config to '{fp}'")

      # Save optimizer weights
      # w = copy.deepcopy(self.model.optimizer.get_weights())

      fp = os.path.join(_save_folder, "w.pickle")
      with open(fp, "wb") as handle:
        # with file_io.FileIO(fp, mode='wb+') as handle:
        pickle.dump(self.model.optimizer.get_weights(), handle, protocol=pickle.HIGHEST_PROTOCOL)
      
      logging.info(f"Saved optimizer weights to '{fp}'")
        
      logging.info(f"Did a gc collect: {gc.collect()}")

    # if 0 < batch and 0 == batch % self.val_freq:
    #   print("-------------------------EVAL-------------------------")
    #   model.evaluate(tfgenTest)
    #   print("\n-------------------------EVAL-------------------------")

# %%
gc.collect()
# Out:
# 9886

# %%
epoch_add = 0

# %%
CALLBACK_EVERY_N_BATCHES = 2000

# %%
cc = CustomCallback(checkpoint_path = CHECKPOINT_PATH,
                    model_name = CHKPNT_NAME,
                    save_freq = CALLBACK_EVERY_N_BATCHES,
                    val_freq = CALLBACK_EVERY_N_BATCHES,
                    epoch_add = epoch_add)

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %reload_ext tensorboard

# %% [markdown]
# The TensorBoard UI is displayed in a browser window. In this colab, perform the following steps to prepare to capture profile information.
# 1.  Click on the dropdown menu box on the top right side and scroll down and click PROFILE. A new window appears that shows: **No profile data was found** at the top.
# 1.  Click on the CAPTURE PROFILE button. A new dialog appears. The top input line shows: **Profile Service URL or TPU name**. Copy and paste the Profile Service URL (the service_addr value shown before launching TensorBoard) into the top input line. While still on the dialog box, start the training with the next step.
# 1.  Click on the next colab cell to start training the model.
# 1.  Watch the output from the training until several epochs have completed. This allows time for the profile data to start being collected. Return to the dialog box and click on the CAPTURE button. If the capture succeeds, the page will auto refresh and redirect you to the profiling results.

# %%
# Todo: Create more elegant solution
log_dir = "gs://ticks_with_indicators_with_volume/logs/TPU/" + CHKPNT_NAME + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

if not COLAB:
    log_dir = os.path.join("/content/bigdata/log",log_dir.split("/")[-1])

log_dir
# Out:
# '/content/bigdata/log/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB20230329-180230'

# %%
import datetime

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    update_freq=CALLBACK_EVERY_N_BATCHES,
    profile_batch=(5,100)
    )
# Out:
# 2023-03-29 18:02:30.568189: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-03-29 18:02:30.568252: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-03-29 18:02:30.569441: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2023-03-29 18:02:30.569949: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory
# 2023-03-29 18:02:30.679672: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-03-29 18:02:30.679858: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed

# %%
model.load_weights("/content/bigdata/chk/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/cp_daily_valid_03_end/model.h5")

# %%
# %tensorboard --logdir $log_dir --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-c42b3013f5f31384" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c42b3013f5f31384");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# model.fit(tfGenTraining,
#           epochs=1,
#           verbose = 1,
#           callbacks=[tensorboard_callback, cc])

# %%
# model.optimizer.learning_rate = 5e-6

# %%
# model.optimizer.learning_rate

# %%
# epoch_add = 1

# cc = CustomCallback(checkpoint_path = CHECKPOINT_PATH,
#                     model_name = CHKPNT_NAME,
#                     save_freq = CALLBACK_EVERY_N_BATCHES,
#                     val_freq = CALLBACK_EVERY_N_BATCHES,
#                     epoch_add = epoch_add)

# %%
# model.fit(tfGenTraining,
#           epochs=5,
#           verbose = 1,
#           callbacks=[tensorboard_callback, cc])

# %%
# A python generator function has to be applied on the dataStream

def pythonGeneratorEval(fileList):
  # Initialize the FileListToDataStream generator
  dataStreamEval= DataStreamCreator.FileListToDataStream(fileList = fileList,
                                                      batch_size = BATCH_SIZE,
                                                      X_Block_lenght = X_BLOCK_LENGHT,
                                                      y_type_dict=Y_TYPE_DICT,
                                                      shuffle=False,
                                                      parallel_generators = 1,
                                                      random_seed = RANDOM_SEED,
                                                      **DATA_STREAM_PARAMETERS
                                                      )
  
  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStreamEval)
      _X = ne['X']
      _y = _y = ne['y']#[:,[1,3]]
    
      # Limit the y signal to avoid excess
      _y /= 10.0
      _y = np.clip(_y, -10.0, 10.0)
    
      # 'Blow up' the X array to a 2**n size
      #_X_new = np.zeros((_X.shape[0], _X.shape[1], TARGET_FEATURE_CNT))
      #_X_new[:,:,:_X.shape[2]] = _X

      yield (_X, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
tfGenEval = tf.data.Dataset.from_generator(lambda: pythonGeneratorEval(fileList=[TRAIN_FILES[4]]), 
                                               output_types = (tf.float32, tf.float32),
                                               output_shapes=(
                                                   (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                   (BATCH_SIZE, 4)
                                                   )
                                               )
tfGenEval
# Out:
# <FlatMapDataset element_spec=(TensorSpec(shape=(384, 256, 160), dtype=tf.float32, name=None), TensorSpec(shape=(384, 4), dtype=tf.float32, name=None))>

# %%
# ne[0].shape

# %%
# ne[1].shape

# %%
# plt.plot(ne[1][:,0])

# %%
# plt.plot(ne[1][:,1])

# %%
# evl = model.evaluate(tfGenEval)
# evl

# %%
p = model.predict(tfGenEval)
p *= 10.0
p.shape
# Out:
# INFO:root:File 'IE00B1FZS350.csv' loaded, 0 left
# 2023-03-29 18:02:38.497674: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8700
# 2023-03-29 18:02:40.025203: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#      14/Unknown - 10s 232ms/step
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# 14/14 [==============================] - 10s 259ms/step
# (5376, 2)

# %%
def getPastDataFromGen(genIn, predictedShapeIn):
    it = genIn.as_numpy_iterator()

    y_past_data = np.empty((predictedShapeIn[0], 2))
    i = 0

    try:
        while (ne := next(it)):
            #print(i)
            y_past_data[i:i+ne[1].shape[0],0] = ne[1][:,0]
            y_past_data[i:i+ne[1].shape[0],1] = ne[1][:,2]

            i += ne[1].shape[0]

    except StopIteration:
        pass

    return y_past_data
    
y_past_data = getPastDataFromGen(tfGenEval, p.shape)
y_past_data.shape
# Out:
# INFO:root:File 'IE00B1FZS350.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# (5376, 2)

# %%
plt.plot(y_past_data[:,0])

# %%
plt.plot(y_past_data[:,1])

# %%
plt.plot(p[:,0])

# %%
plt.plot(p[:,1])

# %%
p.shape
# Out:
# (5376, 2)

# %%
tickDF = pd.read_csv(TRAIN_FILES[1])
tickDF
# Out:
#         startsAt    open    high     low   close  volume  quoteVolume
# 0     1217548800   80.95   80.95   80.95   80.95     0.0          0.0
# 1     1217635200   80.95   80.95   80.95   80.95     0.0          0.0
# 2     1217721600   80.95   80.95   80.95   80.95     0.0          0.0
# 3     1217808000   81.11   81.11   81.11   81.11     0.0          0.0
# 4     1217894400   81.10   81.10   81.10   81.10     0.0          0.0
# ...          ...     ...     ...     ...     ...     ...          ...
# 5316  1676851200  140.38  140.38  140.38  140.38     0.0          0.0
# 5317  1676937600  140.07  140.07  140.07  140.07     0.0          0.0
# 5318  1677024000  140.11  140.11  140.11  140.11     0.0          0.0
# 5319  1677110400  140.70  140.70  140.70  140.70     0.0          0.0
# 5320  1677196800  140.38  140.38  140.38  140.38     0.0          0.0
#
# [5321 rows x 7 columns]

# %%
tickDF.shape[0] - p.shape[0]
# Out:
# -55

# %%
tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
tickDFcropped
# Out:
#         startsAt    open    high     low   close  volume  quoteVolume
# 0     1217548800   80.95   80.95   80.95   80.95     0.0          0.0
# 1     1217635200   80.95   80.95   80.95   80.95     0.0          0.0
# 2     1217721600   80.95   80.95   80.95   80.95     0.0          0.0
# 3     1217808000   81.11   81.11   81.11   81.11     0.0          0.0
# 4     1217894400   81.10   81.10   81.10   81.10     0.0          0.0
# ...          ...     ...     ...     ...     ...     ...          ...
# 5316  1676851200  140.38  140.38  140.38  140.38     0.0          0.0
# 5317  1676937600  140.07  140.07  140.07  140.07     0.0          0.0
# 5318  1677024000  140.11  140.11  140.11  140.11     0.0          0.0
# 5319  1677110400  140.70  140.70  140.70  140.70     0.0          0.0
# 5320  1677196800  140.38  140.38  140.38  140.38     0.0          0.0
#
# [5321 rows x 7 columns]

# %%
# p_dir = p[:,0]
# p_dir_derivation = p[:,1]

p_future = p[:,0]
p_future_derivation = p[:,1]

# %%
# Plot the prediction again, now over the open price
chart_name="Predicted direction of price movement with open price"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name, fontsize=14)

_ = ax1.plot(p_future, color="green", label="Predicted p_future")
_ = ax1.plot(p_future_derivation, color="red", label="Predicted p_future_derivation")
# _ = ax1.plot(p_neutral, color="gray", label="Predicted neutral")

ax2 = ax1.twinx()

ax2.plot(tickDFcropped.loc[:,'open'].values, color="black", label="Price")

ax1.set_xlabel("Timesteps")
ax1.set_ylabel("Direction")
ax2.set_ylabel("Price")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc="upper left")

# Save the figure
# fig_name = "FileListToDataStreamExample_" + chart_name.replace(" ", "_").replace("'", "").replace("(", "").replace(")", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")

# %%
#@title Buy and sell signal thresholds
BUY_SIGNAL_THRESHOLD_FUTURE = 0.15 #@param {type:"number"}
BUY_SIGNAL_THRESHOLD_PAST = 0.01 #@param {type:"number"}

SELL_SIGNAL_THRESHOLD_PAST = 0.1 #@param {type:"number"}

# %%
#@title Plot buy and sell signals
chart_name="Buy and sell signals"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name)

x_datetimes = [datetime.datetime.fromtimestamp(ts) for ts in tickDFcropped.loc[:,'open'].index]

_ = ax1.plot(x_datetimes, tickDFcropped.loc[:,'open'].values, color="black", label="Price", linewidth=2)

# Color area axis
ax2 = ax1.twinx()

# Convert the float value prediction into rising and falling categories
yCategoryFall = p_past_gain >= SELL_SIGNAL_THRESHOLD_PAST
yCategoryRise = (p_future_gain > p_past_gain) & (p_past_gain <= BUY_SIGNAL_THRESHOLD_FUTURE) #(p_future_gain >= BUY_SIGNAL_THRESHOLD_FUTURE)

ax2.fill_between(x_datetimes, yCategoryFall , alpha=0.5, color="red", label="'Buy' signal")
ax2.fill_between(x_datetimes, yCategoryRise , alpha=0.5, color="green", label="'Sell' signal")

# Remove tick marks and set limits for color area axis
ax2.set_yticks([])
ax2.set_ylim(-0.05,1.05)

ax3 = ax1.twinx()
_ = ax3.plot(x_datetimes, p_future_gain, color="blue", label="Predicted future gain")
# _ = ax3.plot(x_datetimes, 10.0*p_dir_derivation, color="red", label="10.0 * Predicted price direction derivation")
# ax3.set_ylim(-1.05,1.05)

ax3.plot([np.min(x_datetimes), np.max(x_datetimes)], [0.0,0.0], color="gray")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax2.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc="upper left")

# Save the figure
# fig_name = chart_name.replace(" ", "_").replace("'", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 14
#      11 ax2 = ax1.twinx()
#      13 # Convert the float value prediction into rising and falling categories
# ---> 14 yCategoryFall = p_past_gain >= SELL_SIGNAL_THRESHOLD_PAST
#      15 yCategoryRise = (p_future_gain > p_past_gain) & (p_past_gain <= BUY_SIGNAL_THRESHOLD_FUTURE) #(p_future_gain >= BUY_SIGNAL_THRESHOLD_FUTURE)
#      17 ax2.fill_between(x_datetimes, yCategoryFall , alpha=0.5, color="red", label="'Buy' signal")
#
# NameError: name 'p_past_gain' is not defined

# %% [markdown]
# # Add predictions to tick tables

# %%
stop

# %%
# PREDICTED_SAVE_PATH = "/content/dataset/etffancy/PastFutureGainV2/test"

# %%
# !mkdir /content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB
# !mkdir /content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/test
# !mkdir /content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/eval

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
# https://stackoverflow.com/questions/52443273/how-do-you-send-arguments-to-a-generator-function-using-tf-data-dataset-from-gen

#fileList = EVAL_FILES
#PREDICTED_SAVE_PATH = "/content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/eval"

fileList = TEST_FILES
PREDICTED_SAVE_PATH = "/content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/test"

pd.options.mode.chained_assignment = None  # default='warn'

for file_index in tqdm(range(0, len(fileList))):
    try:
        filename = fileList[file_index]

        logging.info(f"\nFile name: '{filename}' for index {file_index}")

        tfGenEval = tf.data.Dataset.from_generator(lambda: pythonGeneratorEval(fileList=[filename]), 
                                                       output_types = (tf.float32, tf.float32),
                                                       output_shapes=(
                                                           (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                           (BATCH_SIZE, 4)
                                                           )
                                                       )
        p = model.predict(tfGenEval, verbose = 0)

        logging.info(f"p.shape: {p.shape}")

        p_future_gain = p[:,0]
        p_future_gain_derivation = p[:,1]
        
        # Load the tick table
        tickDF = pd.read_csv(filename)
        tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
        
        # Add the predicted future gain
        tickDFcropped.loc[:,"p_future_gain"] = p_future_gain
        tickDFcropped.loc[:,"p_future_gain_derivation"] = p_future_gain_derivation
        
        # Get the (known) past data
        y_past_data = getPastDataFromGen(tfGenEval, p.shape)

        # Add the past gain
        tickDFcropped.loc[:,"p_past_gain"] = y_past_data[:,0]
        tickDFcropped.loc[:,"p_past_gain_derivation"] = y_past_data[:,1]

        # Save the DF
        tickDFcropped.to_csv(os.path.join(PREDICTED_SAVE_PATH, filename.split(os.path.sep)[-1]))

        logging.info("Saved the predicted data.")
    except KeyboardInterrupt:
        raise
    except Exception as ex:
        logging.warning(str(ex))
# Out:
#   0%|                                                   | 0/266 [00:00<?, ?it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU1598688189.csv' for index 0
# INFO:root:File 'LU1598688189.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'LU1598688189.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   0%|▏                                          | 1/266 [00:10<48:34, 11.00s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B8CJW150.csv' for index 1
# INFO:root:File 'IE00B8CJW150.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8CJW150.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▎                                          | 2/266 [00:17<35:59,  8.18s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYYHSM20.csv' for index 2
# INFO:root:File 'IE00BYYHSM20.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYYHSM20.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▍                                          | 3/266 [00:20<26:50,  6.12s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMW42074.csv' for index 3
# INFO:root:File 'IE00BMW42074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BMW42074.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▋                                          | 4/266 [00:22<19:14,  4.41s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYSZ5T81.csv' for index 4
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BYSZ5T81.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▊                                          | 5/266 [00:27<19:25,  4.47s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMDBMY19.csv' for index 5
# INFO:root:File 'IE00BMDBMY19.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|▉                                          | 6/266 [00:27<13:52,  3.20s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF11F565.csv' for index 6
# INFO:root:File 'IE00BF11F565.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF11F565.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▏                                         | 7/266 [00:32<15:34,  3.61s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B44CGS96.csv' for index 7
# INFO:root:File 'IE00B44CGS96.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'IE00B44CGS96.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▎                                         | 8/266 [00:39<20:39,  4.81s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKM4GZ66.csv' for index 8
# INFO:root:File 'IE00BKM4GZ66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'IE00BKM4GZ66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▍                                         | 9/266 [00:45<21:29,  5.02s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010655712.csv' for index 9
# INFO:root:File 'FR0010655712.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4992, 2)
# INFO:root:File 'FR0010655712.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▌                                        | 10/266 [00:54<26:47,  6.28s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B8GKDB10.csv' for index 10
# INFO:root:File 'IE00B8GKDB10.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8GKDB10.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▋                                        | 11/266 [01:00<26:32,  6.25s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B1TXK627.csv' for index 11
# INFO:root:File 'IE00B1TXK627.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'IE00B1TXK627.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|█▉                                        | 12/266 [01:10<30:48,  7.28s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BLLZQ805.csv' for index 12
# INFO:root:File 'IE00BLLZQ805.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BLLZQ805.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██                                        | 13/266 [01:12<23:47,  5.64s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKWQ0J47.csv' for index 13
# INFO:root:File 'IE00BKWQ0J47.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'IE00BKWQ0J47.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██▏                                       | 14/266 [01:17<23:11,  5.52s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B53L4X51.csv' for index 14
# INFO:root:File 'IE00B53L4X51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B53L4X51.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▎                                       | 15/266 [01:25<26:01,  6.22s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BGYWT403.csv' for index 15
# INFO:root:File 'IE00BGYWT403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BGYWT403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▌                                       | 16/266 [01:27<21:36,  5.19s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B5MJYX09.csv' for index 16
# INFO:root:File 'IE00B5MJYX09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MJYX09.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▋                                       | 17/266 [01:36<25:28,  6.14s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYTH5S21.csv' for index 17
# INFO:root:File 'IE00BYTH5S21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|██▊                                       | 18/266 [01:36<18:36,  4.50s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1291109293.csv' for index 18
# INFO:root:File 'LU1291109293.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 
.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'IE00BKWQ0Q14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▎ | 255/266 [23:51<01:16,  6.97s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BWBXM617.csv' for index 255
# INFO:root:File 'IE00BWBXM617.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BWBXM617.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▍ | 256/266 [23:57<01:05,  6.52s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKY40J65.csv' for index 256
# INFO:root:File 'IE00BKY40J65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BKY40J65.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▌ | 257/266 [23:59<00:46,  5.22s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000G6GSP88.csv' for index 257
# INFO:root:File 'IE000G6GSP88.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  97%|███████████████████████████████████████▊ | 258/266 [23:59<00:30,  3.80s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000I8KRLL9.csv' for index 258
# INFO:root:File 'IE000I8KRLL9.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  97%|███████████████████████████████████████▉ | 259/266 [24:00<00:20,  2.90s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B3VWLG82.csv' for index 259
# INFO:root:File 'IE00B3VWLG82.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B3VWLG82.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████ | 260/266 [24:10<00:29,  4.99s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B3XM3R14.csv' for index 260
# INFO:root:File 'IE00B3XM3R14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B3XM3R14.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▏| 261/266 [24:19<00:31,  6.21s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BNC1F287.csv' for index 261
# INFO:root:File 'IE00BNC1F287.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BNC1F287.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▍| 262/266 [24:21<00:19,  4.93s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B87G8S03.csv' for index 262
# INFO:root:File 'IE00B87G8S03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3456, 2)
# INFO:root:File 'IE00B87G8S03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▌| 263/266 [24:28<00:16,  5.58s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B7K93397.csv' for index 263
# INFO:root:File 'IE00B7K93397.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3456, 2)
# INFO:root:File 'IE00B7K93397.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▋| 264/266 [24:35<00:12,  6.07s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0496786657.csv' for index 264
# INFO:root:File 'LU0496786657.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU0496786657.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|████████████████████████████████████████▊| 265/266 [24:44<00:06,  6.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0446734369.csv' for index 265
# INFO:root:File 'LU0446734369.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0446734369.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|█████████████████████████████████████████| 266/266 [24:53<00:00,  5.61s/it]

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
# https://stackoverflow.com/questions/52443273/how-do-you-send-arguments-to-a-generator-function-using-tf-data-dataset-from-gen

fileList = EVAL_FILES
PREDICTED_SAVE_PATH = "/content/dataset/etffancy/FPNWithAttentionBiggerTimebased_2_FutureOnly_60days_GPU_256LB/eval"

# fileList = TEST_FILES
# PREDICTED_SAVE_PATH = "/content/dataset/etffancy/FPNWithAttentionBiggerTimebased_1_FutureOnly/test"

pd.options.mode.chained_assignment = None  # default='warn'

for file_index in tqdm(range(0, len(fileList))):
    try:
        filename = fileList[file_index]

        logging.info(f"\nFile name: '{filename}' for index {file_index}")

        tfGenEval = tf.data.Dataset.from_generator(lambda: pythonGeneratorEval(fileList=[filename]), 
                                                       output_types = (tf.float32, tf.float32),
                                                       output_shapes=(
                                                           (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                           (BATCH_SIZE, 4)
                                                           )
                                                       )
        p = model.predict(tfGenEval, verbose = 0)

        logging.info(f"p.shape: {p.shape}")

        p_future_gain = p[:,0]
        p_future_gain_derivation = p[:,1]
        
        # Load the tick table
        tickDF = pd.read_csv(filename)
        tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
        
        # Add the predicted future gain
        tickDFcropped.loc[:,"p_future_gain"] = p_future_gain
        tickDFcropped.loc[:,"p_future_gain_derivation"] = p_future_gain_derivation
        
        # Get the (known) past data
        y_past_data = getPastDataFromGen(tfGenEval, p.shape)

        # Add the past gain
        tickDFcropped.loc[:,"p_past_gain"] = y_past_data[:,0]
        tickDFcropped.loc[:,"p_past_gain_derivation"] = y_past_data[:,1]

        # Save the DF
        tickDFcropped.to_csv(os.path.join(PREDICTED_SAVE_PATH, filename.split(os.path.sep)[-1]))

        logging.info("Saved the predicted data.")
    except KeyboardInterrupt:
        raise
    except Exception as ex:
        logging.warning(str(ex))
# Out:
#   0%|                                                   | 0/266 [00:00<?, ?it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE00B4KBBD01.csv' for index 0
# INFO:root:File 'IE00B4KBBD01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00B4KBBD01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   0%|▏                                          | 1/266 [00:03<17:36,  3.99s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62Y33.csv' for index 1
# INFO:root:File 'IE00B0M62Y33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5760, 2)
# INFO:root:File 'IE00B0M62Y33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▎                                          | 2/266 [00:15<35:55,  8.17s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BHZPJ346.csv' for index 2
# INFO:root:File 'IE00BHZPJ346.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BHZPJ346.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   1%|▍                                          | 3/266 [00:18<25:19,  5.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BZ6V7883.csv' for index 3
# INFO:root:File 'IE00BZ6V7883.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BZ6V7883.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▋                                          | 4/266 [00:22<23:05,  5.29s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2082997193.csv' for index 4
# INFO:root:File 'LU2082997193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2082997193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▊                                          | 5/266 [00:24<17:43,  4.07s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B1FZS681.csv' for index 5
# INFO:root:File 'IE00B1FZS681.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'IE00B1FZS681.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   2%|▉                                          | 6/266 [00:34<27:03,  6.24s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF2GFH28.csv' for index 6
# INFO:root:File 'IE00BF2GFH28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BF2GFH28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▏                                         | 7/266 [00:37<22:24,  5.19s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF4RFH31.csv' for index 7
# INFO:root:File 'IE00BF4RFH31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF4RFH31.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▎                                         | 8/266 [00:41<20:04,  4.67s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0011683594.csv' for index 8
# INFO:root:File 'NL0011683594.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'NL0011683594.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   3%|█▍                                         | 9/266 [00:46<19:49,  4.63s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0009690239.csv' for index 9
# INFO:root:File 'NL0009690239.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'NL0009690239.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▌                                        | 10/266 [00:53<24:07,  5.65s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BFWXDW46.csv' for index 10
# INFO:root:File 'IE00BFWXDW46.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BFWXDW46.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   4%|█▋                                        | 11/266 [00:57<20:51,  4.91s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0192223062.csv' for index 11
# INFO:root:File 'LU0192223062.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6528, 2)
# INFO:root:File 'LU0192223062.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|█▉                                        | 12/266 [01:09<30:01,  7.09s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BHXMHK04.csv' for index 12
# INFO:root:File 'IE00BHXMHK04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BHXMHK04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██                                        | 13/266 [01:12<24:39,  5.85s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BM9GRP64.csv' for index 13
# INFO:root:File 'IE00BM9GRP64.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BM9GRP64.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   5%|██▏                                       | 14/266 [01:14<19:22,  4.61s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010424135.csv' for index 14
# INFO:root:File 'FR0010424135.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'FR0010424135.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▎                                       | 15/266 [01:24<26:33,  6.35s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B94ZB998.csv' for index 15
# INFO:root:File 'IE00B94ZB998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B94ZB998.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▌                                       | 16/266 [01:31<26:49,  6.44s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYX8XC17.csv' for index 16
# INFO:root:File 'IE00BYX8XC17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BYX8XC17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   6%|██▋                                       | 17/266 [01:35<24:02,  5.79s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BHZPJ908.csv' for index 17
# INFO:root:File 'IE00BHZPJ908.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BHZPJ908.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   7%|██▊                                       | 18/266 [01:38<20:27,  4.95s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B1XNH568.csv' for index 18
# INFO:root:File 'IE00B1XNH568.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'IE00B1XNH568.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   7%|███                                       | 19/266 [01:48<26:47,  6.51s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0008470928.csv' for index 19
# INFO:root:File 'IE0008470928.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8064, 2)
# INFO:root:File 'IE0008470928.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▏                                      | 20/266 [02:03<36:55,  9.01s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BZ048579.csv' for index 20
# INFO:root:File 'IE00BZ048579.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BZ048579.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▎                                      | 21/266 [02:06<29:31,  7.23s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0530119774.csv' for index 21
# INFO:root:File 'LU0530119774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU0530119774.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   8%|███▍                                      | 22/266 [02:14<30:36,  7.53s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1273488715.csv' for index 22
# INFO:root:File 'LU1273488715.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'LU1273488715.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▋                                      | 23/266 [02:19<27:00,  6.67s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1291106356.csv' for index 23
# INFO:root:File 'LU1291106356.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'LU1291106356.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▊                                      | 24/266 [02:24<24:49,  6.15s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B5SSQT16.csv' for index 24
# INFO:root:File 'IE00B5SSQT16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'IE00B5SSQT16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#   9%|███▉                                      | 25/266 [02:31<26:28,  6.59s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0392496344.csv' for index 25
# INFO:root:File 'LU0392496344.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0392496344.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  10%|████                                      | 26/266 [02:41<29:39,  7.41s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000HMSHYJ6.csv' for index 26
# INFO:root:File 'IE000HMSHYJ6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  10%|████▎                                     | 27/266 [02:41<21:20,  5.36s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B27YCK28.csv' for index 27
# INFO:root:File 'IE00B27YCK28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4992, 2)
# INFO:root:File 'IE00B27YCK28.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▍                                     | 28/266 [02:51<26:48,  6.76s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000O58J820.csv' for index 28
# INFO:root:File 'IE000O58J820.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  11%|████▌                                     | 29/266 [02:52<19:14,  4.87s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B60SX394.csv' for index 29
# INFO:root:File 'IE00B60SX394.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B60SX394.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  11%|████▋                                     | 30/266 [03:01<24:12,  6.15s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B3YCGJ38.csv' for index 30
# INFO:root:File 'IE00B3YCGJ38.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B3YCGJ38.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|████▉                                     | 31/266 [03:09<26:49,  6.85s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0446734872.csv' for index 31
# INFO:root:File 'LU0446734872.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU0446734872.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████                                     | 32/266 [03:18<29:00,  7.44s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE0002635281.csv' for index 32
# INFO:root:File 'DE0002635281.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE0002635281.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  12%|█████▏                                    | 33/266 [03:30<33:39,  8.67s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M63177.csv' for index 33
# INFO:root:File 'IE00B0M63177.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5760, 2)
# INFO:root:File 'IE00B0M63177.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▎                                    | 34/266 [03:41<36:21,  9.40s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1737653045.csv' for index 34
# INFO:root:File 'LU1737653045.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1737653045.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  13%|█████▌                                    | 35/266 [03:44<29:30,  7.66s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF92J153.csv' for index 35
# INFO:root:File 'IE00BF92J153.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  14%|█████▋                                    | 36/266 [03:45<21:28,  5.60s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BWTN6Y99.csv' for index 36
# INFO:root:File 'IE00BWTN6Y99.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BWTN6Y99.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|█████▊                                    | 37/266 [03:51<21:02,  5.51s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BH04GL39.csv' for index 37
# INFO:root:File 'IE00BH04GL39.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BH04GL39.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  14%|██████                                    | 38/266 [03:54<18:09,  4.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BK5BQT80.csv' for index 38
# INFO:root:File 'IE00BK5BQT80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (768, 2)
# INFO:root:File 'IE00BK5BQT80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▏                                   | 39/266 [03:56<15:35,  4.12s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1829220216.csv' for index 39
# INFO:root:File 'LU1829220216.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'LU1829220216.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▎                                   | 40/266 [04:04<19:26,  5.16s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1681038243.csv' for index 40
# INFO:root:File 'LU1681038243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU1681038243.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  15%|██████▍                                   | 41/266 [04:12<23:00,  6.14s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000TVPSRI1.csv' for index 41
# INFO:root:File 'IE000TVPSRI1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  16%|██████▋                                   | 42/266 [04:13<16:38,  4.46s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2009202107.csv' for index 42
# INFO:root:File 'LU2009202107.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (768, 2)
# INFO:root:File 'LU2009202107.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  16%|██████▊                                   | 43/266 [04:15<14:33,  3.92s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B9M6RS56.csv' for index 43
# INFO:root:File 'IE00B9M6RS56.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B9M6RS56.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|██████▉                                   | 44/266 [04:22<17:20,  4.69s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A2QP323.csv' for index 44
# INFO:root:File 'DE000A2QP323.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'DE000A2QP323.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████                                   | 45/266 [04:24<13:57,  3.79s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF16M727.csv' for index 45
# INFO:root:File 'IE00BF16M727.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BF16M727.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  17%|███████▎                                  | 46/266 [04:26<11:54,  3.25s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF3N7102.csv' for index 46
# INFO:root:File 'IE00BF3N7102.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF3N7102.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▍                                  | 47/266 [04:29<12:12,  3.35s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMDBMK72.csv' for index 47
# INFO:root:File 'IE00BMDBMK72.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  18%|███████▌                                  | 48/266 [04:30<09:09,  2.52s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BFNM3K80.csv' for index 48
# INFO:root:File 'IE00BFNM3K80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BFNM3K80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  18%|███████▋                                  | 49/266 [04:33<09:44,  2.69s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000W95TAE6.csv' for index 49
# INFO:root:File 'IE000W95TAE6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  19%|███████▉                                  | 50/266 [04:33<07:25,  2.06s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2090062782.csv' for index 50
# INFO:root:File 'LU2090062782.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2090062782.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  19%|████████                                  | 51/266 [04:35<07:17,  2.04s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0005042456.csv' for index 51
# INFO:root:File 'IE0005042456.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8064, 2)
# INFO:root:File 'IE0005042456.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▏                                 | 52/266 [04:50<20:45,  5.82s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0F5UG3.csv' for index 52
# INFO:root:File 'DE000A0F5UG3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5760, 2)
# INFO:root:File 'DE000A0F5UG3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▎                                 | 53/266 [05:01<26:06,  7.35s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BZ163H91.csv' for index 53
# INFO:root:File 'IE00BZ163H91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BZ163H91.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  20%|████████▌                                 | 54/266 [05:06<23:03,  6.53s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B4L5ZY03.csv' for index 54
# INFO:root:File 'IE00B4L5ZY03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B4L5ZY03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▋                                 | 55/266 [05:14<25:23,  7.22s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B44Z5B48.csv' for index 55
# INFO:root:File 'IE00B44Z5B48.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'IE00B44Z5B48.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|████████▊                                 | 56/266 [05:22<25:51,  7.39s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B78JSG98.csv' for index 56
# INFO:root:File 'IE00B78JSG98.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3456, 2)
# INFO:root:File 'IE00B78JSG98.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  21%|█████████                                 | 57/266 [05:29<25:31,  7.33s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1650492330.csv' for index 57
# INFO:root:File 'LU1650492330.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'LU1650492330.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▏                                | 58/266 [05:34<22:28,  6.48s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2133056387.csv' for index 58
# INFO:root:File 'LU2133056387.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2133056387.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  22%|█████████▎                                | 59/266 [05:36<17:42,  5.13s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2109787635.csv' for index 59
# INFO:root:File 'LU2109787635.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2109787635.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▍                                | 60/266 [05:38<14:28,  4.22s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B5MJYY16.csv' for index 60
# INFO:root:File 'IE00B5MJYY16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MJYY16.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▋                                | 61/266 [05:47<19:11,  5.62s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYX5K108.csv' for index 61
# INFO:root:File 'IE00BYX5K108.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYX5K108.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  23%|█████████▊                                | 62/266 [05:51<17:24,  5.12s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMDBMN04.csv' for index 62
# INFO:root:File 'IE00BMDBMN04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BMDBMN04.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  24%
.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BF0M6N54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▍                            | 85/266 [07:45<15:21,  5.09s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYTRRF33.csv' for index 85
# INFO:root:File 'IE00BYTRRF33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BYTRRF33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  32%|█████████████▌                            | 86/266 [07:49<14:51,  4.95s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2082999132.csv' for index 86
# INFO:root:File 'LU2082999132.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2082999132.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|█████████████▋                            | 87/266 [07:51<12:06,  4.06s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMH5YR69.csv' for index 87
# INFO:root:File 'IE00BMH5YR69.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  33%|█████████████▉                            | 88/266 [07:52<09:00,  3.04s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYXVGX24.csv' for index 88
# INFO:root:File 'IE00BYXVGX24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BYXVGX24.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  33%|██████████████                            | 89/266 [07:56<09:48,  3.33s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1650487413.csv' for index 89
# INFO:root:File 'LU1650487413.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5760, 2)
# INFO:root:File 'LU1650487413.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▏                           | 90/266 [08:07<16:34,  5.65s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BVGC6645.csv' for index 90
# INFO:root:File 'IE00BVGC6645.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BVGC6645.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  34%|██████████████▎                           | 91/266 [08:13<16:12,  5.56s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1324516308.csv' for index 91
# INFO:root:File 'LU1324516308.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'LU1324516308.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▌                           | 92/266 [08:17<15:18,  5.28s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1602144732.csv' for index 92
# INFO:root:File 'LU1602144732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1602144732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▋                           | 93/266 [08:21<14:00,  4.86s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1832418773.csv' for index 93
# INFO:root:File 'LU1832418773.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU1832418773.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  35%|██████████████▊                           | 94/266 [08:29<16:59,  5.93s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B5B5TG76.csv' for index 94
# INFO:root:File 'IE00B5B5TG76.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B5B5TG76.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████                           | 95/266 [08:38<19:09,  6.72s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BWBXM278.csv' for index 95
# INFO:root:File 'IE00BWBXM278.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BWBXM278.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▏                          | 96/266 [08:43<17:42,  6.25s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B6SPMN59.csv' for index 96
# INFO:root:File 'IE00B6SPMN59.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3456, 2)
# INFO:root:File 'IE00B6SPMN59.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  36%|███████████████▎                          | 97/266 [08:50<18:08,  6.44s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYVQ9F29.csv' for index 97
# INFO:root:File 'IE00BYVQ9F29.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BYVQ9F29.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▍                          | 98/266 [08:53<15:18,  5.47s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0259322260.csv' for index 98
# INFO:root:File 'LU0259322260.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'LU0259322260.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  37%|███████████████▋                          | 99/266 [09:04<19:14,  6.91s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BYYXBF44.csv' for index 99
# INFO:root:File 'IE00BYYXBF44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BYYXBF44.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▍                         | 100/266 [09:08<17:10,  6.21s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BD45KH83.csv' for index 100
# INFO:root:File 'IE00BD45KH83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'IE00BD45KH83.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▌                         | 101/266 [09:12<14:50,  5.40s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1287023185.csv' for index 101
# INFO:root:File 'LU1287023185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'LU1287023185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  38%|███████████████▋                         | 102/266 [09:21<17:40,  6.47s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B6R52036.csv' for index 102
# INFO:root:File 'IE00B6R52036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'IE00B6R52036.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|███████████████▉                         | 103/266 [09:28<18:25,  6.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1812091194.csv' for index 103
# INFO:root:File 'LU1812091194.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU1812091194.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|████████████████                         | 104/266 [09:37<19:38,  7.28s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0908501058.csv' for index 104
# INFO:root:File 'LU0908501058.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'LU0908501058.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  39%|████████████████▏                        | 105/266 [09:43<18:59,  7.08s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1048313974.csv' for index 105
# INFO:root:File 'LU1048313974.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (768, 2)
# INFO:root:File 'LU1048313974.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  40%|████████████████▎                        | 106/266 [09:46<15:21,  5.76s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B1FZS574.csv' for index 106
# INFO:root:File 'IE00B1FZS574.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# ...
# INFO:root:File 'IE00BZCQB185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BZCQB185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  87%|███████████████████████████████████▌     | 231/266 [20:33<02:21,  4.03s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010524777.csv' for index 231
# INFO:root:File 'FR0010524777.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4992, 2)
# INFO:root:File 'FR0010524777.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  87%|███████████████████████████████████▊     | 232/266 [20:42<03:05,  5.46s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B8X9NW27.csv' for index 232
# INFO:root:File 'IE00B8X9NW27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'IE00B8X9NW27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|███████████████████████████████████▉     | 233/266 [20:48<03:05,  5.61s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0F5UJ7.csv' for index 233
# INFO:root:File 'DE000A0F5UJ7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7680, 2)
# INFO:root:File 'DE000A0F5UJ7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████     | 234/266 [21:01<04:07,  7.73s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011857234.csv' for index 234
# INFO:root:File 'FR0011857234.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'FR0011857234.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  88%|████████████████████████████████████▏    | 235/266 [21:06<03:35,  6.95s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0D8Q23.csv' for index 235
# INFO:root:File 'DE000A0D8Q23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:File 'DE000A0D8Q23.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▍    | 236/266 [21:16<03:56,  7.90s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0H08R2.csv' for index 236
# INFO:root:File 'DE000A0H08R2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7680, 2)
# INFO:root:File 'DE000A0H08R2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▌    | 237/266 [21:29<04:32,  9.41s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B4L5YX21.csv' for index 237
# INFO:root:File 'IE00B4L5YX21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B4L5YX21.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  89%|████████████████████████████████████▋    | 238/266 [21:37<04:10,  8.94s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010424143.csv' for index 238
# INFO:root:File 'FR0010424143.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5376, 2)
# INFO:root:File 'FR0010424143.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▊    | 239/266 [21:46<04:01,  8.95s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BF4G6Z54.csv' for index 239
# INFO:root:File 'IE00BF4G6Z54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'IE00BF4G6Z54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  90%|████████████████████████████████████▉    | 240/266 [21:48<03:04,  7.11s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMW3QX54.csv' for index 240
# INFO:root:File 'IE00BMW3QX54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'IE00BMW3QX54.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▏   | 241/266 [21:53<02:41,  6.45s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B14X4Q57.csv' for index 241
# INFO:root:File 'IE00B14X4Q57.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5760, 2)
# INFO:root:File 'IE00B14X4Q57.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  91%|█████████████████████████████████████▎   | 242/266 [22:03<02:57,  7.42s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKY81B71.csv' for index 242
# INFO:root:File 'IE00BKY81B71.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#  91%|█████████████████████████████████████▍   | 243/266 [22:04<02:03,  5.37s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BZ163G84.csv' for index 243
# INFO:root:File 'IE00BZ163G84.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'IE00BZ163G84.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▌   | 244/266 [22:08<01:49,  4.99s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1452600270.csv' for index 244
# INFO:root:File 'LU1452600270.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1920, 2)
# INFO:root:File 'LU1452600270.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▊   | 245/266 [22:12<01:38,  4.71s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKS7L097.csv' for index 245
# INFO:root:File 'IE00BKS7L097.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (768, 2)
# INFO:root:File 'IE00BKS7L097.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  92%|█████████████████████████████████████▉   | 246/266 [22:14<01:18,  3.93s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B6YX5K17.csv' for index 246
# INFO:root:File 'IE00B6YX5K17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3456, 2)
# INFO:root:File 'IE00B6YX5K17.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████   | 247/266 [22:20<01:28,  4.66s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B5MTXK03.csv' for index 247
# INFO:root:File 'IE00B5MTXK03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:File 'IE00B5MTXK03.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  93%|██████████████████████████████████████▏  | 248/266 [22:28<01:41,  5.64s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BMDFDY08.csv' for index 248
# INFO:root:File 'IE00BMDFDY08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BMDFDY08.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▍  | 249/266 [22:30<01:15,  4.47s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B2NPKV68.csv' for index 249
# INFO:root:File 'IE00B2NPKV68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4992, 2)
# INFO:root:File 'IE00B2NPKV68.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▌  | 250/266 [22:38<01:31,  5.74s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKM4H197.csv' for index 250
# INFO:root:File 'IE00BKM4H197.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2688, 2)
# INFO:root:File 'IE00BKM4H197.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  94%|██████████████████████████████████████▋  | 251/266 [22:44<01:23,  5.55s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B3WMTH43.csv' for index 251
# INFO:root:File 'IE00B3WMTH43.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B3WMTH43.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▊  | 252/266 [22:51<01:25,  6.13s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0H08F7.csv' for index 252
# INFO:root:File 'DE000A0H08F7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6912, 2)
# INFO:root:File 'DE000A0H08F7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|██████████████████████████████████████▉  | 253/266 [23:03<01:41,  7.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BHZRR030.csv' for index 253
# INFO:root:File 'IE00BHZRR030.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (768, 2)
# INFO:root:File 'IE00BHZRR030.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  95%|███████████████████████████████████████▏ | 254/266 [23:05<01:13,  6.16s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1804202403.csv' for index 254
# INFO:root:File 'LU1804202403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1152, 2)
# INFO:root:File 'LU1804202403.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▎ | 255/266 [23:08<00:57,  5.19s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0603933895.csv' for index 255
# INFO:root:File 'LU0603933895.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'LU0603933895.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  96%|███████████████████████████████████████▍ | 256/266 [23:15<00:56,  5.70s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B53L3W79.csv' for index 256
# INFO:root:File 'IE00B53L3W79.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'IE00B53L3W79.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▌ | 257/266 [23:23<00:56,  6.27s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011550193.csv' for index 257
# INFO:root:File 'FR0011550193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:File 'FR0011550193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▊ | 258/266 [23:28<00:48,  6.05s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B44CND37.csv' for index 258
# INFO:root:File 'IE00B44CND37.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3840, 2)
# INFO:root:File 'IE00B44CND37.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  97%|███████████████████████████████████████▉ | 259/266 [23:35<00:43,  6.25s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BWBXM500.csv' for index 259
# INFO:root:File 'IE00BWBXM500.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2304, 2)
# INFO:root:File 'IE00BWBXM500.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████ | 260/266 [23:39<00:34,  5.76s/it]INFO:root:
# File name: '/content/dataset/etffancy/DE000A0F5UK5.csv' for index 260
# INFO:root:File 'DE000A0F5UK5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6912, 2)
# INFO:root:File 'DE000A0F5UK5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▏| 261/266 [23:51<00:37,  7.57s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU2082999215.csv' for index 261
# INFO:root:File 'LU2082999215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'LU2082999215.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  98%|████████████████████████████████████████▍| 262/266 [23:53<00:23,  5.83s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00BKY58G26.csv' for index 262
# INFO:root:File 'IE00BKY58G26.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (384, 2)
# INFO:root:File 'IE00BKY58G26.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▌| 263/266 [23:55<00:13,  4.60s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1659681669.csv' for index 263
# INFO:root:File 'LU1659681669.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (1536, 2)
# INFO:root:File 'LU1659681669.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████▋| 264/266 [23:58<00:08,  4.19s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU0378438732.csv' for index 264
# INFO:root:File 'LU0378438732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4992, 2)
# INFO:root:File 'LU0378438732.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|████████████████████████████████████████▊| 265/266 [24:06<00:05,  5.39s/it]INFO:root:
# File name: '/content/dataset/etffancy/LU1681048804.csv' for index 265
# INFO:root:File 'LU1681048804.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4224, 2)
# INFO:root:File 'LU1681048804.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:Saved the predicted data.
# 100%|█████████████████████████████████████████| 266/266 [24:14<00:00,  5.47s/it]
