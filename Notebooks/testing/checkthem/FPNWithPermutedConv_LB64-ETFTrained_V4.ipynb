# %% [markdown]
# # Mount drive and bucket
# Todo: Remove in public version

# %%
# Check if the notebook is run in Google Colab
import sys

COLAB = 'google.colab' in sys.modules

# %%
import sys
import datetime
import logging

nblog = open(f"/content/bigdata/nb_{datetime.datetime.utcnow().strftime('%Y%m%d_%H%M')}.log", "a+")
print(nblog)
sys.stdout.echo = nblog
sys.stderr.echo = nblog

#get_ipython().log.handlers[0].stream = nblog
#get_ipython().log.setLevel(logging.INFO)

# %autosave 60
# Out:
# <_io.TextIOWrapper name='/content/bigdata/nb_20230302_0939.log' mode='a+' encoding='UTF-8'>
# Autosaving every 60 seconds

# %%
# if COLAB:
#   from google.colab import drive
#   drive.mount('/content/drive')

# %%
if COLAB:
  from google.colab import auth
  auth.authenticate_user()
else:
    print("Run the command!")
  #Todo #bring the command inside the notebook
  #run this terminal inside docker: gcloud auth login b.girsule@gmail.com --no-launch-browser
# Out:
# Run the command!

# %%
# Todo: Check if possible in local docker
# from google.cloud import storage

# %%
# Check if the tf version is 2.10.0, this is required to use the 'ignore_class' in the  SparseCategoricalCrossentropy
import tensorflow as tf

if '2.10.0' != tf.__version__:
  # !pip uninstall tensorflow -y
  # !pip install tensorflow-gpu==2.10.0
  please_restart_the_runtime
else:
  print("TF Version is 2.10.0, ok!")
# Out:
# 2023-03-02 09:39:57.228839: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 09:39:57.355469: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-02 09:39:57.989672: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-02 09:39:57.989750: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-02 09:39:57.989772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TF Version is 2.10.0, ok!

# %%
from tensorflow import keras
# import tensorflow_gcs_config
from tensorflow.python.lib.io import file_io

from keras.layers import Input, Dense, Flatten #, ReLU, Add, Flatten, Concatenate, LayerNormalization, UpSampling2D, Activation, LSTM, Multiply, Dropout, Reshape, Permute, BatchNormalization, MaxPooling1D, AveragePooling1D, MaxPooling3D, AveragePooling2D, LayerNormalization, MaxPooling2D
from keras.models import Model
from keras.optimizers import Adam

# %%
import os
from os import listdir
from os.path import isfile, join

# %%
import pandas as pd
import numpy as np
import copy
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import gc

# %%
# Set the google cloud bucket data
project_id = 'tweetprediction'
bucket_name = 'crypto_nlp_training'

# %%
# Set the checkpoint path for saving train progress
if COLAB:
    CHECKPOINT_PATH = f"gs://{bucket_name}/chk/"
else:
    CHECKPOINT_PATH = f"/content/bigdata/chk/"

# %%
# Check if the notebook is run in google colab, if so, clone the repo
if COLAB:
    print("Running in Colab")

    # Clone the whole repo to get all data and code if not already done
    if not os.path.exists("/content/CryptoCrystalBall"):
      # !git clone https://github.com/girsigit/CryptoCrystalBall

      # cd into the notebooks directory --> Necessary to match all paths for importing
    #%cd /content/CryptoCrystalBall/JupyterDocker/notebooks
    # %cd /content

# %%
# Try importing the Ta-Lib library, if this fails, try to install it and
# import it again afterwards
try:
    import talib
except:
    # !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
    # !tar -xzvf ta-lib-0.4.0-src.tar.gz
    # %cd ta-lib
    # !./configure --prefix=/usr
    # !make
    # !make install
    # !pip install Ta-Lib
    # %cd ..

    import talib

# %%
try:
  from transformers import TFRobertaModel, RobertaConfig
except:
  # Important!: Version 4.23 does not work on TPU
  # !pip install transformers==4.22

  from transformers import TFRobertaModel, RobertaConfig

# %%
# !pip uninstall -y tensorboard-plugin-profile

# %%
# # Required to do profiling
# !pip install tensorboard-plugin-profile

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ---
# # Add custom import path for DataStreamCreator and IndicatorCalculator
#
# These libs are not in the standard python directory, so their paths have to be added to the import paths

# %%
# # Get the current directory
# current_dir = os.getcwd()
# current_dir_splitted = current_dir.split(os.sep)

# Todo: is inside /content/CB in local docker
current_dir_splitted = ["", "content"]
current_dir_splitted
# Out:
# ['', 'content']

# %%
# Create the import directories for the DataStreamCreator and the IndicatorCalculator
dsc_dir = '/content/CryptoCrystalBall/DataStreamCreator'
print(f"dsc_dir: {dsc_dir}")

ind_dir = '/content/CryptoCrystalBall/IndicatorCalculator'
print(f"ind_dir: {ind_dir}")

# Add them to the import paths
sys.path.insert(0, dsc_dir)
sys.path.insert(0, ind_dir)
# Out:
# dsc_dir: /content/CryptoCrystalBall/DataStreamCreator
# ind_dir: /content/CryptoCrystalBall/IndicatorCalculator

# %%
# Import the actual classes
from IndicatorCalculator import IndicatorCalculator
import DataStreamCreator

# %% [markdown]
# ---
# # Define all the parameters and variables

# %%
# Define the tick data path
DATA_PATH = os.path.join(os.sep, *current_dir_splitted, 'DemoData')
print(f"DATA_PATH: {DATA_PATH}")
# Out:
# DATA_PATH: /content/DemoData

# %%
# Define the chart image save path
IMG_SAVE_PATH = os.path.join(os.sep, *current_dir_splitted, 'Documentation', 'Images')
print(f"IMG_SAVE_PATH: {IMG_SAVE_PATH}")
# Out:
# IMG_SAVE_PATH: /content/Documentation/Images

# %%
# Define a global random seed
RANDOM_SEED = 42+2

# Set the seed in np
np.random.seed(RANDOM_SEED)

# %%
# X_BLOCK_LENGHT defines how far into the past a 'slice of a chart' shall be
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator#xblockgenerator
X_BLOCK_LENGHT = 64

# %%
# How many examples shall be processed at the same time, limited by GPU memory
BATCH_SIZE = 512

# %%
# A fixed number of features is used
FEATURES = 160

# %%
# Finanical indicator timespans
# See: https://github.com/girsigit/CryptoCrystalBall/tree/main/IndicatorCalculator
SHORTSPAN = 7
MIDSPAN = 38
LONGSPAN = 50

# %%
# Additional settings for the data stream
# For this notebook, the calculation of pattern indicators is turned off
DATA_STREAM_PARAMETERS = {
    "calcPatternIndicators": False, # No patterns are used
    "calcVolumeInidators": False, # No volume indicators, these are wide spread and may disturb the classifer
    "dropna": True # Drop all tick/indicator table rows containing nan values instead of just replacing them by 0 (which would lead to wrong predictions)
}

# %% [markdown]
# # Load the train dataset

# %%
# # Check if the dataset already has been copy, if not, copy it
# if not os.path.exists("/content/dataset") or not os.path.exists("/content/dataset/Train"):
#   !mkdir /content/dataset
#   !mkdir /content/dataset/Train
#   !gsutil -m cp -r gs://cryptocrystalball_public/CryptoDataset/Hourly/significant_currencies.txt /content/dataset/significant_currencies.txt
#   !gsutil -m cp -r gs://cryptocrystalball_public/CryptoDataset/Hourly/Train/* /content/dataset/Train/

# %%
# #@markdown ### Use only significant currencies
# #@markdown Load a manually defined list of significant currencies (`significant_currencies.txt`).
# #@markdown This list contains no currencies which little or no volume or price movement, to
# #@markdown avoid training on data sample which would never be used to trade on in a real 
# #@markdown application.

# #@markdown If enabled, only currency pairs with the base currency USDT are laoded,
# #@markdown this is important to prevent interference between different cryptocurrencies.
# #@markdown For example, in `BTC-ETH.csv`, there is influence of both the BTC and the ETH price, but we want to predict trade signals based on a 'real' currency (USDT is kind of the same as USD).

# significant_only = True #@param {type:"boolean"}

# if significant_only:
#   with open("/content/dataset/significant_currencies.txt") as f:
#     SIGNIFICANT_CURRS = f.read().splitlines()

#   print(f"Loaded {len(SIGNIFICANT_CURRS)} significant files names.")

# %%
# # Get train file names - Only pick the ones ending with -USDT to prevent
# # influence between different currencies
# TRAIN_PATH = "/content/dataset/Train"

# # Get all file names
# TRAIN_FILES = [os.path.join(TRAIN_PATH,f) for f in listdir(TRAIN_PATH) if isfile(join(TRAIN_PATH, f)) and ".csv" in f ]

# # Filter for significant currencies only
# if significant_only:
#   TRAIN_FILES = [f for f in TRAIN_FILES if f.split("/")[-1].replace(".csv","") in SIGNIFICANT_CURRS]

# # Filter for USDT-based ones only
# TRAIN_FILES = [f for f in TRAIN_FILES if "-USDT" in f]

# # Sort them (as a stable basis for randomizing afterwards)
# TRAIN_FILES = sorted(TRAIN_FILES)

# print(f"The train dataset contains {len(TRAIN_FILES)} files.")
# print(TRAIN_FILES[:3])

# %%
# Get train file names - Only pick the ones ending with -USDT to prevent
# influence between different currencies
TRAIN_PATH = "/content/dataset/etffancy"

# Get all file names
TRAIN_FILES = [os.path.join(TRAIN_PATH,f) for f in listdir(TRAIN_PATH) if isfile(join(TRAIN_PATH, f)) and ".csv" in f ]

# Sort them (as a stable basis for randomizing afterwards)
TRAIN_FILES = sorted(TRAIN_FILES)

print(f"The train dataset contains {len(TRAIN_FILES)} files.")
print(TRAIN_FILES[:3])
# Out:
# The train dataset contains 1064 files.
# ['/content/dataset/etffancy/DE0002635265.csv', '/content/dataset/etffancy/DE0002635273.csv', '/content/dataset/etffancy/DE0002635281.csv']

# %% [markdown]
# ---
# # Prepare data source
#
# For training a neural network, first the data source has to be prepared. For this purpose, the method `FileListToDataStream` from the `DataStreamCreator` class is used. This method creates a stream of `X-Block` and `y-data` arrays out of a list of .csv file names, pointing to tick tables (called `EXAMPLE_FILE_PATHS` in this example). For details about `X-Blocks` and `y-data`, please refer to the documentation of the `XBlockGenerator` and the `YDataGenerator` under https://github.com/girsigit/CryptoCrystalBall/tree/main/DataStreamCreator.
#
# <br>
#
# Target values (y-data) from the data generator would not be necessary in this notebook, but since it cannot be switched off, the future direction and its derviation of the price have been chosen in `Y_TYPE_DICT` since they are not expensive to compute. A switch flag will be added in a future release.

# %%
# Set direction and derivation information as y target
# Both y values (direction & derivation) are in the interval [-1.0,1.0]

Y_TYPE_DICT = copy.deepcopy(DataStreamCreator.YDataGenerator.PARAM_DICT_TEMPLATE_Y_DATA_TYPE_DIRECTION_FLOAT)
Y_TYPE_DICT
# Out:
# {'dataType': 0,
#  'direction_ma_timespan': 200,
#  'derivation_ma_timespan': 100,
#  'direction_derivation_shift_span': 0}

# %%
TARGET_FEATURE_CNT = 256

# %%
XShape = (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT)
XShape
# Out:
# (512, 64, 256)

# %%
# A python generator function has to be applied on the dataStream

def pythonGeneratorMLMTraining():
  # Initialize the FileListToDataStream generator
  dataStreamTraining = DataStreamCreator.FileListToDataStream(fileList = TRAIN_FILES,
                                                      batch_size = BATCH_SIZE,
                                                      X_Block_lenght = X_BLOCK_LENGHT,
                                                      y_type_dict=Y_TYPE_DICT,
                                                      shuffle=True,
                                                      parallel_generators = np.min([BATCH_SIZE, 8]),
                                                      random_seed = RANDOM_SEED,
                                                      **DATA_STREAM_PARAMETERS
                                                      )

  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStreamTraining)
      _X = ne['X']
      _y = ne['y']
    
      # 'Blow up' the X array to a 2**n size
      _X_new = np.zeros((_X.shape[0], _X.shape[1], TARGET_FEATURE_CNT))
      _X_new[:,:,:_X.shape[2]] = _X

      yield (_X_new, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
tfGenTraining = tf.data.Dataset.from_generator(pythonGeneratorMLMTraining, 
                                               output_types = (tf.int32, tf.float32),
                                               output_shapes=(
                                                   (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                   (BATCH_SIZE, 2)
                                                   )
                                               )
tfGenTraining.prefetch(buffer_size=2)
tfGenTraining
# Out:
# 2023-03-02 09:39:59.747130: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-02 09:39:59.747158: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: cd3c62ddcfb6
# 2023-03-02 09:39:59.747166: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: cd3c62ddcfb6
# 2023-03-02 09:39:59.747289: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.108.3
# 2023-03-02 09:39:59.747309: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.108.3
# 2023-03-02 09:39:59.747316: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 510.108.3
# 2023-03-02 09:39:59.747788: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <FlatMapDataset element_spec=(TensorSpec(shape=(512, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(512, 2), dtype=tf.float32, name=None))>

# %%
# it = tfGenTraining.as_numpy_iterator()
# ne = next(it)

# %%
# ne[0]

# %%
# ne[1]

# %%
# plt.hist(ne[0].flatten())

# %%
# plt.hist(ne[1].flatten())

# %%
# wurst = np.array(ne[1])
# wurst[ne[0] != MASK_TOKEN_ID] = -1
# wurst

# %%
# np.sum(ne[0][0,:] == 3)

# %% [markdown]
# ---
# # Create the neural network
#
# In the example, two Conv1D pyramids are used to extract features at different levels out of the feature and the time dimension.
#
# It is also possible to use different architecures, like LSTM, Conv2D, Attention-Based ones or even NLP-based models. I have already tried many different ones and will publish them into the model zoo.
#
# ```
# Todo: Create Model Zoo
# ```
#
# ```
# Todo: Create Image of netwrok structure
# ```

# %%
# from keras.layers import Input, Dense, ReLU, Add, Flatten, Concatenate, LayerNormalization, UpSampling2D, Activation, LSTM, Multiply, Dropout, Reshape, Permute, BatchNormalization, MaxPooling1D, AveragePooling1D, MaxPooling3D, AveragePooling2D, LayerNormalization, MaxPooling2D, UnitNormalization, UpSampling1D
from keras.layers import UnitNormalization, Permute, Conv1D, UpSampling1D, Add, LSTM

# %%
# Create the FPNWithFScaledInput model
# Infos about the feature pyramid: https://jonathan-hui.medium.com/understanding-feature-pyramid-networks-for-object-detection-fpn-45b227b9106c

def CreateModelFPNWithFScaledInput():
  # Define model parameters
  mp = {
      "NAME": "FPNWithFScaledInput",
      "VERSION": "5_ETF_Trained_ConcRegr",
      "CNN_INITIAL_FILTERS": 32, 
      "CNN_EXTRACTOR_LAYERS": 6,
      "CNN_INITIAL_KERNEL_SIZE": 2,
      "CNN_MAX_KERNEL_SIZE": 8,
      "FEATURE_PYRAMID_START_INDEX": 2,
      "HEAD_LSTM_SIZE": 32,
      "HEAD_DENSE_SIZE": 8
      }
  
  # Create the model input  
  inputTicksAndIndicators = Input(shape=(X_BLOCK_LENGHT, TARGET_FEATURE_CNT), name='inputTicksAndIndicators', dtype='float32')

  # Normalize the input data, as it has a wide value spread (range of 1e8)
  normalized = UnitNormalization(name="UnitNormalizationInput", axis=-2)(inputTicksAndIndicators)

  # Permute it to Conv over Features
  normalized = Permute((2, 1), name="PermuteInput")(normalized)

  # ----------------------------------------------------------------------------

  # As an example a 1D-CNN pyramid is used to extract higher-level features out
  # of the indicator+tick dimension
  conv_layers = []
  aligned_layers = []
  feature_map_layers = []
  anti_aliased_layers = []
  anti_aliased_pyramid_indices = []
  regressor_layers = []

  finalFilters = mp["CNN_INITIAL_FILTERS"] * 2**(mp["FEATURE_PYRAMID_START_INDEX"])
  print(finalFilters)

  for i in range(mp["CNN_EXTRACTOR_LAYERS"]):
    if 0 == i:
      source_layer = normalized
    else:
      source_layer = feature_conv
    
    filters = int(mp["CNN_INITIAL_FILTERS"]*(2**i))
    kernel_size = mp["CNN_INITIAL_KERNEL_SIZE"]*(2**i)
    kernel_size = int(np.min([mp["CNN_MAX_KERNEL_SIZE"], kernel_size]))
    strides = int(np.min([2,kernel_size]))

    print(f"Step {i}, using {filters} filters with a kernel size of {kernel_size} at strides of {strides}")

    feature_conv = Conv1D(filters=filters,
                          kernel_size=kernel_size,
                          strides=strides, 
                          padding="same",
                          name=f"Feature_Conv1D_{i}")(source_layer)
    
    conv_layers.append(feature_conv)

    # Apply the feature extraction pyramid
    if mp["FEATURE_PYRAMID_START_INDEX"] <= i:
      # Apply a 1x1 convolution to align the channel depth    
      if feature_conv.shape[-1] != finalFilters:
        aligned_layer = Conv1D(filters=finalFilters,
                              kernel_size=1,
                              strides=1,
                              padding="same",
                              name=f"Channel_Depth_Alignment_{i}")(feature_conv)
      else:
        aligned_layer = feature_conv
      
      aligned_layers.append(aligned_layer)

  # Go top-down through the aligned_layers to create the feature_map_layers
  for i in range(mp["CNN_EXTRACTOR_LAYERS"]-1, mp["FEATURE_PYRAMID_START_INDEX"]-1, -1):
    aligned_layers_index = i - mp["FEATURE_PYRAMID_START_INDEX"]
    aligned_layer = aligned_layers[aligned_layers_index]

    print(f"Building feature_map_layers, step {i}. Shape of aligned_layer: {aligned_layer.shape}")

    # The highest-filtered layer is taken as feature map directly
    if i == mp["CNN_EXTRACTOR_LAYERS"]-1:
      feature_map_layers.append(aligned_layer)
      anti_aliased_layers.append(feature_map_layers[-1])
    else:
      # Take the last feature_map_layer and scale it by two
      upsampled = UpSampling1D(size=2,
                               name=f"Pyramid_Upsampling_{i}")(feature_map_layers[-1])

      # Add the aligned_layer
      added = Add(name=f"Pyramid_Add_{i}")([upsampled, aligned_layer])

      # Append as new feature_map_layer
      feature_map_layers.append(added)

      # Apply a convolution with a kernel size of 3 to "reduce the aliasing effect"
      anti_aliased_layer = Conv1D(filters=feature_map_layers[-1].shape[-1],
                                  kernel_size=3,
                                  strides=1,
                                  padding="same",
                                  name=f"Anti_Alias_{i}")(feature_map_layers[-1])

      anti_aliased_layers.append(anti_aliased_layer)

    # Helper storage to keep pyramid index consistent, also in predictor/regressor
    anti_aliased_pyramid_indices.append(i)

  # Apply the predictor head to each feature dimension layer
  for n in range(len(anti_aliased_layers)):
    predictor_input = anti_aliased_layers[n]

    # Get the pyramid index
    pyramid_index = anti_aliased_pyramid_indices[n]

    # Permute the Conv output back
    predictor_input = Permute((2, 1), name=f"PermutePredictorInput_{pyramid_index}")(predictor_input)

    predictor = LSTM(units=mp["HEAD_LSTM_SIZE"],
                     name=f"Predictor_Head_{pyramid_index}_LSTM")(predictor_input)
    
    # Direction and derivation regressor
    regressor = Dense(units=mp["HEAD_DENSE_SIZE"],
                      name=f"Predictor_Head_{pyramid_index}_Dense_Regressor",
                      activation='relu')(predictor)
    
    regressor_layers.append(regressor)
  
  # Add all regressors together
  regressor_added = Add(name="Add_regressors")(regressor_layers)
 
  # The output are two values (direction and derivation) in the range [-1.0, 1.0]
  output = Dense(2, activation='tanh', name="Output")(regressor_added)
  outputs = [output]

  # Combine it all into a model object
  model = Model(inputs=inputTicksAndIndicators, outputs=outputs, name=mp["NAME"] + "_" + str(mp["VERSION"]))

  return model, mp

model, model_config = CreateModelFPNWithFScaledInput()
print(model_config)
model.summary(line_length=220)
# Out:
# 128
# Step 0, using 32 filters with a kernel size of 2 at strides of 2
# Step 1, using 64 filters with a kernel size of 4 at strides of 2
# Step 2, using 128 filters with a kernel size of 8 at strides of 2
# Step 3, using 256 filters with a kernel size of 8 at strides of 2
# Step 4, using 512 filters with a kernel size of 8 at strides of 2
# Step 5, using 1024 filters with a kernel size of 8 at strides of 2
# Building feature_map_layers, step 5. Shape of aligned_layer: (None, 4, 128)
# Building feature_map_layers, step 4. Shape of aligned_layer: (None, 8, 128)
# Building feature_map_layers, step 3. Shape of aligned_layer: (None, 16, 128)
# Building feature_map_layers, step 2. Shape of aligned_layer: (None, 32, 128)
# {'NAME': 'FPNWithFScaledInput', 'VERSION': '5_ETF_Trained_ConcRegr', 'CNN_INITIAL_FILTERS': 32, 'CNN_EXTRACTOR_LAYERS': 6, 'CNN_INITIAL_KERNEL_SIZE': 2, 'CNN_MAX_KERNEL_SIZE': 8, 'FEATURE_PYRAMID_START_INDEX': 2, 'HEAD_LSTM_SIZE': 32, 'HEAD_DENSE_SIZE': 8}
# Model: "FPNWithFScaledInput_5_ETF_Trained_ConcRegr"
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                           Output Shape                                     Param #                   Connected to
# ============================================================================================================================================================================================================================
#  inputTicksAndIndicators (InputLayer)                                   [(None, 64, 256)]                                0                         []
#
#  UnitNormalizationInput (UnitNormalization)                             (None, 64, 256)                                  0                         ['inputTicksAndIndicators[0][0]']
#
#  PermuteInput (Permute)                                                 (None, 256, 64)                                  0                         ['UnitNormalizationInput[0][0]']
#
#  Feature_Conv1D_0 (Conv1D)                                              (None, 128, 32)                                  4128                      ['PermuteInput[0][0]']
#
#  Feature_Conv1D_1 (Conv1D)                                              (None, 64, 64)                                   8256                      ['Feature_Conv1D_0[0][0]']
#
#  Feature_Conv1D_2 (Conv1D)                                              (None, 32, 128)                                  65664                     ['Feature_Conv1D_1[0][0]']
#
#  Feature_Conv1D_3 (Conv1D)                                              (None, 16, 256)                                  262400                    ['Feature_Conv1D_2[0][0]']
#
#  Feature_Conv1D_4 (Conv1D)                                              (None, 8, 512)                                   1049088                   ['Feature_Conv1D_3[0][0]']
#
#  Feature_Conv1D_5 (Conv1D)                                              (None, 4, 1024)                                  4195328                   ['Feature_Conv1D_4[0][0]']
#
#  Channel_Depth_Alignment_5 (Conv1D)                                     (None, 4, 128)                                   131200                    ['Feature_Conv1D_5[0][0]']
#
#  Pyramid_Upsampling_4 (UpSampling1D)                                    (None, 8, 128)                                   0                         ['Channel_Depth_Alignment_5[0][0]']
#
#  Channel_Depth_Alignment_4 (Conv1D)                                     (None, 8, 128)                                   65664                     ['Feature_Conv1D_4[0][0]']
#
#  Pyramid_Add_4 (Add)                                                    (None, 8, 128)                                   0                         ['Pyramid_Upsampling_4[0][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_4[0][0]']
#
#  Pyramid_Upsampling_3 (UpSampling1D)                                    (None, 16, 128)                                  0                         ['Pyramid_Add_4[0][0]']
#
#  Channel_Depth_Alignment_3 (Conv1D)                                     (None, 16, 128)                                  32896                     ['Feature_Conv1D_3[0][0]']
#
#  Pyramid_Add_3 (Add)                                                    (None, 16, 128)                                  0                         ['Pyramid_Upsampling_3[0][0]',
#                                                                                                                                                     'Channel_Depth_Alignment_3[0][0]']
#
#  Pyramid_Upsampling_2 (UpSampling1D)                                    (None, 32, 128)                                  0                         ['Pyramid_Add_3[0][0]']
#
#  Pyramid_Add_2 (Add)                                                    (None, 32, 128)                                  0                         ['Pyramid_Upsampling_2[0][0]',
#                                                                                                                                                     'Feature_Conv1D_2[0][0]']
#
#  Anti_Alias_4 (Conv1D)                                                  (None, 8, 128)                                   49280                     ['Pyramid_Add_4[0][0]']
#
#  Anti_Alias_3 (Conv1D)                                                  (None, 16, 128)                                  49280                     ['Pyramid_Add_3[0][0]']
#
#  Anti_Alias_2 (Conv1D)                                                  (None, 32, 128)                                  49280                     ['Pyramid_Add_2[0][0]']
#
#  PermutePredictorInput_5 (Permute)                                      (None, 128, 4)                                   0                         ['Channel_Depth_Alignment_5[0][0]']
#
#  PermutePredictorInput_4 (Permute)                                      (None, 128, 8)                                   0                         ['Anti_Alias_4[0][0]']
#
#  PermutePredictorInput_3 (Permute)                                      (None, 128, 16)                                  0                         ['Anti_Alias_3[0][0]']
#
#  PermutePredictorInput_2 (Permute)                                      (None, 128, 32)                                  0                         ['Anti_Alias_2[0][0]']
#
#  Predictor_Head_5_LSTM (LSTM)                                           (None, 32)                                       4736                      ['PermutePredictorInput_5[0][0]']
#
#  Predictor_Head_4_LSTM (LSTM)                                           (None, 32)                                       5248                      ['PermutePredictorInput_4[0][0]']
#
#  Predictor_Head_3_LSTM (LSTM)                                           (None, 32)                                       6272                      ['PermutePredictorInput_3[0][0]']
#
#  Predictor_Head_2_LSTM (LSTM)                                           (None, 32)                                       8320                      ['PermutePredictorInput_2[0][0]']
#
#  Predictor_Head_5_Dense_Regressor (Dense)                               (None, 8)                                        264                       ['Predictor_Head_5_LSTM[0][0]']
#
#  Predictor_Head_4_Dense_Regressor (Dense)                               (None, 8)                                        264                       ['Predictor_Head_4_LSTM[0][0]']
#
#  Predictor_Head_3_Dense_Regressor (Dense)                               (None, 8)                                        264                       ['Predictor_Head_3_LSTM[0][0]']
#
#  Predictor_Head_2_Dense_Regressor (Dense)                               (None, 8)                                        264                       ['Predictor_Head_2_LSTM[0][0]']
#
#  Add_regressors (Add)                                                   (None, 8)                                        0                         ['Predictor_Head_5_Dense_Regressor[0][0]',
#                                                                                                                                                     'Predictor_Head_4_Dense_Regressor[0][0]',
#                                                                                                                                                     'Predictor_Head_3_Dense_Regressor[0][0]',
#                                                                                                                                                     'Predictor_Head_2_Dense_Regressor[0][0]']
#
#  Output (Dense)                                                         (None, 2)                                        18                        ['Add_regressors[0][0]']
#
# ============================================================================================================================================================================================================================
# Total params: 5,988,114
# Trainable params: 5,988,114
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
# model.load_weights("/content/bigdata/chk/FPNWithFScaledInput_3_GPU_64LB/cp_daily_valid_202_end/model.h5")

# %%
# model.get_layer("CryptoRoberta").set_weights(modelMLM.get_layer("tf_roberta_model").get_weights())

# %%
# model.get_layer("CryptoRoberta").trainable=False

# %%
# model.summary()

# %%
# model.save("/content/bigdata/RobertaToDirDerv_1_init.h5")

# %%
# model.load_weights("/content/bigdata/RobertaToDirDerv_1_init.h5")
#model.load_weights("/content/bigdata/chk/RobertaToDirDerv_1_GPU_512LB_10000VC_MaskedPrediction/cp_daily_valid_00_18000/model.h5")

# %% [markdown]
# # Train the model

# %% [markdown]
# ### Train strategy in the paper
# https://huggingface.co/roberta-base
#
# The model was trained on 1024 V100 GPUs for 500K steps with a batch size of 8K and a sequence length of 512. The optimizer used is Adam with a learning rate of 6e-4, β1=0.9\beta_{1} = 0.9β1​=0.9, β2=0.98\beta_{2} = 0.98β2​=0.98 and ϵ=1e−6\epsilon = 1e-6ϵ=1e−6, a weight decay of 0.01, learning rate warmup for 24,000 steps and linear decay of the learning rate after.

# %%
CHKPNT_NAME = f"{model.name}_GPU_{X_BLOCK_LENGHT}LB"
CHKPNT_NAME
# Out:
# 'FPNWithFScaledInput_5_ETF_Trained_ConcRegr_GPU_64LB'

# %%
# Set an optimizer
optimizer = Adam(
    learning_rate=5e-03,
    epsilon=1e-06,
    beta_1=0.9,
    beta_2=0.98,
    decay=0.01)

# %%
# Compile the model
model.compile(
    optimizer = optimizer,
    loss = ["mse"], 
    metrics=["mae"])

# %%
# model.summary(line_length=220)

# %%
#@title CustomCallback
class CustomCallback(tf.keras.callbacks.Callback):
  def __init__(self, save_freq, val_freq, checkpoint_path, model_name, epoch_add=0):
    self.save_freq = save_freq
    self.val_freq = val_freq
    self.checkpoint_path = checkpoint_path
    self.model_name = model_name
    self.current_epoch = 0
    self.epoch_add = epoch_add

  def on_epoch_begin(self, epoch, logs=None):
    self.current_epoch = epoch + self.epoch_add
    # keys = list(logs.keys())
    # print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

  def on_epoch_end(self, epoch, logs=None):
    self.saveTheModel(-1, logs)

  def on_train_batch_end(self, batch, logs=None):
    self.saveTheModel(batch, logs)

  def saveTheModel(self, batch, logs=None):
    if (0 < batch and 0 == batch % self.save_freq) or (0 > batch):
      logging.info(str(datetime.datetime.utcnow()))
    
      if 0 > batch:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_end".format(self.current_epoch)
                                    )
      else:
        _save_folder = os.path.join(self.checkpoint_path,
                                    self.model_name,
                                    "cp_daily_valid_{:02d}_{:05d}".format(self.current_epoch, batch)
                                    )
      
      fp = os.path.join(_save_folder, "model.h5")
      model.save(fp)
      logging.info(f"Saved model to '{fp}'")
      
      # Save optimizer config
      # c = copy.deepcopy(self.model.optimizer.get_config())

      fp = os.path.join(_save_folder, "c.pickle")
      with file_io.FileIO(fp, mode='wb+') as handle:
        pickle.dump(self.model.optimizer.get_config(), handle, protocol=pickle.HIGHEST_PROTOCOL)
        
      logging.info(f"Saved optimizer config to '{fp}'")

      # Save optimizer weights
      # w = copy.deepcopy(self.model.optimizer.get_weights())

      fp = os.path.join(_save_folder, "w.pickle")
      with open(fp, "wb") as handle:
        # with file_io.FileIO(fp, mode='wb+') as handle:
        pickle.dump(self.model.optimizer.get_weights(), handle, protocol=pickle.HIGHEST_PROTOCOL)
      
      logging.info(f"Saved optimizer weights to '{fp}'")
        
      logging.info(f"Did a gc collect: {gc.collect()}")

    # if 0 < batch and 0 == batch % self.val_freq:
    #   print("-------------------------EVAL-------------------------")
    #   model.evaluate(tfgenTest)
    #   print("\n-------------------------EVAL-------------------------")

# %%
gc.collect()
# Out:
# 3242

# %%
# CLASS_WEIGHTS_DICT = None
# CLASS_WEIGHTS_DICT = {}

# for i, cw in enumerate(CLASS_WEIGHTS[0,0,:]):
#   CLASS_WEIGHTS_DICT[i] = cw

# %%
epoch_add = 0

# %%
CALLBACK_EVERY_N_BATCHES = 1000

# %%
cc = CustomCallback(checkpoint_path = CHECKPOINT_PATH,
                    model_name = CHKPNT_NAME,
                    save_freq = CALLBACK_EVERY_N_BATCHES,
                    val_freq = CALLBACK_EVERY_N_BATCHES,
                    epoch_add = epoch_add)

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %reload_ext tensorboard

# %% [markdown]
# The TensorBoard UI is displayed in a browser window. In this colab, perform the following steps to prepare to capture profile information.
# 1.  Click on the dropdown menu box on the top right side and scroll down and click PROFILE. A new window appears that shows: **No profile data was found** at the top.
# 1.  Click on the CAPTURE PROFILE button. A new dialog appears. The top input line shows: **Profile Service URL or TPU name**. Copy and paste the Profile Service URL (the service_addr value shown before launching TensorBoard) into the top input line. While still on the dialog box, start the training with the next step.
# 1.  Click on the next colab cell to start training the model.
# 1.  Watch the output from the training until several epochs have completed. This allows time for the profile data to start being collected. Return to the dialog box and click on the CAPTURE button. If the capture succeeds, the page will auto refresh and redirect you to the profiling results.

# %%
# Todo: Create more elegant solution
log_dir = "gs://ticks_with_indicators_with_volume/logs/TPU/" + CHKPNT_NAME + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

if not COLAB:
    log_dir = os.path.join("/content/bigdata/log",log_dir.split("/")[-1])

log_dir
# Out:
# '/content/bigdata/log/FPNWithFScaledInput_5_ETF_Trained_ConcRegr_GPU_64LB20230302-094001'

# %%
import datetime

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    update_freq=CALLBACK_EVERY_N_BATCHES,
    profile_batch=(5,100)
    )
# Out:
# 2023-03-02 09:40:01.102207: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-03-02 09:40:01.102250: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-03-02 09:40:01.104605: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.

# %%
# CLASS_WEIGHTS_DICT = None

# %%
model.load_weights("/content/bigdata/chk/FPNWithFScaledInput_4_ETF_Trained_GPU_64LB/cp_daily_valid_03_04000/model.h5")

# %%
# %tensorboard --logdir $log_dir --host 0.0.0.0 --port 6006

# %%
# model.optimizer.learning_rate = 5e-4

# %%
# model.fit(tfGenTraining,
#           epochs=200,
#           verbose = 1,
#           callbacks=[tensorboard_callback, cc])

# %% [markdown]
# # Predict all train files

# %%
# A python generator function has to be applied on the dataStream
def pythonGeneratorEval(fileList):
  # Initialize the FileListToDataStream generator
  dataStreamEval= DataStreamCreator.FileListToDataStream(fileList = fileList,
                                                      batch_size = BATCH_SIZE,
                                                      X_Block_lenght = X_BLOCK_LENGHT,
                                                      y_type_dict=Y_TYPE_DICT,
                                                      shuffle=False,
                                                      parallel_generators = 1,
                                                      random_seed = RANDOM_SEED,
                                                      **DATA_STREAM_PARAMETERS
                                                      )
  
  # This while has to integrated into the FileListToDataStream method
  while True:  
    try:
      ne = next(dataStreamEval)
      _X = ne['X']
      _y = ne['y']
    
      # 'Blow up' the X array to a 2**n size
      _X_new = np.zeros((_X.shape[0], _X.shape[1], TARGET_FEATURE_CNT))
      _X_new[:,:,:_X.shape[2]] = _X

      yield (_X_new, _y)
    except StopIteration as si:
      logging.warning("StopIteration in pythonGenerator")
      logging.warning(si)
      return

# %%
file_index = 330

# %%
PREDICTED_SAVE_PATH = "/content/dataset/etffancy/predicted_V4"

# %%
# Create a Tensorflow dataset out of the python generator, which can be fed to the network
# https://stackoverflow.com/questions/52443273/how-do-you-send-arguments-to-a-generator-function-using-tf-data-dataset-from-gen

pd.options.mode.chained_assignment = None  # default='warn'

for file_index in tqdm(range(87, len(TRAIN_FILES))):
    try:
        filename = TRAIN_FILES[file_index]

        logging.info(f"\nFile name: '{filename}' for index {file_index}")

        tfGenEval = tf.data.Dataset.from_generator(lambda: pythonGeneratorEval(fileList=[filename]), 
                                                       output_types = (tf.float32, tf.float32),
                                                       output_shapes=(
                                                           (BATCH_SIZE, X_BLOCK_LENGHT, TARGET_FEATURE_CNT),
                                                           (BATCH_SIZE, 2)
                                                           )
                                                       )
        p = model.predict(tfGenEval, verbose = 0)

        logging.info(f"p.shape: {p.shape}")

        p_dir = p[:,0]
        p_dir_derivation = p[:,1]

        tickDF = pd.read_csv(filename)
        tickDFcropped = tickDF.iloc[-p.shape[0]:, :]

        tickDFcropped.loc[:,"p_dir"] = p_dir
        tickDFcropped.loc[:,"p_dir_derivation"] = p_dir_derivation

        tickDFcropped.to_csv(os.path.join(PREDICTED_SAVE_PATH, filename.split(os.path.sep)[-1]))

        logging.info("Saved the predicted data.")
    except KeyboardInterrupt:
        raise
    except Exception as ex:
        logging.warning(str(ex))
# Out:
#   0%|                                                                                                                                                                                                                 | 0/977 [00:00<?, ?it/s]INFO:root:
# File name: '/content/dataset/etffancy/FR0010342592.csv' for index 87
# INFO:root:File 'FR0010342592.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:Saved the predicted data.
#   0%|▏                                                                                                                                                                                                      | 1/977 [00:03<1:01:59,  3.81s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010361683.csv' for index 88
# INFO:root:File 'FR0010361683.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:Saved the predicted data.
#   0%|▍                                                                                                                                                                                                      | 2/977 [00:07<1:00:24,  3.72s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010424135.csv' for index 89
# INFO:root:File 'FR0010424135.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:Saved the predicted data.
#   0%|▌                                                                                                                                                                                                      | 3/977 [00:11<1:00:36,  3.73s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010424143.csv' for index 90
# INFO:root:File 'FR0010424143.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:Saved the predicted data.
#   0%|▊                                                                                                                                                                                                      | 4/977 [00:15<1:01:09,  3.77s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010429068.csv' for index 91
# INFO:root:File 'FR0010429068.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5632, 2)
# INFO:root:Saved the predicted data.
#   1%|█                                                                                                                                                                                                      | 5/977 [00:18<1:01:18,  3.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010510800.csv' for index 92
# INFO:root:File 'FR0010510800.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:Saved the predicted data.
#   1%|█▏                                                                                                                                                                                                       | 6/977 [00:22<59:31,  3.68s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010524777.csv' for index 93
# INFO:root:File 'FR0010524777.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:Saved the predicted data.
#   1%|█▍                                                                                                                                                                                                       | 7/977 [00:25<58:23,  3.61s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010527275.csv' for index 94
# INFO:root:File 'FR0010527275.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:Saved the predicted data.
#   1%|█▋                                                                                                                                                                                                       | 8/977 [00:29<57:32,  3.56s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010655712.csv' for index 95
# INFO:root:File 'FR0010655712.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (5120, 2)
# INFO:root:Saved the predicted data.
#   1%|█▊                                                                                                                                                                                                     | 9/977 [00:33<1:01:47,  3.83s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010869495.csv' for index 96
# INFO:root:File 'FR0010869495.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:Saved the predicted data.
#   1%|██                                                                                                                                                                                                      | 10/977 [00:36<57:38,  3.58s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0010869578.csv' for index 97
# INFO:root:File 'FR0010869578.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4608, 2)
# INFO:root:Saved the predicted data.
#   1%|██▎                                                                                                                                                                                                     | 11/977 [00:39<55:09,  3.43s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011475078.csv' for index 98
# INFO:root:File 'FR0011475078.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   1%|██▍                                                                                                                                                                                                     | 12/977 [00:41<49:12,  3.06s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011550185.csv' for index 99
# INFO:root:File 'FR0011550185.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   1%|██▋                                                                                                                                                                                                     | 13/977 [00:44<45:01,  2.80s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011550193.csv' for index 100
# INFO:root:File 'FR0011550193.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   1%|██▊                                                                                                                                                                                                     | 14/977 [00:46<42:10,  2.63s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011607084.csv' for index 101
# INFO:root:File 'FR0011607084.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   2%|███                                                                                                                                                                                                     | 15/977 [00:48<40:07,  2.50s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011660927.csv' for index 102
# INFO:root:File 'FR0011660927.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   2%|███▎                                                                                                                                                                                                    | 16/977 [00:50<38:43,  2.42s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011720911.csv' for index 103
# INFO:root:File 'FR0011720911.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:Saved the predicted data.
#   2%|███▍                                                                                                                                                                                                    | 17/977 [00:52<36:16,  2.27s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0011857234.csv' for index 104
# INFO:root:File 'FR0011857234.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
#   2%|███▋                                                                                                                                                                                                    | 18/977 [00:55<36:05,  2.26s/it]INFO:root:
# File name: '/content/dataset/etffancy/FR0013041530.csv' for index 105
# INFO:root:File 'FR0013041530.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:Saved the predicted data.
#   2%|███▉                                                                                                                                                                                                    | 19/977 [00:56<34:22,  2.15s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0001VXZTV7.csv' for index 106
# INFO:root:File 'IE0001VXZTV7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|████                                                                                                                                                                                                    | 20/977 [00:57<25:47,  1.62s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0002MXIF34.csv' for index 107
# INFO:root:File 'IE0002MXIF34.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|████▎                                                                                                                                                                                                   | 21/977 [00:57<19:54,  1.25s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0002PG6CA6.csv' for index 108
# INFO:root:File 'IE0002PG6CA6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|████▌                                                                                                                                                                                                   | 22/977 [00:58<16:00,  1.01s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0003Z9E2Y3.csv' for index 109
# INFO:root:File 'IE0003Z9E2Y3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|████▋                                                                                                                                                                                                   | 23/977 [00:58<13:16,  1.20it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE0004U3TX15.csv' for index 110
# INFO:root:File 'IE0004U3TX15.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   2%|████▉                                                                                                                                                                                                   | 24/977 [00:58<11:02,  1.44it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE0005042456.csv' for index 111
# INFO:root:File 'IE0005042456.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:Saved the predicted data.
#   3%|█████                                                                                                                                                                                                   | 25/977 [01:04<32:30,  2.05s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00077FRP95.csv' for index 112
# INFO:root:File 'IE00077FRP95.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|█████▎                                                                                                                                                                                                  | 26/977 [01:04<24:39,  1.56s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0007P4PBU1.csv' for index 113
# INFO:root:File 'IE0007P4PBU1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|█████▌                                                                                                                                                                                                  | 27/977 [01:04<19:06,  1.21s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0008470928.csv' for index 114
# INFO:root:File 'IE0008470928.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:Saved the predicted data.
#   3%|█████▋                                                                                                                                                                                                  | 28/977 [01:10<38:12,  2.42s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0008471009.csv' for index 115
# INFO:root:File 'IE0008471009.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (8192, 2)
# INFO:root:Saved the predicted data.
#   3%|█████▉                                                                                                                                                                                                  | 29/977 [01:15<51:48,  3.28s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0008T6IUX0.csv' for index 116
# INFO:root:File 'IE0008T6IUX0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|██████▏                                                                                                                                                                                                 | 30/977 [01:15<38:03,  2.41s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0009MG7KH8.csv' for index 117
# INFO:root:File 'IE0009MG7KH8.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|██████▎                                                                                                                                                                                                 | 31/977 [01:16<28:26,  1.80s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000APK27S2.csv' for index 118
# INFO:root:File 'IE000APK27S2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|██████▌                                                                                                                                                                                                 | 32/977 [01:16<21:55,  1.39s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000BPQIAA3.csv' for index 119
# INFO:root:File 'IE000BPQIAA3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|██████▊                                                                                                                                                                                                 | 33/977 [01:17<17:14,  1.10s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE000BWKUES1.csv' for index 120
# INFO:root:File 'IE000BWKUES1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   3%|██████▉                                                                                                                                                                                                 | 34/977 [01:17<14:00,  1.12it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000EBFYWX3.csv' for index 121
# INFO:root:File 'IE000EBFYWX3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|███████▏                                                                                                                                                                                                | 35/977 [01:17<11:47,  1.33it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000FNVOB27.csv' for index 122
# INFO:root:File 'IE000FNVOB27.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|███████▎                                                                                                                                                                                                | 36/977 [01:18<10:07,  1.55it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000G6GSP88.csv' for index 123
# INFO:root:File 'IE000G6GSP88.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|███████▌                                                                                                                                                                                                | 37/977 [01:18<08:56,  1.75it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000GOJO2A3.csv' for index 124
# INFO:root:File 'IE000GOJO2A3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|███████▊                                                                                                                                                                                                | 38/977 [01:19<08:06,  1.93it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000H1H16W5.csv' for index 125
# INFO:root:File 'IE000H1H16W5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|███████▉                                                                                                                                                                                                | 39/977 [01:19<07:31,  2.08it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000HJV1VH3.csv' for index 126
# INFO:root:File 'IE000HJV1VH3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|████████▏                                                                                                                                                                                               | 40/977 [01:19<07:12,  2.16it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000HMSHYJ6.csv' for index 127
# INFO:root:File 'IE000HMSHYJ6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|████████▍                                                                                                                                                                                               | 41/977 [01:20<06:55,  2.25it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000I8KRLL9.csv' for index 128
# INFO:root:File 'IE000I8KRLL9.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|████████▌                                                                                                                                                                                               | 42/977 [01:20<06:56,  2.24it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000IM4K4K2.csv' for index 129
# INFO:root:File 'IE000IM4K4K2.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   4%|████████▊                                                                                                                                                                                               | 43/977 [01:21<06:50,  2.27it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000JZ473P7.csv' for index 130
# INFO:root:File 'IE000JZ473P7.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|█████████                                                                                                                                                                                               | 44/977 [01:21<06:40,  2.33it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000KDY10O3.csv' for index 131
# INFO:root:File 'IE000KDY10O3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|█████████▏                                                                                                                                                                                              | 45/977 [01:22<06:40,  2.33it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000KPJJWM6.csv' for index 132
# INFO:root:File 'IE000KPJJWM6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|█████████▍                                                                                                                                                                                              | 46/977 [01:22<06:30,  2.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000L2ZNB07.csv' for index 133
# INFO:root:File 'IE000L2ZNB07.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|█████████▌                                                                                                                                                                                              | 47/977 [01:22<06:20,  2.44it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000L5NW549.csv' for index 134
# INFO:root:File 'IE000L5NW549.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|█████████▊                                                                                                                                                                                              | 48/977 [01:23<06:28,  2.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000M0ZXLY9.csv' for index 135
# INFO:root:File 'IE000M0ZXLY9.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|██████████                                                                                                                                                                                              | 49/977 [01:23<06:22,  2.43it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000MWUQBJ0.csv' for index 136
# INFO:root:File 'IE000MWUQBJ0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|██████████▏                                                                                                                                                                                             | 50/977 [01:24<06:15,  2.47it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000NDWFGA5.csv' for index 137
# INFO:root:File 'IE000NDWFGA5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|██████████▍                                                                                                                                                                                             | 51/977 [01:24<06:15,  2.46it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000NRGX9M3.csv' for index 138
# INFO:root:File 'IE000NRGX9M3.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|██████████▋                                                                                                                                                                                             | 52/977 [01:24<06:10,  2.50it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000O58J820.csv' for index 139
# INFO:root:File 'IE000O58J820.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   5%|██████████▊                                                                                                                                                                                             | 53/977 [01:25<06:11,  2.49it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000QNJAOX1.csv' for index 140
# INFO:root:File 'IE000QNJAOX1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|███████████                                                                                                                                                                                             | 54/977 [01:25<06:07,  2.51it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000QRNAC66.csv' for index 141
# INFO:root:File 'IE000QRNAC66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|███████████▎                                                                                                                                                                                            | 55/977 [01:26<06:11,  2.48it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000QUOSE01.csv' for index 142
# INFO:root:File 'IE000QUOSE01.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|███████████▍                                                                                                                                                                                            | 56/977 [01:26<06:10,  2.48it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000ST40PX8.csv' for index 143
# INFO:root:File 'IE000ST40PX8.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|███████████▋                                                                                                                                                                                            | 57/977 [01:26<06:06,  2.51it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000TLLSP66.csv' for index 144
# INFO:root:File 'IE000TLLSP66.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|███████████▊                                                                                                                                                                                            | 58/977 [01:27<06:01,  2.54it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000TVPSRI1.csv' for index 145
# INFO:root:File 'IE000TVPSRI1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|████████████                                                                                                                                                                                            | 59/977 [01:27<06:02,  2.53it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000UQND7H4.csv' for index 146
# INFO:root:File 'IE000UQND7H4.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|████████████▎                                                                                                                                                                                           | 60/977 [01:28<06:06,  2.50it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000UU299V4.csv' for index 147
# INFO:root:File 'IE000UU299V4.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|████████████▍                                                                                                                                                                                           | 61/977 [01:28<06:11,  2.46it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000VTOHNZ0.csv' for index 148
# INFO:root:File 'IE000VTOHNZ0.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|████████████▋                                                                                                                                                                                           | 62/977 [01:28<06:06,  2.50it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000W95TAE6.csv' for index 149
# INFO:root:File 'IE000W95TAE6.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   6%|████████████▉                                                                                                                                                                                           | 63/977 [01:29<06:14,  2.44it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000XFORJ80.csv' for index 150
# INFO:root:File 'IE000XFORJ80.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|█████████████                                                                                                                                                                                           | 64/977 [01:29<06:06,  2.49it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000XGNMWE1.csv' for index 151
# INFO:root:File 'IE000XGNMWE1.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|█████████████▎                                                                                                                                                                                          | 65/977 [01:30<06:10,  2.46it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000YDZG487.csv' for index 152
# INFO:root:File 'IE000YDZG487.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|█████████████▌                                                                                                                                                                                          | 66/977 [01:30<06:10,  2.46it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE000YKE1AQ5.csv' for index 153
# INFO:root:File 'IE000YKE1AQ5.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# WARNING:root:Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.
#   7%|█████████████▋                                                                                                                                                                                          | 67/977 [01:30<06:10,  2.46it/s]INFO:root:
# File name: '/content/dataset/etffancy/IE0031442068.csv' for index 154
# INFO:root:File 'IE0031442068.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:Saved the predicted data.
#   7%|█████████████▉                                                                                                                                                                                          | 68/977 [01:35<25:09,  1.66s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0032077012.csv' for index 155
# INFO:root:File 'IE0032077012.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:Saved the predicted data.
#   7%|██████████████                                                                                                                                                                                          | 69/977 [01:40<38:27,  2.54s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0032523478.csv' for index 156
# INFO:root:File 'IE0032523478.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:Saved the predicted data.
#   7%|██████████████▎                                                                                                                                                                                         | 70/977 [01:44<47:35,  3.15s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE0032895942.csv' for index 157
# INFO:root:File 'IE0032895942.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (7168, 2)
# INFO:root:Saved the predicted data.
#   7%|██████████████▌                                                                                                                                                                                         | 71/977 [01:49<54:21,  3.60s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B02KXH56.csv' for index 158
# INFO:root:File 'IE00B02KXH56.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6656, 2)
# INFO:root:Saved the predicted data.
#   7%|██████████████▋                                                                                                                                                                                         | 72/977 [01:53<56:56,  3.78s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B02KXK85.csv' for index 159
# INFO:root:File 'IE00B02KXK85.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   7%|██████████████▉                                                                                                                                                                                         | 73/977 [01:57<58:20,  3.87s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B02KXL92.csv' for index 160
# INFO:root:File 'IE00B02KXL92.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|███████████████▏                                                                                                                                                                                        | 74/977 [02:01<59:14,  3.94s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B02KXM00.csv' for index 161
# INFO:root:File 'IE00B02KXM00.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|███████████████▎                                                                                                                                                                                        | 75/977 [02:05<59:45,  3.98s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62Q58.csv' for index 162
# INFO:root:File 'IE00B0M62Q58.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|███████████████▌                                                                                                                                                                                        | 76/977 [02:09<59:58,  3.99s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62S72.csv' for index 163
# INFO:root:File 'IE00B0M62S72.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|███████████████▌                                                                                                                                                                                      | 77/977 [02:13<1:00:08,  4.01s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62V02.csv' for index 164
# INFO:root:File 'IE00B0M62V02.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|███████████████▉                                                                                                                                                                                        | 78/977 [02:17<59:53,  4.00s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62X26.csv' for index 165
# INFO:root:File 'IE00B0M62X26.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|████████████████                                                                                                                                                                                      | 79/977 [02:21<1:00:00,  4.01s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M62Y33.csv' for index 166
# INFO:root:File 'IE00B0M62Y33.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (6144, 2)
# INFO:root:Saved the predicted data.
#   8%|████████████████▏                                                                                                                                                                                     | 80/977 [02:25<1:00:04,  4.02s/it]INFO:root:
# File name: '/content/dataset/etffancy/IE00B0M63060.csv' for index 167
# INFO:root:File 'IE00B0M63060.csv' loaded, 0 left
# ...
# File name: '/content/dataset/etffancy/LU2090062949.csv' for index 1032
# INFO:root:File 'LU2090062949.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋      | 946/977 [30:47<00:22,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2090063160.csv' for index 1033
# INFO:root:File 'LU2090063160.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉      | 947/977 [30:47<00:21,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2090063327.csv' for index 1034
# INFO:root:File 'LU2090063327.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████      | 948/977 [30:48<00:21,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2090063673.csv' for index 1035
# INFO:root:File 'LU2090063673.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 949/977 [30:49<00:20,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2109786827.csv' for index 1036
# INFO:root:File 'LU2109786827.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌     | 950/977 [30:50<00:19,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2109787635.csv' for index 1037
# INFO:root:File 'LU2109787635.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 951/977 [30:50<00:18,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2133056387.csv' for index 1038
# INFO:root:File 'LU2133056387.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉     | 952/977 [30:51<00:18,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2182388236.csv' for index 1039
# INFO:root:File 'LU2182388236.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 953/977 [30:52<00:17,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2182388319.csv' for index 1040
# INFO:root:File 'LU2182388319.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 954/977 [30:52<00:16,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2182388400.csv' for index 1041
# INFO:root:File 'LU2182388400.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 955/977 [30:53<00:16,  1.37it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2182388582.csv' for index 1042
# INFO:root:File 'LU2182388582.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋    | 956/977 [30:54<00:15,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2194447293.csv' for index 1043
# INFO:root:File 'LU2194447293.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉    | 957/977 [30:55<00:14,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2197908721.csv' for index 1044
# INFO:root:File 'LU2197908721.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 958/977 [30:55<00:13,  1.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2198883410.csv' for index 1045
# INFO:root:File 'LU2198883410.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 959/977 [30:56<00:13,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2206597713.csv' for index 1046
# INFO:root:File 'LU2206597713.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌   | 960/977 [30:57<00:12,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2206597804.csv' for index 1047
# INFO:root:File 'LU2206597804.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 961/977 [30:58<00:11,  1.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2206598109.csv' for index 1048
# INFO:root:File 'LU2206598109.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 962/977 [30:58<00:10,  1.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2233156749.csv' for index 1049
# INFO:root:File 'LU2233156749.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 963/977 [30:59<00:10,  1.38it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2244386053.csv' for index 1050
# INFO:root:File 'LU2244386053.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 964/977 [31:00<00:09,  1.39it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2244387457.csv' for index 1051
# INFO:root:File 'LU2244387457.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌  | 965/977 [31:00<00:08,  1.40it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2250132763.csv' for index 1052
# INFO:root:File 'LU2250132763.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊  | 966/977 [31:01<00:07,  1.40it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2265794276.csv' for index 1053
# INFO:root:File 'LU2265794276.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 967/977 [31:02<00:07,  1.42it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2297533809.csv' for index 1054
# INFO:root:File 'LU2297533809.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 968/977 [31:03<00:06,  1.41it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2300294316.csv' for index 1055
# INFO:root:File 'LU2300294316.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 969/977 [31:03<00:05,  1.42it/s]INFO:root:
# File name: '/content/dataset/etffancy/LU2356220926.csv' for index 1056
# INFO:root:File 'LU2356220926.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (512, 2)
# INFO:root:Saved the predicted data.
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 970/977 [31:04<00:04,  1.43it/s]INFO:root:
# File name: '/content/dataset/etffancy/NL0009690239.csv' for index 1057
# INFO:root:File 'NL0009690239.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:Saved the predicted data.
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 971/977 [31:07<00:08,  1.35s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0009690247.csv' for index 1058
# INFO:root:File 'NL0009690247.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:Saved the predicted data.
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 972/977 [31:10<00:08,  1.77s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0009690254.csv' for index 1059
# INFO:root:File 'NL0009690254.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (4096, 2)
# INFO:root:Saved the predicted data.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏| 973/977 [31:12<00:08,  2.10s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0010273801.csv' for index 1060
# INFO:root:File 'NL0010273801.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3584, 2)
# INFO:root:Saved the predicted data.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 974/977 [31:15<00:06,  2.22s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0010408704.csv' for index 1061
# INFO:root:File 'NL0010408704.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (3072, 2)
# INFO:root:Saved the predicted data.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 975/977 [31:17<00:04,  2.21s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0010731816.csv' for index 1062
# INFO:root:File 'NL0010731816.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2560, 2)
# INFO:root:Saved the predicted data.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 976/977 [31:19<00:02,  2.15s/it]INFO:root:
# File name: '/content/dataset/etffancy/NL0011683594.csv' for index 1063
# INFO:root:File 'NL0011683594.csv' loaded, 0 left
# WARNING:root:StopIteration in pythonGenerator
# WARNING:root:
# INFO:root:p.shape: (2048, 2)
# INFO:root:Saved the predicted data.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 977/977 [31:21<00:00,  1.93s/it]

# %%
plt.plot(p[:,0])

# %%
plt.plot(p[:,1])

# %%
p.shape

# %%
tickDF = pd.read_csv(TRAIN_FILES[file_index])
tickDF

# %%
tickDF.shape[0] - p.shape[0]

# %%
tickDFcropped = tickDF.iloc[-p.shape[0]:, :]
tickDFcropped

# %%
p_dir = p[:,0]
p_dir_derivation = p[:,1]

# %%
# Plot the prediction again, now over the open price
chart_name="Predicted direction of price movement with open price"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name, fontsize=14)

_ = ax1.plot(p_dir, color="blue", label="Predicted y direction")

ax2 = ax1.twinx()

ax2.plot(tickDFcropped.loc[:,'open'].values, color="black", label="Price")

ax1.set_xlabel("Timesteps")
ax1.set_ylabel("Direction")
ax2.set_ylabel("Price")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc="upper left")

# Save the figure
# fig_name = "FileListToDataStreamExample_" + chart_name.replace(" ", "_").replace("'", "").replace("(", "").replace(")", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")

# %%
# Plot the prediction again, now over the open price
chart_name="Predicted direction derv of price movement with open price"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name, fontsize=14)

_ = ax1.plot(p_dir_derivation, color="red", label="Predicted y direction derv")

ax2 = ax1.twinx()

ax2.plot(tickDFcropped.loc[:,'open'].values, color="black", label="Price")

ax1.set_xlabel("Timesteps")
ax1.set_ylabel("Direction")
ax2.set_ylabel("Price")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc="upper left")

# Save the figure
# fig_name = "FileListToDataStreamExample_" + chart_name.replace(" ", "_").replace("'", "").replace("(", "").replace(")", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")

# %%
#@title Buy and sell signal thresholds
BUY_SIGNAL_THRESHOLD_DIR = 0.25 #@param {type:"number"}
BUY_SIGNAL_THRESHOLD_DIR_DER = -0.02 #@param {type:"number"}

SELL_SIGNAL_THRESHOLD_DIR = 0.0 #@param {type:"number"}

# %%
#@title Plot buy and sell signals
chart_name="Buy and sell signals"
fig, ax1 = plt.subplots(figsize=(20,10))
ax1.set_title(chart_name)

x_datetimes = [datetime.datetime.fromtimestamp(ts) for ts in tickDFcropped.loc[:,'open'].index]

_ = ax1.plot(x_datetimes, tickDFcropped.loc[:,'open'].values, color="black", label="Price", linewidth=2)

# Color area axis
ax2 = ax1.twinx()

# Convert the float value prediction into rising and falling categories
yCategoryFall = p_dir < SELL_SIGNAL_THRESHOLD_DIR
yCategoryRise = (p_dir > BUY_SIGNAL_THRESHOLD_DIR) & (p_dir_derivation > BUY_SIGNAL_THRESHOLD_DIR_DER)

ax2.fill_between(x_datetimes, yCategoryFall , alpha=0.5, color="red", label="'Buy' signal")
ax2.fill_between(x_datetimes, yCategoryRise , alpha=0.5, color="green", label="'Sell' signal")

# Remove tick marks and set limits for color area axis
ax2.set_yticks([])
ax2.set_ylim(-0.05,1.05)

ax3 = ax1.twinx()
_ = ax3.plot(x_datetimes, p_dir, color="blue", label="Predicted price direction")
# _ = ax3.plot(x_datetimes, 10.0*p_dir_derivation, color="red", label="10.0 * Predicted price direction derivation")
# ax3.set_ylim(-1.05,1.05)

ax3.plot([np.min(x_datetimes), np.max(x_datetimes)], [0.0,0.0], color="gray")

# Show a legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax2.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc="upper left")

# Save the figure
# fig_name = chart_name.replace(" ", "_").replace("'", "") + ".svg"
# plt.savefig(os.path.join(IMG_SAVE_PATH, fig_name), bbox_inches="tight")
